# %%
# Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
#tf.disable_eager_execution()
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
tf.__version__
# Out:
# '2.9.1'

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        

        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        


        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        #self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
       
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        #self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_tf-self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_tf-self.u_bc2_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        #self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t
        self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        
        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def train(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, Y_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, Y_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2], self.u_bc1_tf:Y_bc1_batch,
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2], self.u_bc2_tf:Y_bc2_batch,
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # Store losses
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)
                self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %
                      (it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))

                start_time = timeit.default_timer()
            
          
            if log_NTK:
                if it % 100 == 0:
                        print("Compute NTK...")
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) + \
                                       np.trace(K_r_value)

                        # Store NTK matrices
                        self.K_u_log.append(K_u_value)
                        self.K_ut_log.append(K_ut_value)
                        self.K_r_log.append(K_r_value)
                        
                        if update_lam:

                          self.lam_u_val = trace_K / np.trace(K_u_value)
                          self.lam_ut_val = trace_K /np.trace(K_ut_value)
                          self.lam_r_val = trace_K / np.trace(K_r_value)

                          # Store NTK weights
                          self.lam_u_log.append(self.lam_u_val)
                          self.lam_ut_log.append(self.lam_ut_val)
                          self.lam_r_log.append(self.lam_r_val)
                        
                        
          
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
"""# Define the exact solution and its derivatives
def u(x, a, c):
    """
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    return np.sin(np.pi * x) * np.cos(c * np.pi * t) + \
            a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -  c * np.pi * np.sin(np.pi * x) * np.sin(c * np.pi * t) - \
            a * 4 * c * np.pi * np.sin(2 * c * np.pi* x) * np.sin(4 * c * np.pi * t)
    return u_t

def u_tt(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -(c * np.pi)**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - \
            a * (4 * c * np.pi)**2 *  np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return u_tt

def u_xx(x, a, c):
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - \
              a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual"""
# Out:
#   Input In [5]
#     :param x: x = (t, x)
#     ^
# IndentationError: unexpected indent

# %%
# Define the exact solution and its derivatives
def u(x, a, c):
    """
    exact solution
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    
    return np.cos(a*(np.pi)*x)*np.exp(-c*(a*np.pi)**2*t)
    
    #return np.sin(np.pi * x) * np.cos(c * np.pi * t) + \
    #a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    # first derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = np.cos(a*(np.pi)*x)*(-c*(a*np.pi)**2)*np.exp(-c*(a*np.pi)**2*t)
    return u_t

def u_tt(x, a, c):
    # second derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = (-c*(a*np.pi)**2)*np.cos(a*(np.pi)*x)*(-c*(a*np.pi)**2)*np.exp(-c*(a*np.pi)**2*t)
    return u_tt

def u_xx(x, a, c):
    # second derivitive of x
    t = x[:,0:1]
    x = x[:,1:2]
    
    u_xx = a*(np.pi)*np.exp(-c*(a*np.pi)**2*t)*a*(np.pi)*(-np.cos(a*(np.pi)*x))
    return  u_xx


def r(x, a, c):
    # THE pde its selft
    return u_t(x, a, c) -  c*u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    # gradient
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_t -  c*u_xx
    return residual

# %%
# Domain boundaries
ics_coords = np.array([[0.0, 0.0],
                        [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],
                        [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],
                        [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')

# %%
# Define PINN model
a = 3
c = 0.05
tf.compat.v1.disable_eager_execution()
layers = [2, 500, 500, 500, 1]
kernel_size = 30
model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# Train model
itertaions = 27000
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK 

model.train(nIter=itertaions, batch_size=kernel_size, log_NTK=log_NTK, update_lam=update_lam)
# Out:
# It: 0, Loss: 1.099e+00, Loss_res: 1.155e-02,  Loss_bcs: 5.516e-01, Loss_ut_ics: 4.675e-01,, Time: 0.02
# lambda_u: 1.917e+00
# lambda_ut: 4.885e+00
# lambda_r: 3.656e+00
# Compute NTK...
# It: 100, Loss: 1.097e+00, Loss_res: 4.230e-03,  Loss_bcs: 5.943e-01, Loss_ut_ics: 3.908e-01,, Time: 1.20
# lambda_u: 1.819e+00
# lambda_ut: 5.677e+00
# lambda_r: 3.647e+00
# Compute NTK...
# It: 200, Loss: 1.239e+00, Loss_res: 8.003e-03,  Loss_bcs: 5.715e-01, Loss_ut_ics: 4.883e-01,, Time: 1.07
# lambda_u: 2.120e+00
# lambda_ut: 4.226e+00
# lambda_r: 3.428e+00
# Compute NTK...
# It: 300, Loss: 1.338e+00, Loss_res: 1.527e-02,  Loss_bcs: 6.110e-01, Loss_ut_ics: 4.026e-01,, Time: 1.13
# lambda_u: 2.109e+00
# lambda_ut: 4.618e+00
# lambda_r: 3.233e+00
# Compute NTK...
# It: 400, Loss: 7.707e-01, Loss_res: 1.660e-02,  Loss_bcs: 3.106e-01, Loss_ut_ics: 2.200e-01,, Time: 1.10
# lambda_u: 2.322e+00
# lambda_ut: 4.269e+00
# lambda_r: 2.985e+00
# Compute NTK...
# It: 500, Loss: 7.414e-01, Loss_res: 1.703e-02,  Loss_bcs: 2.736e-01, Loss_ut_ics: 2.202e-01,, Time: 1.12
# lambda_u: 2.497e+00
# lambda_ut: 3.260e+00
# lambda_r: 3.416e+00
# Compute NTK...
# It: 600, Loss: 2.180e+00, Loss_res: 4.456e-02,  Loss_bcs: 6.161e-01, Loss_ut_ics: 4.966e-01,, Time: 1.15
# lambda_u: 3.318e+00
# lambda_ut: 2.697e+00
# lambda_r: 3.051e+00
# Compute NTK...
# It: 700, Loss: 2.146e+00, Loss_res: 1.122e-01,  Loss_bcs: 3.697e-01, Loss_ut_ics: 3.243e-01,, Time: 1.14
# lambda_u: 5.223e+00
# lambda_ut: 3.483e+00
# lambda_r: 1.918e+00
# Compute NTK...
# It: 800, Loss: 3.488e+00, Loss_res: 1.386e-01,  Loss_bcs: 5.247e-01, Loss_ut_ics: 4.921e-01,, Time: 1.16
# lambda_u: 6.139e+00
# lambda_ut: 3.134e+00
# lambda_r: 1.930e+00
# Compute NTK...
# It: 900, Loss: 2.761e+00, Loss_res: 2.477e-01,  Loss_bcs: 3.107e-01, Loss_ut_ics: 2.932e-01,, Time: 1.10
# lambda_u: 7.431e+00
# lambda_ut: 3.147e+00
# lambda_r: 1.826e+00
# Compute NTK...
# It: 1000, Loss: 3.133e+00, Loss_res: 2.765e-01,  Loss_bcs: 2.545e-01, Loss_ut_ics: 2.129e-01,, Time: 1.13
# lambda_u: 1.055e+01
# lambda_ut: 3.481e+00
# lambda_r: 1.618e+00
# Compute NTK...
# It: 1100, Loss: 3.317e+00, Loss_res: 3.012e-01,  Loss_bcs: 2.883e-01, Loss_ut_ics: 2.635e-01,, Time: 1.16
# lambda_u: 9.274e+00
# lambda_ut: 2.360e+00
# lambda_r: 2.134e+00
# Compute NTK...
# It: 1200, Loss: 3.658e+00, Loss_res: 4.457e-01,  Loss_bcs: 1.886e-01, Loss_ut_ics: 1.613e-01,, Time: 1.14
# lambda_u: 1.568e+01
# lambda_ut: 3.338e+00
# lambda_r: 1.571e+00
# Compute NTK...
# It: 1300, Loss: 2.315e+00, Loss_res: 2.679e-01,  Loss_bcs: 1.153e-01, Loss_ut_ics: 1.003e-01,, Time: 1.15
# lambda_u: 1.553e+01
# lambda_ut: 2.352e+00
# lambda_r: 1.959e+00
# Compute NTK...
# It: 1400, Loss: 2.601e+00, Loss_res: 1.068e-01,  Loss_bcs: 2.103e-01, Loss_ut_ics: 1.916e-01,, Time: 1.22
# lambda_u: 1.130e+01
# lambda_ut: 2.288e+00
# lambda_r: 2.108e+00
# Compute NTK...
# It: 1500, Loss: 2.752e+00, Loss_res: 1.280e-01,  Loss_bcs: 1.385e-01, Loss_ut_ics: 1.142e-01,, Time: 1.15
# lambda_u: 1.779e+01
# lambda_ut: 2.001e+00
# lambda_r: 2.252e+00
# Compute NTK...
# It: 1600, Loss: 2.774e+00, Loss_res: 2.407e-01,  Loss_bcs: 1.172e-01, Loss_ut_ics: 8.296e-02,, Time: 1.30
# lambda_u: 1.769e+01
# lambda_ut: 1.667e+00
# lambda_r: 2.912e+00
# Compute NTK...
# It: 1700, Loss: 2.992e+00, Loss_res: 4.214e-01,  Loss_bcs: 8.083e-02, Loss_ut_ics: 7.542e-02,, Time: 1.23
# lambda_u: 1.929e+01
# lambda_ut: 1.529e+00
# lambda_r: 3.399e+00
# Compute NTK...
# It: 1800, Loss: 1.522e+00, Loss_res: 2.730e-01,  Loss_bcs: 4.352e-02, Loss_ut_ics: 4.171e-02,, Time: 1.13
# lambda_u: 1.757e+01
# lambda_ut: 1.716e+00
# lambda_r: 2.774e+00
# Compute NTK...
# It: 1900, Loss: 3.807e+00, Loss_res: 1.693e-01,  Loss_bcs: 1.317e-01, Loss_ut_ics: 9.980e-02,, Time: 1.12
# lambda_u: 2.360e+01
# lambda_ut: 1.398e+00
# lambda_r: 4.124e+00
# Compute NTK...
# It: 2000, Loss: 1.510e+00, Loss_res: 1.517e-01,  Loss_bcs: 6.245e-02, Loss_ut_ics: 5.465e-02,, Time: 1.25
# lambda_u: 1.527e+01
# lambda_ut: 1.511e+00
# lambda_r: 3.668e+00
# Compute NTK...
# It: 2100, Loss: 2.354e+00, Loss_res: 2.712e-01,  Loss_bcs: 5.366e-02, Loss_ut_ics: 4.945e-02,, Time: 1.06
# lambda_u: 2.163e+01
# lambda_ut: 1.376e+00
# lambda_r: 4.400e+00
# Compute NTK...
# It: 2200, Loss: 1.767e+00, Loss_res: 1.252e-01,  Loss_bcs: 4.703e-02, Loss_ut_ics: 4.080e-02,, Time: 1.08
# lambda_u: 2.333e+01
# lambda_ut: 1.298e+00
# lambda_r: 5.354e+00
# Compute NTK...
# It: 2300, Loss: 2.284e+00, Loss_res: 1.738e-01,  Loss_bcs: 4.362e-02, Loss_ut_ics: 3.144e-02,, Time: 1.05
# lambda_u: 3.201e+01
# lambda_ut: 1.294e+00
# lambda_r: 5.109e+00
# Compute NTK...
# It: 2400, Loss: 1.155e+00, Loss_res: 1.321e-01,  Loss_bcs: 2.705e-02, Loss_ut_ics: 2.435e-02,, Time: 1.18
# lambda_u: 2.564e+01
# lambda_ut: 1.482e+00
# lambda_r: 3.495e+00
# Compute NTK...
# It: 2500, Loss: 1.554e+00, Loss_res: 1.441e-01,  Loss_bcs: 4.279e-02, Loss_ut_ics: 4.050e-02,, Time: 1.16
# lambda_u: 2.125e+01
# lambda_ut: 1.371e+00
# lambda_r: 4.473e+00
# Compute NTK...
# It: 2600, Loss: 9.508e-01, Loss_res: 1.188e-01,  Loss_bcs: 2.169e-02, Loss_ut_ics: 1.732e-02,, Time: 1.12
# lambda_u: 1.987e+01
# lambda_ut: 1.387e+00
# lambda_r: 4.375e+00
# Compute NTK...
# It: 2700, Loss: 1.146e+00, Loss_res: 1.001e-01,  Loss_bcs: 2.611e-02, Loss_ut_ics: 1.634e-02,, Time: 1.17
# lambda_u: 2.398e+01
# lambda_ut: 1.306e+00
# lambda_r: 5.198e+00
# Compute NTK...
# It: 2800, Loss: 6.121e-01, Loss_res: 5.123e-02,  Loss_bcs: 2.241e-02, Loss_ut_ics: 1.572e-02,, Time: 1.09
# lambda_u: 1.752e+01
# lambda_ut: 1.409e+00
# lambda_r: 4.286e+00
# Compute NTK...
# It: 2900, Loss: 1.097e+00, Loss_res: 7.664e-02,  Loss_bcs: 3.539e-02, Loss_ut_ics: 2.468e-02,, Time: 1.11
# lambda_u: 1.720e+01
# lambda_ut: 1.274e+00
# lambda_r: 6.370e+00
# Compute NTK...
# It: 3000, Loss: 6.508e-01, Loss_res: 3.160e-02,  Loss_bcs: 2.611e-02, Loss_ut_ics: 2.461e-02,, Time: 1.12
# lambda_u: 1.801e+01
# lambda_ut: 1.300e+00
# lambda_r: 5.713e+00
# Compute NTK...
# It: 3100, Loss: 5.556e-01, Loss_res: 4.713e-02,  Loss_bcs: 1.779e-02, Loss_ut_ics: 9.131e-03,, Time: 1.09
# lambda_u: 1.824e+01
# lambda_ut: 1.349e+00
# lambda_r: 4.901e+00
# Compute NTK...
# It: 3200, Loss: 5.610e-01, Loss_res: 2.743e-02,  Loss_bcs: 1.790e-02, Loss_ut_ics: 6.605e-03,, Time: 1.05
# lambda_u: 1.902e+01
# lambda_ut: 1.215e+00
# lambda_r: 8.040e+00
# Compute NTK...
# It: 3300, Loss: 2.861e-01, Loss_res: 7.898e-03,  Loss_bcs: 1.284e-02, Loss_ut_ics: 1.203e-02,, Time: 1.09
# lambda_u: 1.919e+01
# lambda_ut: 1.336e+00
# lambda_r: 5.019e+00
# Compute NTK...
# It: 3400, Loss: 5.312e-01, Loss_res: 4.897e-02,  Loss_bcs: 1.719e-02, Loss_ut_ics: 1.060e-02,, Time: 1.09
# lambda_u: 1.505e+01
# lambda_ut: 1.326e+00
# lambda_r: 5.566e+00
# Compute NTK...
# It: 3500, Loss: 1.998e-01, Loss_res: 2.660e-02,  Loss_bcs: 5.930e-03, Loss_ut_ics: 3.742e-03,, Time: 1.09
# lambda_u: 1.629e+01
# lambda_ut: 1.469e+00
# lambda_r: 3.880e+00
# Compute NTK...
# It: 3600, Loss: 2.502e-01, Loss_res: 9.234e-03,  Loss_bcs: 1.222e-02, Loss_ut_ics: 9.224e-03,, Time: 1.10
# lambda_u: 1.660e+01
# lambda_ut: 1.343e+00
# lambda_r: 5.131e+00
# Compute NTK...
# It: 3700, Loss: 2.858e-01, Loss_res: 1.982e-02,  Loss_bcs: 1.348e-02, Loss_ut_ics: 8.225e-03,, Time: 1.07
# lambda_u: 1.306e+01
# lambda_ut: 1.346e+00
# lambda_r: 5.537e+00
# Compute NTK...
# It: 3800, Loss: 1.571e-01, Loss_res: 1.872e-02,  Loss_bcs: 5.118e-03, Loss_ut_ics: 2.531e-03,, Time: 1.13
# lambda_u: 1.364e+01
# lambda_ut: 1.404e+00
# lambda_r: 4.662e+00
# Compute NTK...
# It: 3900, Loss: 1.672e-01, Loss_res: 8.360e-03,  Loss_bcs: 7.091e-03, Loss_ut_ics: 3.872e-03,, Time: 1.17
# lambda_u: 1.600e+01
# lambda_ut: 1.279e+00
# lambda_r: 6.428e+00
# Compute NTK...
# It: 4000, Loss: 2.585e-01, Loss_res: 1.636e-02,  Loss_bcs: 1.157e-02, Loss_ut_ics: 7.457e-03,, Time: 1.11
# lambda_u: 1.548e+01
# lambda_ut: 1.372e+00
# lambda_r: 4.847e+00
# Compute NTK...
# It: 4100, Loss: 9.823e-02, Loss_res: 1.509e-02,  Loss_bcs: 1.205e-03, Loss_ut_ics: 7.006e-04,, Time: 1.18
# lambda_u: 1.404e+01
# lambda_ut: 1.346e+00
# lambda_r: 5.388e+00
# Compute NTK...
# It: 4200, Loss: 1.420e-01, Loss_res: 1.606e-02,  Loss_bcs: 2.570e-03, Loss_ut_ics: 2.266e-03,, Time: 1.13
# lambda_u: 1.660e+01
# lambda_ut: 1.285e+00
# lambda_r: 6.185e+00
# Compute NTK...
# It: 4300, Loss: 1.092e-01, Loss_res: 9.341e-03,  Loss_bcs: 4.088e-03, Loss_ut_ics: 1.338e-03,, Time: 1.14
# lambda_u: 1.645e+01
# lambda_ut: 1.396e+00
# lambda_r: 4.491e+00
# Compute NTK...
# It: 4400, Loss: 1.928e-01, Loss_res: 5.552e-03,  Loss_bcs: 1.062e-02, Loss_ut_ics: 1.040e-02,, Time: 1.16
# lambda_u: 1.515e+01
# lambda_ut: 1.316e+00
# lambda_r: 5.737e+00
# Compute NTK...
# It: 4500, Loss: 7.220e-02, Loss_res: 6.231e-03,  Loss_bcs: 2.899e-03, Loss_ut_ics: 1.786e-03,, Time: 1.22
# lambda_u: 1.394e+01
# lambda_ut: 1.366e+00
# lambda_r: 5.102e+00
# Compute NTK...
# It: 4600, Loss: 1.276e-01, Loss_res: 2.005e-02,  Loss_bcs: 2.936e-03, Loss_ut_ics: 1.529e-03,, Time: 1.16
# lambda_u: 1.543e+01
# lambda_ut: 1.446e+00
# lambda_r: 4.105e+00
# Compute NTK...
# It: 4700, Loss: 1.053e-01, Loss_res: 8.743e-03,  Loss_bcs: 4.597e-03, Loss_ut_ics: 2.742e-03,, Time: 1.11
# lambda_u: 1.377e+01
# lambda_ut: 1.390e+00
# lambda_r: 4.804e+00
# Compute NTK...
# It: 4800, Loss: 8.366e-02, Loss_res: 8.428e-03,  Loss_bcs: 2.922e-03, Loss_ut_ics: 1.867e-03,, Time: 1.16
# lambda_u: 1.483e+01
# lambda_ut: 1.382e+00
# lambda_r: 4.784e+00
# Compute NTK...
# It: 4900, Loss: 9.531e-02, Loss_res: 3.612e-03,  Loss_bcs: 5.181e-03, Loss_ut_ics: 1.728e-03,, Time: 1.07
# lambda_u: 1.495e+01
# lambda_ut: 1.369e+00
# lambda_r: 4.937e+00
# Compute NTK...
# It: 5000, Loss: 5.208e-02, Loss_res: 5.828e-03,  Loss_bcs: 1.877e-03, Loss_ut_ics: 1.281e-03,, Time: 1.05
# lambda_u: 1.436e+01
# lambda_ut: 1.432e+00
# lambda_r: 4.311e+00
# Compute NTK...
# It: 5100, Loss: 2.988e-01, Loss_res: 3.139e-02,  Loss_bcs: 6.447e-03, Loss_ut_ics: 4.902e-03,, Time: 1.14
# lambda_u: 1.452e+01
# lambda_ut: 1.285e+00
# lambda_r: 6.538e+00
# Compute NTK...
# It: 5200, Loss: 7.210e-02, Loss_res: 8.824e-03,  Loss_bcs: 1.529e-03, Loss_ut_ics: 7.149e-04,, Time: 1.17
# lambda_u: 1.430e+01
# lambda_ut: 1.326e+00
# lambda_r: 5.692e+00
# Compute NTK...
# It: 5300, Loss: 4.528e-02, Loss_res: 3.397e-03,  Loss_bcs: 2.260e-03, Loss_ut_ics: 1.071e-03,, Time: 1.10
# lambda_u: 1.383e+01
# lambda_ut: 1.459e+00
# lambda_r: 4.128e+00
# Compute NTK...
# It: 5400, Loss: 6.233e-02, Loss_res: 3.898e-03,  Loss_bcs: 3.317e-03, Loss_ut_ics: 1.078e-03,, Time: 1.18
# lambda_u: 1.314e+01
# lambda_ut: 1.396e+00
# lambda_r: 4.815e+00
# Compute NTK...
# It: 5500, Loss: 3.970e-02, Loss_res: 3.774e-03,  Loss_bcs: 1.674e-03, Loss_ut_ics: 1.184e-03,, Time: 1.14
# lambda_u: 1.326e+01
# lambda_ut: 1.410e+00
# lambda_r: 4.639e+00
# Compute NTK...
# It: 5600, Loss: 8.534e-02, Loss_res: 7.524e-03,  Loss_bcs: 2.591e-03, Loss_ut_ics: 5.816e-04,, Time: 1.18
# lambda_u: 1.460e+01
# lambda_ut: 1.293e+00
# lambda_r: 6.316e+00
# Compute NTK...
# It: 5700, Loss: 3.333e-02, Loss_res: 4.700e-03,  Loss_bcs: 8.927e-04, Loss_ut_ics: 6.236e-04,, Time: 1.23
# lambda_u: 1.447e+01
# lambda_ut: 1.427e+00
# lambda_r: 4.343e+00
# Compute NTK...
# It: 5800, Loss: 1.124e-01, Loss_res: 1.040e-02,  Loss_bcs: 2.924e-03, Loss_ut_ics: 1.663e-03,, Time: 1.19
# lambda_u: 1.502e+01
# lambda_ut: 1.279e+00
# lambda_r: 6.590e+00
# Compute NTK...
# It: 5900, Loss: 8.868e-02, Loss_res: 1.373e-02,  Loss_bcs: 1.371e-03, Loss_ut_ics: 8.996e-04,, Time: 1.11
# lambda_u: 1.472e+01
# lambda_ut: 1.367e+00
# lambda_r: 4.991e+00
# Compute NTK...
# It: 6000, Loss: 3.694e-02, Loss_res: 3.702e-03,  Loss_bcs: 1.402e-03, Loss_ut_ics: 6.213e-04,, Time: 1.12
# lambda_u: 1.501e+01
# lambda_ut: 1.427e+00
# lambda_r: 4.296e+00
# Compute NTK...
# It: 6100, Loss: 4.398e-02, Loss_res: 2.598e-03,  Loss_bcs: 2.111e-03, Loss_ut_ics: 1.581e-03,, Time: 1.08
# lambda_u: 1.423e+01
# lambda_ut: 1.345e+00
# lambda_r: 5.368e+00
# Compute NTK...
# It: 6200, Loss: 3.139e-02, Loss_res: 2.371e-03,  Loss_bcs: 1.308e-03, Loss_ut_ics: 2.380e-04,, Time: 1.21
# lambda_u: 1.422e+01
# lambda_ut: 1.344e+00
# lambda_r: 5.392e+00
# Compute NTK...
# It: 6300, Loss: 1.973e-01, Loss_res: 1.030e-02,  Loss_bcs: 1.060e-02, Loss_ut_ics: 5.633e-03,, Time: 1.14
# lambda_u: 1.348e+01
# lambda_ut: 1.358e+00
# lambda_r: 5.279e+00
# Compute NTK...
# It: 6400, Loss: 1.120e-01, Loss_res: 1.304e-02,  Loss_bcs: 3.280e-03, Loss_ut_ics: 1.296e-03,, Time: 1.23
# lambda_u: 1.342e+01
# lambda_ut: 1.363e+00
# lambda_r: 5.212e+00
# Compute NTK...
# It: 6500, Loss: 1.767e-02, Loss_res: 2.379e-03,  Loss_bcs: 5.637e-04, Loss_ut_ics: 3.581e-04,, Time: 1.09
# lambda_u: 1.344e+01
# lambda_ut: 1.450e+00
# lambda_r: 4.240e+00
# Compute NTK...
# It: 6600, Loss: 7.557e-02, Loss_res: 4.461e-03,  Loss_bcs: 3.546e-03, Loss_ut_ics: 2.180e-03,, Time: 1.18
# lambda_u: 1.380e+01
# lambda_ut: 1.316e+00
# lambda_r: 5.966e+00
# Compute NTK...
# It: 6700, Loss: 4.025e-02, Loss_res: 5.314e-03,  Loss_bcs: 8.127e-04, Loss_ut_ics: 4.529e-04,, Time: 1.22
# lambda_u: 1.430e+01
# lambda_ut: 1.343e+00
# lambda_r: 5.388e+00
# Compute NTK...
# It: 6800, Loss: 2.873e-02, Loss_res: 3.477e-03,  Loss_bcs: 8.210e-04, Loss_ut_ics: 4.213e-04,, Time: 1.19
# lambda_u: 1.454e+01
# lambda_ut: 1.381e+00
# lambda_r: 4.829e+00
# Compute NTK...
# It: 6900, Loss: 2.759e-02, Loss_res: 2.064e-03,  Loss_bcs: 1.162e-03, Loss_ut_ics: 7.792e-04,, Time: 1.24
# lambda_u: 1.548e+01
# lambda_ut: 1.388e+00
# lambda_r: 4.651e+00
# Compute NTK...
# It: 7000, Loss: 3.141e-02, Loss_res: 2.849e-03,  Loss_bcs: 1.062e-03, Loss_ut_ics: 6.269e-04,, Time: 1.14
# lambda_u: 1.501e+01
# lambda_ut: 1.335e+00
# lambda_r: 5.429e+00
# Compute NTK...
# It: 7100, Loss: 4.504e-02, Loss_res: 3.889e-03,  Loss_bcs: 1.848e-03, Loss_ut_ics: 8.660e-04,, Time: 1.07
# lambda_u: 1.275e+01
# lambda_ut: 1.350e+00
# lambda_r: 5.524e+00
# Compute NTK...
# It: 7200, Loss: 4.435e-02, Loss_res: 7.622e-03,  Loss_bcs: 7.429e-04, Loss_ut_ics: 3.240e-04,, Time: 1.11
# lambda_u: 1.544e+01
# lambda_ut: 1.422e+00
# lambda_r: 4.314e+00
# Compute NTK...
# It: 7300, Loss: 2.908e-02, Loss_res: 3.362e-03,  Loss_bcs: 1.012e-03, Loss_ut_ics: 8.578e-04,, Time: 1.13
# lambda_u: 1.312e+01
# lambda_ut: 1.406e+00
# lambda_r: 4.701e+00
# Compute NTK...
# It: 7400, Loss: 1.098e-02, Loss_res: 1.611e-03,  Loss_bcs: 2.474e-04, Loss_ut_ics: 1.928e-04,, Time: 1.16
# lambda_u: 1.329e+01
# lambda_ut: 1.398e+00
# lambda_r: 4.777e+00
# Compute NTK...
# It: 7500, Loss: 4.532e-02, Loss_res: 6.624e-03,  Loss_bcs: 1.041e-03, Loss_ut_ics: 6.488e-04,, Time: 1.13
# lambda_u: 1.417e+01
# lambda_ut: 1.403e+00
# lambda_r: 4.615e+00
# Compute NTK...
# It: 7600, Loss: 2.683e-02, Loss_res: 1.620e-03,  Loss_bcs: 1.237e-03, Loss_ut_ics: 1.123e-03,, Time: 1.31
# lambda_u: 1.401e+01
# lambda_ut: 1.319e+00
# lambda_r: 5.864e+00
# Compute NTK...
# It: 7700, Loss: 2.190e-02, Loss_res: 1.620e-03,  Loss_bcs: 9.651e-04, Loss_ut_ics: 2.367e-04,, Time: 1.14
# lambda_u: 1.435e+01
# lambda_ut: 1.371e+00
# lambda_r: 4.972e+00
# Compute NTK...
# It: 7800, Loss: 6.172e-02, Loss_res: 4.031e-03,  Loss_bcs: 2.681e-03, Loss_ut_ics: 1.177e-03,, Time: 1.06
# lambda_u: 1.346e+01
# lambda_ut: 1.301e+00
# lambda_r: 6.357e+00
# Compute NTK...
# It: 7900, Loss: 3.982e-02, Loss_res: 2.424e-03,  Loss_bcs: 2.137e-03, Loss_ut_ics: 1.225e-03,, Time: 1.09
# lambda_u: 1.294e+01
# lambda_ut: 1.382e+00
# lambda_r: 5.016e+00
# Compute NTK...
# It: 8000, Loss: 1.132e-02, Loss_res: 8.711e-04,  Loss_bcs: 5.024e-04, Loss_ut_ics: 2.581e-04,, Time: 1.08
# lambda_u: 1.369e+01
# lambda_ut: 1.368e+00
# lambda_r: 5.101e+00
# Compute NTK...
# It: 8100, Loss: 3.329e-02, Loss_res: 2.164e-03,  Loss_bcs: 1.766e-03, Loss_ut_ics: 7.079e-04,, Time: 1.14
# lambda_u: 1.230e+01
# lambda_ut: 1.367e+00
# lambda_r: 5.346e+00
# Compute NTK...
# It: 8200, Loss: 2.793e-02, Loss_res: 3.521e-03,  Loss_bcs: 5.428e-04, Loss_ut_ics: 1.752e-04,, Time: 1.02
# lambda_u: 1.283e+01
# lambda_ut: 1.326e+00
# lambda_r: 5.953e+00
# Compute NTK...
# It: 8300, Loss: 4.397e-02, Loss_res: 3.544e-03,  Loss_bcs: 1.645e-03, Loss_ut_ics: 9.916e-04,, Time: 1.05
# lambda_u: 1.306e+01
# lambda_ut: 1.306e+00
# lambda_r: 6.347e+00
# Compute NTK...
# It: 8400, Loss: 4.544e-02, Loss_res: 4.648e-03,  Loss_bcs: 1.145e-03, Loss_ut_ics: 9.079e-04,, Time: 1.12
# lambda_u: 1.366e+01
# lambda_ut: 1.297e+00
# lambda_r: 6.413e+00
# Compute NTK...
# It: 8500, Loss: 1.882e-02, Loss_res: 1.008e-03,  Loss_bcs: 9.183e-04, Loss_ut_ics: 6.686e-04,, Time: 1.11
# lambda_u: 1.433e+01
# lambda_ut: 1.330e+00
# lambda_r: 5.613e+00
# Compute NTK...
# It: 8600, Loss: 2.272e-02, Loss_res: 1.705e-03,  Loss_bcs: 9.833e-04, Loss_ut_ics: 7.164e-04,, Time: 1.11
# lambda_u: 1.377e+01
# lambda_ut: 1.348e+00
# lambda_r: 5.386e+00
# Compute NTK...
# It: 8700, Loss: 3.279e-02, Loss_res: 3.653e-03,  Loss_bcs: 7.566e-04, Loss_ut_ics: 3.913e-04,, Time: 1.05
# lambda_u: 1.455e+01
# lambda_ut: 1.310e+00
# lambda_r: 5.962e+00
# Compute NTK...
# It: 8800, Loss: 1.024e-02, Loss_res: 9.869e-04,  Loss_bcs: 3.217e-04, Loss_ut_ics: 2.140e-04,, Time: 1.14
# lambda_u: 1.479e+01
# lambda_ut: 1.329e+00
# lambda_r: 5.560e+00
# Compute NTK...
# It: 8900, Loss: 1.966e-02, Loss_res: 2.472e-03,  Loss_bcs: 4.073e-04, Loss_ut_ics: 2.404e-04,, Time: 1.07
# lambda_u: 1.385e+01
# lambda_ut: 1.331e+00
# lambda_r: 5.673e+00
# Compute NTK...
# It: 9000, Loss: 2.063e-02, Loss_res: 1.587e-03,  Loss_bcs: 9.709e-04, Loss_ut_ics: 3.449e-04,, Time: 1.08
# lambda_u: 1.355e+01
# lambda_ut: 1.401e+00
# lambda_r: 4.709e+00
# Compute NTK...
# It: 9100, Loss: 2.431e-02, Loss_res: 2.248e-03,  Loss_bcs: 8.175e-04, Loss_ut_ics: 6.650e-04,, Time: 1.10
# lambda_u: 1.376e+01
# lambda_ut: 1.324e+00
# lambda_r: 5.810e+00
# Compute NTK...
# It: 9200, Loss: 1.295e-02, Loss_res: 2.232e-03,  Loss_bcs: 1.540e-04, Loss_ut_ics: 9.439e-05,, Time: 1.13
# lambda_u: 1.464e+01
# lambda_ut: 1.383e+00
# lambda_r: 4.789e+00
# Compute NTK...
# It: 9300, Loss: 9.710e-02, Loss_res: 2.287e-03,  Loss_bcs: 5.776e-03, Loss_ut_ics: 1.282e-03,, Time: 1.06
# lambda_u: 1.450e+01
# lambda_ut: 1.316e+00
# lambda_r: 5.841e+00
# Compute NTK...
# It: 9400, Loss: 1.434e-02, Loss_res: 1.042e-03,  Loss_bcs: 5.619e-04, Loss_ut_ics: 3.065e-04,, Time: 1.13
# lambda_u: 1.352e+01
# lambda_ut: 1.296e+00
# lambda_r: 6.467e+00
# Compute NTK...
# It: 9500, Loss: 1.622e-02, Loss_res: 1.410e-03,  Loss_bcs: 4.556e-04, Loss_ut_ics: 3.212e-04,, Time: 1.16
# lambda_u: 1.208e+01
# lambda_ut: 1.273e+00
# lambda_r: 7.596e+00
# Compute NTK...
# It: 9600, Loss: 1.266e-02, Loss_res: 1.460e-03,  Loss_bcs: 3.411e-04, Loss_ut_ics: 2.392e-04,, Time: 1.07
# lambda_u: 1.313e+01
# lambda_ut: 1.342e+00
# lambda_r: 5.602e+00
# Compute NTK...
# It: 9700, Loss: 2.317e-02, Loss_res: 1.552e-03,  Loss_bcs: 1.015e-03, Loss_ut_ics: 3.193e-04,, Time: 1.06
# lambda_u: 1.434e+01
# lambda_ut: 1.333e+00
# lambda_r: 5.549e+00
# Compute NTK...
# It: 9800, Loss: 7.910e-03, Loss_res: 9.881e-04,  Loss_bcs: 1.806e-04, Loss_ut_ics: 1.050e-04,, Time: 1.09
# lambda_u: 1.302e+01
# lambda_ut: 1.342e+00
# lambda_r: 5.624e+00
# Compute NTK...
# It: 9900, Loss: 5.012e-03, Loss_res: 3.891e-04,  Loss_bcs: 2.187e-04, Loss_ut_ics: 1.731e-04,, Time: 1.10
# lambda_u: 1.320e+01
# lambda_ut: 1.349e+00
# lambda_r: 5.462e+00
# Compute NTK...
# It: 10000, Loss: 4.042e-02, Loss_res: 3.437e-03,  Loss_bcs: 1.344e-03, Loss_ut_ics: 6.673e-04,, Time: 1.08
# lambda_u: 1.355e+01
# lambda_ut: 1.296e+00
# lambda_r: 6.463e+00
# Compute NTK...
# It: 10100, Loss: 1.332e-02, Loss_res: 1.336e-03,  Loss_bcs: 4.481e-04, Loss_ut_ics: 3.435e-04,, Time: 1.10
# lambda_u: 1.291e+01
# lambda_ut: 1.342e+00
# lambda_r: 5.639e+00
# Compute NTK...
# It: 10200, Loss: 1.405e-02, Loss_res: 1.140e-03,  Loss_bcs: 6.190e-04, Loss_ut_ics: 2.066e-04,, Time: 1.04
# lambda_u: 1.474e+01
# lambda_ut: 1.427e+00
# lambda_r: 4.322e+00
# Compute NTK...
# It: 10300, Loss: 4.318e-03, Loss_res: 4.019e-04,  Loss_bcs: 1.688e-04, Loss_ut_ics: 1.094e-04,, Time: 1.06
# lambda_u: 1.382e+01
# lambda_ut: 1.379e+00
# lambda_r: 4.941e+00
# Compute NTK...
# It: 10400, Loss: 5.891e-03, Loss_res: 5.434e-04,  Loss_bcs: 1.953e-04, Loss_ut_ics: 1.145e-04,, Time: 1.02
# lambda_u: 1.316e+01
# lambda_ut: 1.315e+00
# lambda_r: 6.110e+00
# Compute NTK...
# It: 10500, Loss: 8.606e-03, Loss_res: 7.540e-04,  Loss_bcs: 3.356e-04, Loss_ut_ics: 1.139e-04,, Time: 1.17
# lambda_u: 1.459e+01
# lambda_ut: 1.373e+00
# lambda_r: 4.920e+00
# Compute NTK...
# It: 10600, Loss: 2.699e-02, Loss_res: 3.334e-03,  Loss_bcs: 5.279e-04, Loss_ut_ics: 1.693e-04,, Time: 1.04
# lambda_u: 1.372e+01
# lambda_ut: 1.319e+00
# lambda_r: 5.922e+00
# Compute NTK...
# It: 10700, Loss: 9.691e-02, Loss_res: 7.780e-03,  Loss_bcs: 2.065e-03, Loss_ut_ics: 8.134e-04,, Time: 1.13
# lambda_u: 1.451e+01
# lambda_ut: 1.227e+00
# lambda_r: 8.604e+00
# Compute NTK...
# It: 10800, Loss: 6.286e-03, Loss_res: 6.997e-04,  Loss_bcs: 1.752e-04, Loss_ut_ics: 1.161e-04,, Time: 1.04
# lambda_u: 1.232e+01
# lambda_ut: 1.335e+00
# lambda_r: 5.897e+00
# Compute NTK...
# It: 10900, Loss: 5.882e-03, Loss_res: 6.126e-04,  Loss_bcs: 1.809e-04, Loss_ut_ics: 1.145e-04,, Time: 1.14
# lambda_u: 1.441e+01
# lambda_ut: 1.345e+00
# lambda_r: 5.345e+00
# Compute NTK...
# It: 11000, Loss: 3.283e-03, Loss_res: 3.587e-04,  Loss_bcs: 8.371e-05, Loss_ut_ics: 6.336e-05,, Time: 1.09
# lambda_u: 1.384e+01
# lambda_ut: 1.318e+00
# lambda_r: 5.923e+00
# Compute NTK...
# It: 11100, Loss: 1.067e-02, Loss_res: 9.936e-04,  Loss_bcs: 3.732e-04, Loss_ut_ics: 1.233e-04,, Time: 1.13
# lambda_u: 1.309e+01
# lambda_ut: 1.330e+00
# lambda_r: 5.824e+00
# Compute NTK...
# It: 11200, Loss: 1.521e-02, Loss_res: 1.237e-03,  Loss_bcs: 4.890e-04, Loss_ut_ics: 2.702e-04,, Time: 1.03
# lambda_u: 1.357e+01
# lambda_ut: 1.279e+00
# lambda_r: 6.929e+00
# Compute NTK...
# It: 11300, Loss: 1.985e-02, Loss_res: 1.697e-03,  Loss_bcs: 5.716e-04, Loss_ut_ics: 2.432e-04,, Time: 1.09
# lambda_u: 1.389e+01
# lambda_ut: 1.273e+00
# lambda_r: 7.015e+00
# Compute NTK...
# It: 11400, Loss: 8.934e-03, Loss_res: 8.165e-04,  Loss_bcs: 2.767e-04, Loss_ut_ics: 1.231e-04,, Time: 1.12
# lambda_u: 1.306e+01
# lambda_ut: 1.299e+00
# lambda_r: 6.515e+00
# Compute NTK...
# It: 11500, Loss: 7.431e-03, Loss_res: 9.003e-04,  Loss_bcs: 1.862e-04, Loss_ut_ics: 6.100e-05,, Time: 1.04
# lambda_u: 1.344e+01
# lambda_ut: 1.346e+00
# lambda_r: 5.474e+00
# Compute NTK...
# It: 11600, Loss: 1.622e-02, Loss_res: 1.219e-03,  Loss_bcs: 4.998e-04, Loss_ut_ics: 6.904e-05,, Time: 1.11
# lambda_u: 1.381e+01
# lambda_ut: 1.255e+00
# lambda_r: 7.649e+00
# Compute NTK...
# It: 11700, Loss: 6.004e-03, Loss_res: 5.874e-04,  Loss_bcs: 2.232e-04, Loss_ut_ics: 6.319e-05,, Time: 1.06
# lambda_u: 1.466e+01
# lambda_ut: 1.395e+00
# lambda_r: 4.651e+00
# Compute NTK...
# It: 11800, Loss: 4.973e-03, Loss_res: 3.663e-04,  Loss_bcs: 1.964e-04, Loss_ut_ics: 1.542e-04,, Time: 1.13
# lambda_u: 1.340e+01
# lambda_ut: 1.301e+00
# lambda_r: 6.393e+00
# Compute NTK...
# It: 11900, Loss: 2.269e-02, Loss_res: 2.760e-03,  Loss_bcs: 5.553e-04, Loss_ut_ics: 1.949e-04,, Time: 1.11
# lambda_u: 1.346e+01
# lambda_ut: 1.344e+00
# lambda_r: 5.511e+00
# Compute NTK...
# It: 12000, Loss: 5.348e-03, Loss_res: 4.981e-04,  Loss_bcs: 2.286e-04, Loss_ut_ics: 1.286e-04,, Time: 1.14
# lambda_u: 1.365e+01
# lambda_ut: 1.422e+00
# lambda_r: 4.470e+00
# Compute NTK...
# It: 12100, Loss: 8.542e-03, Loss_res: 7.195e-04,  Loss_bcs: 3.560e-04, Loss_ut_ics: 9.263e-05,, Time: 1.03
# lambda_u: 1.330e+01
# lambda_ut: 1.359e+00
# lambda_r: 5.290e+00
# Compute NTK...
# It: 12200, Loss: 3.751e-03, Loss_res: 4.654e-04,  Loss_bcs: 1.083e-04, Loss_ut_ics: 4.996e-05,, Time: 1.19
# lambda_u: 1.424e+01
# lambda_ut: 1.391e+00
# lambda_r: 4.747e+00
# Compute NTK...
# It: 12300, Loss: 1.087e-02, Loss_res: 7.774e-04,  Loss_bcs: 5.015e-04, Loss_ut_ics: 1.488e-04,, Time: 1.04
# lambda_u: 1.262e+01
# lambda_ut: 1.334e+00
# lambda_r: 5.845e+00
# Compute NTK...
# It: 12400, Loss: 8.437e-03, Loss_res: 5.999e-04,  Loss_bcs: 3.741e-04, Loss_ut_ics: 6.886e-05,, Time: 1.06
# lambda_u: 1.343e+01
# lambda_ut: 1.334e+00
# lambda_r: 5.689e+00
# Compute NTK...
# It: 12500, Loss: 1.557e-02, Loss_res: 9.259e-04,  Loss_bcs: 6.954e-04, Loss_ut_ics: 2.763e-04,, Time: 1.02
# lambda_u: 1.327e+01
# lambda_ut: 1.284e+00
# lambda_r: 6.848e+00
# Compute NTK...
# It: 12600, Loss: 4.831e-03, Loss_res: 5.243e-04,  Loss_bcs: 1.564e-04, Loss_ut_ics: 5.284e-05,, Time: 1.09
# lambda_u: 1.296e+01
# lambda_ut: 1.359e+00
# lambda_r: 5.349e+00
# Compute NTK...
# It: 12700, Loss: 1.473e-02, Loss_res: 1.659e-03,  Loss_bcs: 3.069e-04, Loss_ut_ics: 2.510e-04,, Time: 1.04
# lambda_u: 1.434e+01
# lambda_ut: 1.299e+00
# lambda_r: 6.228e+00
# Compute NTK...
# It: 12800, Loss: 7.419e-03, Loss_res: 7.842e-04,  Loss_bcs: 1.405e-04, Loss_ut_ics: 9.689e-05,, Time: 1.08
# lambda_u: 1.331e+01
# lambda_ut: 1.276e+00
# lambda_r: 7.076e+00
# Compute NTK...
# It: 12900, Loss: 1.575e-02, Loss_res: 1.148e-03,  Loss_bcs: 7.083e-04, Loss_ut_ics: 1.737e-04,, Time: 1.06
# lambda_u: 1.346e+01
# lambda_ut: 1.350e+00
# lambda_r: 5.409e+00
# Compute NTK...
# It: 13000, Loss: 6.032e-03, Loss_res: 3.913e-04,  Loss_bcs: 2.971e-04, Loss_ut_ics: 2.639e-04,, Time: 1.15
# lambda_u: 1.298e+01
# lambda_ut: 1.346e+00
# lambda_r: 5.556e+00
# Compute NTK...
# It: 13100, Loss: 3.298e-03, Loss_res: 3.070e-04,  Loss_bcs: 1.103e-04, Loss_ut_ics: 6.406e-05,, Time: 1.15
# lambda_u: 1.248e+01
# lambda_ut: 1.316e+00
# lambda_r: 6.259e+00
# Compute NTK...
# It: 13200, Loss: 2.248e-03, Loss_res: 3.006e-04,  Loss_bcs: 6.555e-05, Loss_ut_ics: 3.833e-05,, Time: 1.01
# lambda_u: 1.381e+01
# lambda_ut: 1.421e+00
# lambda_r: 4.467e+00
# Compute NTK...
# It: 13300, Loss: 5.250e-03, Loss_res: 6.191e-04,  Loss_bcs: 1.286e-04, Loss_ut_ics: 6.482e-05,, Time: 1.08
# lambda_u: 1.276e+01
# lambda_ut: 1.333e+00
# lambda_r: 5.828e+00
# Compute NTK...
# It: 13400, Loss: 4.253e-02, Loss_res: 7.575e-03,  Loss_bcs: 2.585e-04, Loss_ut_ics: 1.490e-04,, Time: 1.11
# lambda_u: 1.439e+01
# lambda_ut: 1.360e+00
# lambda_r: 5.124e+00
# Compute NTK...
# It: 13500, Loss: 1.020e-02, Loss_res: 8.334e-04,  Loss_bcs: 3.927e-04, Loss_ut_ics: 2.004e-04,, Time: 1.13
# lambda_u: 1.423e+01
# lambda_ut: 1.335e+00
# lambda_r: 5.535e+00
# Compute NTK...
# It: 13600, Loss: 5.632e-03, Loss_res: 5.203e-04,  Loss_bcs: 2.127e-04, Loss_ut_ics: 1.891e-04,, Time: 1.13
# lambda_u: 1.268e+01
# lambda_ut: 1.344e+00
# lambda_r: 5.640e+00
# Compute NTK...
# It: 13700, Loss: 8.513e-03, Loss_res: 6.918e-04,  Loss_bcs: 2.797e-04, Loss_ut_ics: 9.852e-05,, Time: 1.08
# lambda_u: 1.432e+01
# lambda_ut: 1.288e+00
# lambda_r: 6.515e+00
# Compute NTK...
# It: 13800, Loss: 4.500e-03, Loss_res: 4.439e-04,  Loss_bcs: 1.406e-04, Loss_ut_ics: 8.712e-05,, Time: 1.10
# lambda_u: 1.265e+01
# lambda_ut: 1.320e+00
# lambda_r: 6.131e+00
# Compute NTK...
# It: 13900, Loss: 4.224e-03, Loss_res: 3.091e-04,  Loss_bcs: 1.968e-04, Loss_ut_ics: 1.283e-04,, Time: 1.06
# lambda_u: 1.292e+01
# lambda_ut: 1.354e+00
# lambda_r: 5.438e+00
# Compute NTK...
# It: 14000, Loss: 2.060e-01, Loss_res: 3.896e-03,  Loss_bcs: 1.324e-02, Loss_ut_ics: 9.797e-03,, Time: 1.14
# lambda_u: 1.344e+01
# lambda_ut: 1.271e+00
# lambda_r: 7.191e+00
# Compute NTK...
# It: 14100, Loss: 2.624e-02, Loss_res: 1.181e-03,  Loss_bcs: 1.494e-03, Loss_ut_ics: 6.300e-04,, Time: 1.15
# lambda_u: 1.247e+01
# lambda_ut: 1.308e+00
# lambda_r: 6.442e+00
# Compute NTK...
# It: 14200, Loss: 1.223e-02, Loss_res: 1.151e-03,  Loss_bcs: 3.661e-04, Loss_ut_ics: 2.754e-04,, Time: 1.08
# lambda_u: 1.179e+01
# lambda_ut: 1.299e+00
# lambda_r: 6.873e+00
# Compute NTK...
# It: 14300, Loss: 1.032e-02, Loss_res: 1.175e-03,  Loss_bcs: 1.976e-04, Loss_ut_ics: 6.473e-05,, Time: 1.12
# lambda_u: 1.178e+01
# lambda_ut: 1.302e+00
# lambda_r: 6.803e+00
# Compute NTK...
# It: 14400, Loss: 2.979e-03, Loss_res: 3.514e-04,  Loss_bcs: 1.024e-04, Loss_ut_ics: 5.983e-05,, Time: 1.13
# lambda_u: 1.281e+01
# lambda_ut: 1.406e+00
# lambda_r: 4.745e+00
# Compute NTK...
# It: 14500, Loss: 2.948e-03, Loss_res: 2.017e-04,  Loss_bcs: 1.508e-04, Loss_ut_ics: 8.905e-05,, Time: 1.06
# lambda_u: 1.209e+01
# lambda_ut: 1.355e+00
# lambda_r: 5.573e+00
# Compute NTK...
# It: 14600, Loss: 2.652e-03, Loss_res: 3.105e-04,  Loss_bcs: 5.309e-05, Loss_ut_ics: 4.002e-05,, Time: 1.15
# lambda_u: 1.249e+01
# lambda_ut: 1.309e+00
# lambda_r: 6.407e+00
# Compute NTK...
# It: 14700, Loss: 2.992e-03, Loss_res: 2.978e-04,  Loss_bcs: 1.256e-04, Loss_ut_ics: 3.170e-05,, Time: 1.09
# lambda_u: 1.302e+01
# lambda_ut: 1.421e+00
# lambda_r: 4.553e+00
# Compute NTK...
# It: 14800, Loss: 7.264e-03, Loss_res: 5.411e-04,  Loss_bcs: 2.382e-04, Loss_ut_ics: 4.033e-05,, Time: 1.11
# lambda_u: 1.136e+01
# lambda_ut: 1.261e+00
# lambda_r: 8.426e+00
# Compute NTK...
# It: 14900, Loss: 7.931e-03, Loss_res: 7.178e-04,  Loss_bcs: 2.445e-04, Loss_ut_ics: 1.182e-04,, Time: 1.08
# lambda_u: 1.355e+01
# lambda_ut: 1.297e+00
# lambda_r: 6.435e+00
# Compute NTK...
# It: 15000, Loss: 3.670e-03, Loss_res: 4.409e-04,  Loss_bcs: 9.958e-05, Loss_ut_ics: 7.308e-05,, Time: 1.12
# lambda_u: 1.339e+01
# lambda_ut: 1.358e+00
# lambda_r: 5.299e+00
# Compute NTK...
# It: 15100, Loss: 4.598e-03, Loss_res: 5.045e-04,  Loss_bcs: 1.304e-04, Loss_ut_ics: 1.018e-04,, Time: 1.10
# lambda_u: 1.164e+01
# lambda_ut: 1.333e+00
# lambda_r: 6.105e+00
# Compute NTK...
# It: 15200, Loss: 1.319e-02, Loss_res: 8.980e-04,  Loss_bcs: 5.904e-04, Loss_ut_ics: 1.493e-04,, Time: 1.17
# lambda_u: 1.320e+01
# lambda_ut: 1.319e+00
# lambda_r: 6.012e+00
# Compute NTK...
# It: 15300, Loss: 3.288e-03, Loss_res: 4.654e-04,  Loss_bcs: 8.283e-05, Loss_ut_ics: 6.325e-05,, Time: 1.07
# lambda_u: 1.315e+01
# lambda_ut: 1.404e+00
# lambda_r: 4.725e+00
# Compute NTK...
# It: 15400, Loss: 1.277e-02, Loss_res: 6.958e-04,  Loss_bcs: 6.034e-04, Loss_ut_ics: 1.369e-04,, Time: 1.11
# lambda_u: 1.238e+01
# lambda_ut: 1.269e+00
# lambda_r: 7.620e+00
# Compute NTK...
# It: 15500, Loss: 6.611e-03, Loss_res: 6.706e-04,  Loss_bcs: 1.478e-04, Loss_ut_ics: 8.879e-05,, Time: 1.09
# lambda_u: 1.255e+01
# lambda_ut: 1.283e+00
# lambda_r: 7.094e+00
# Compute NTK...
# It: 15600, Loss: 1.750e-03, Loss_res: 1.568e-04,  Loss_bcs: 7.711e-05, Loss_ut_ics: 2.766e-05,, Time: 1.09
# lambda_u: 1.337e+01
# lambda_ut: 1.414e+00
# lambda_r: 4.585e+00
# Compute NTK...
# It: 15700, Loss: 7.075e-03, Loss_res: 5.847e-04,  Loss_bcs: 2.673e-04, Loss_ut_ics: 1.366e-04,, Time: 1.05
# lambda_u: 1.202e+01
# lambda_ut: 1.306e+00
# lambda_r: 6.606e+00
# Compute NTK...
# It: 15800, Loss: 7.455e-03, Loss_res: 7.097e-04,  Loss_bcs: 2.263e-04, Loss_ut_ics: 7.420e-05,, Time: 1.08
# lambda_u: 1.345e+01
# lambda_ut: 1.308e+00
# lambda_r: 6.217e+00
# Compute NTK...
# It: 15900, Loss: 6.813e-03, Loss_res: 7.892e-04,  Loss_bcs: 1.639e-04, Loss_ut_ics: 1.138e-04,, Time: 1.11
# lambda_u: 1.186e+01
# lambda_ut: 1.327e+00
# lambda_r: 6.171e+00
# Compute NTK...
# It: 16000, Loss: 9.055e-03, Loss_res: 5.583e-04,  Loss_bcs: 4.549e-04, Loss_ut_ics: 1.810e-04,, Time: 1.05
# lambda_u: 1.297e+01
# lambda_ut: 1.341e+00
# lambda_r: 5.651e+00
# Compute NTK...
# It: 16100, Loss: 1.699e-02, Loss_res: 1.371e-03,  Loss_bcs: 2.782e-04, Loss_ut_ics: 1.927e-04,, Time: 1.10
# lambda_u: 1.247e+01
# lambda_ut: 1.222e+00
# lambda_r: 9.859e+00
# Compute NTK...
# It: 16200, Loss: 2.870e-03, Loss_res: 2.833e-04,  Loss_bcs: 9.693e-05, Loss_ut_ics: 3.687e-05,, Time: 1.13
# lambda_u: 1.321e+01
# lambda_ut: 1.340e+00
# lambda_r: 5.610e+00
# Compute NTK...
# It: 16300, Loss: 3.003e-03, Loss_res: 3.444e-04,  Loss_bcs: 1.034e-04, Loss_ut_ics: 6.708e-05,, Time: 1.10
# lambda_u: 1.397e+01
# lambda_ut: 1.414e+00
# lambda_r: 4.521e+00
# Compute NTK...
# It: 16400, Loss: 3.583e-03, Loss_res: 2.771e-04,  Loss_bcs: 1.535e-04, Loss_ut_ics: 4.128e-05,, Time: 1.08
# lambda_u: 1.248e+01
# lambda_ut: 1.327e+00
# lambda_r: 6.013e+00
# Compute NTK...
# It: 16500, Loss: 3.395e-03, Loss_res: 5.565e-04,  Loss_bcs: 4.343e-05, Loss_ut_ics: 2.205e-05,, Time: 1.15
# lambda_u: 1.285e+01
# lambda_ut: 1.377e+00
# lambda_r: 5.097e+00
# Compute NTK...
# It: 16600, Loss: 1.697e-03, Loss_res: 2.097e-04,  Loss_bcs: 2.502e-05, Loss_ut_ics: 1.519e-05,, Time: 1.12
# lambda_u: 1.318e+01
# lambda_ut: 1.297e+00
# lambda_r: 6.523e+00
# Compute NTK...
# It: 16700, Loss: 5.493e-03, Loss_res: 6.586e-04,  Loss_bcs: 1.253e-04, Loss_ut_ics: 1.020e-04,, Time: 1.14
# lambda_u: 1.314e+01
# lambda_ut: 1.329e+00
# lambda_r: 5.841e+00
# Compute NTK...
# It: 16800, Loss: 2.172e-03, Loss_res: 2.524e-04,  Loss_bcs: 5.675e-05, Loss_ut_ics: 2.362e-05,, Time: 1.10
# lambda_u: 1.208e+01
# lambda_ut: 1.338e+00
# lambda_r: 5.890e+00
# Compute NTK...
# It: 16900, Loss: 1.920e-03, Loss_res: 2.221e-04,  Loss_bcs: 5.120e-05, Loss_ut_ics: 2.611e-05,, Time: 1.10
# lambda_u: 1.383e+01
# lambda_ut: 1.343e+00
# lambda_r: 5.457e+00
# Compute NTK...
# It: 17000, Loss: 1.431e-02, Loss_res: 1.871e-03,  Loss_bcs: 1.447e-04, Loss_ut_ics: 6.682e-06,, Time: 1.07
# lambda_u: 1.312e+01
# lambda_ut: 1.294e+00
# lambda_r: 6.635e+00
# Compute NTK...
# It: 17100, Loss: 4.454e-03, Loss_res: 4.702e-04,  Loss_bcs: 1.412e-04, Loss_ut_ics: 5.223e-05,, Time: 1.08
# lambda_u: 1.309e+01
# lambda_ut: 1.346e+00
# lambda_r: 5.542e+00
# Compute NTK...
# It: 17200, Loss: 6.229e-03, Loss_res: 6.084e-04,  Loss_bcs: 2.126e-04, Loss_ut_ics: 1.401e-04,, Time: 1.07
# lambda_u: 1.413e+01
# lambda_ut: 1.350e+00
# lambda_r: 5.302e+00
# Compute NTK...
# It: 17300, Loss: 7.862e-03, Loss_res: 7.401e-04,  Loss_bcs: 2.440e-04, Loss_ut_ics: 7.458e-05,, Time: 1.06
# lambda_u: 1.262e+01
# lambda_ut: 1.305e+00
# lambda_r: 6.462e+00
# Compute NTK...
# It: 17400, Loss: 1.070e-02, Loss_res: 7.391e-04,  Loss_bcs: 4.864e-04, Loss_ut_ics: 2.260e-04,, Time: 1.08
# lambda_u: 1.321e+01
# lambda_ut: 1.331e+00
# lambda_r: 5.783e+00
# Compute NTK...
# It: 17500, Loss: 5.960e-03, Loss_res: 3.589e-04,  Loss_bcs: 2.608e-04, Loss_ut_ics: 1.809e-04,, Time: 1.13
# lambda_u: 1.209e+01
# lambda_ut: 1.267e+00
# lambda_r: 7.820e+00
# Compute NTK...
# It: 17600, Loss: 5.876e-03, Loss_res: 6.852e-04,  Loss_bcs: 8.743e-05, Loss_ut_ics: 3.410e-05,, Time: 1.07
# lambda_u: 1.212e+01
# lambda_ut: 1.290e+00
# lambda_r: 7.029e+00
# Compute NTK...
# It: 17700, Loss: 2.951e-03, Loss_res: 3.782e-04,  Loss_bcs: 4.359e-05, Loss_ut_ics: 2.221e-05,, Time: 1.09
# lambda_u: 1.159e+01
# lambda_ut: 1.317e+00
# lambda_r: 6.466e+00
# Compute NTK...
# It: 17800, Loss: 1.331e-02, Loss_res: 1.431e-03,  Loss_bcs: 3.139e-04, Loss_ut_ics: 2.827e-04,, Time: 1.10
# lambda_u: 1.411e+01
# lambda_ut: 1.302e+00
# lambda_r: 6.204e+00
# Compute NTK...
# It: 17900, Loss: 3.308e-03, Loss_res: 3.576e-04,  Loss_bcs: 8.427e-05, Loss_ut_ics: 3.933e-05,, Time: 1.17
# lambda_u: 1.265e+01
# lambda_ut: 1.313e+00
# lambda_r: 6.268e+00
# Compute NTK...
# It: 18000, Loss: 4.346e-03, Loss_res: 4.573e-04,  Loss_bcs: 1.127e-04, Loss_ut_ics: 3.311e-05,, Time: 1.16
# lambda_u: 1.289e+01
# lambda_ut: 1.308e+00
# lambda_r: 6.328e+00
# Compute NTK...
# It: 18100, Loss: 6.090e-03, Loss_res: 6.861e-04,  Loss_bcs: 1.121e-04, Loss_ut_ics: 4.153e-05,, Time: 1.09
# lambda_u: 1.253e+01
# lambda_ut: 1.292e+00
# lambda_r: 6.830e+00
# Compute NTK...
# It: 18200, Loss: 2.341e-03, Loss_res: 1.900e-04,  Loss_bcs: 7.714e-05, Loss_ut_ics: 3.919e-05,, Time: 1.11
# lambda_u: 1.229e+01
# lambda_ut: 1.278e+00
# lambda_r: 7.332e+00
# Compute NTK...
# It: 18300, Loss: 2.019e-03, Loss_res: 1.667e-04,  Loss_bcs: 7.710e-05, Loss_ut_ics: 3.095e-05,, Time: 1.11
# lambda_u: 1.410e+01
# lambda_ut: 1.333e+00
# lambda_r: 5.591e+00
# Compute NTK...
# It: 18400, Loss: 1.616e-03, Loss_res: 1.584e-04,  Loss_bcs: 5.803e-05, Loss_ut_ics: 2.918e-05,, Time: 1.09
# lambda_u: 1.341e+01
# lambda_ut: 1.358e+00
# lambda_r: 5.291e+00
# Compute NTK...
# It: 18500, Loss: 2.459e-03, Loss_res: 1.113e-04,  Loss_bcs: 1.391e-04, Loss_ut_ics: 1.032e-04,, Time: 1.09
# lambda_u: 1.327e+01
# lambda_ut: 1.345e+00
# lambda_r: 5.515e+00
# Compute NTK...
# It: 18600, Loss: 4.581e-03, Loss_res: 3.625e-04,  Loss_bcs: 1.977e-04, Loss_ut_ics: 6.254e-05,, Time: 1.09
# lambda_u: 1.164e+01
# lambda_ut: 1.324e+00
# lambda_r: 6.292e+00
# Compute NTK...
# It: 18700, Loss: 1.028e-03, Loss_res: 1.214e-04,  Loss_bcs: 3.211e-05, Loss_ut_ics: 1.441e-05,, Time: 1.05
# lambda_u: 1.474e+01
# lambda_ut: 1.402e+00
# lambda_r: 4.572e+00
# Compute NTK...
# It: 18800, Loss: 3.489e-03, Loss_res: 4.954e-04,  Loss_bcs: 5.154e-05, Loss_ut_ics: 2.675e-05,, Time: 1.06
# lambda_u: 1.289e+01
# lambda_ut: 1.339e+00
# lambda_r: 5.702e+00
# Compute NTK...
# It: 18900, Loss: 1.334e-03, Loss_res: 1.259e-04,  Loss_bcs: 4.444e-05, Loss_ut_ics: 3.112e-05,, Time: 1.03
# lambda_u: 1.473e+01
# lambda_ut: 1.339e+00
# lambda_r: 5.396e+00
# Compute NTK...
# It: 19000, Loss: 8.960e-04, Loss_res: 7.214e-05,  Loss_bcs: 3.528e-05, Loss_ut_ics: 2.223e-05,, Time: 1.12
# lambda_u: 1.282e+01
# lambda_ut: 1.317e+00
# lambda_r: 6.149e+00
# Compute NTK...
# It: 19100, Loss: 1.203e-03, Loss_res: 1.067e-04,  Loss_bcs: 3.777e-05, Loss_ut_ics: 2.001e-05,, Time: 1.05
# lambda_u: 1.248e+01
# lambda_ut: 1.292e+00
# lambda_r: 6.864e+00
# Compute NTK...
# It: 19200, Loss: 6.813e-03, Loss_res: 6.764e-04,  Loss_bcs: 2.193e-04, Loss_ut_ics: 1.938e-04,, Time: 1.11
# lambda_u: 1.254e+01
# lambda_ut: 1.327e+00
# lambda_r: 6.007e+00
# Compute NTK...
# It: 19300, Loss: 2.675e-03, Loss_res: 2.879e-04,  Loss_bcs: 7.672e-05, Loss_ut_ics: 3.625e-05,, Time: 1.10
# lambda_u: 1.355e+01
# lambda_ut: 1.333e+00
# lambda_r: 5.680e+00
# Compute NTK...
# It: 19400, Loss: 5.865e-03, Loss_res: 6.480e-04,  Loss_bcs: 1.415e-04, Loss_ut_ics: 6.561e-05,, Time: 1.18
# lambda_u: 1.324e+01
# lambda_ut: 1.312e+00
# lambda_r: 6.160e+00
# Compute NTK...
# It: 19500, Loss: 1.595e-03, Loss_res: 1.152e-04,  Loss_bcs: 7.285e-05, Loss_ut_ics: 2.367e-05,, Time: 1.18
# lambda_u: 1.334e+01
# lambda_ut: 1.351e+00
# lambda_r: 5.407e+00
# Compute NTK...
# It: 19600, Loss: 4.720e-03, Loss_res: 3.257e-04,  Loss_bcs: 1.930e-04, Loss_ut_ics: 2.083e-05,, Time: 1.12
# lambda_u: 1.356e+01
# lambda_ut: 1.296e+00
# lambda_r: 6.453e+00
# Compute NTK...
# It: 19700, Loss: 2.138e-03, Loss_res: 2.105e-04,  Loss_bcs: 7.101e-05, Loss_ut_ics: 3.461e-05,, Time: 1.11
# lambda_u: 1.405e+01
# lambda_ut: 1.344e+00
# lambda_r: 5.417e+00
# Compute NTK...
# It: 19800, Loss: 3.177e-03, Loss_res: 3.772e-04,  Loss_bcs: 5.269e-05, Loss_ut_ics: 1.617e-05,, Time: 1.19
# lambda_u: 1.310e+01
# lambda_ut: 1.295e+00
# lambda_r: 6.592e+00
# Compute NTK...
# It: 19900, Loss: 3.563e-03, Loss_res: 3.507e-04,  Loss_bcs: 9.764e-05, Loss_ut_ics: 6.893e-05,, Time: 1.07
# lambda_u: 1.356e+01
# lambda_ut: 1.299e+00
# lambda_r: 6.383e+00
# Compute NTK...
# It: 20000, Loss: 1.527e-03, Loss_res: 8.117e-05,  Loss_bcs: 7.656e-05, Loss_ut_ics: 4.583e-05,, Time: 1.17
# lambda_u: 1.286e+01
# lambda_ut: 1.294e+00
# lambda_r: 6.692e+00
# Compute NTK...
# It: 20100, Loss: 5.547e-03, Loss_res: 9.450e-04,  Loss_bcs: 4.858e-05, Loss_ut_ics: 1.738e-05,, Time: 1.12
# lambda_u: 1.435e+01
# lambda_ut: 1.360e+00
# lambda_r: 5.132e+00
# Compute NTK...
# It: 20200, Loss: 2.018e-03, Loss_res: 1.556e-04,  Loss_bcs: 7.946e-05, Loss_ut_ics: 1.660e-05,, Time: 1.14
# lambda_u: 1.390e+01
# lambda_ut: 1.320e+00
# lambda_r: 5.871e+00
# Compute NTK...
# It: 20300, Loss: 1.520e-03, Loss_res: 6.423e-05,  Loss_bcs: 8.541e-05, Loss_ut_ics: 3.197e-05,, Time: 1.13
# lambda_u: 1.287e+01
# lambda_ut: 1.299e+00
# lambda_r: 6.563e+00
# Compute NTK...
# It: 20400, Loss: 6.126e-03, Loss_res: 6.606e-04,  Loss_bcs: 1.382e-04, Loss_ut_ics: 4.660e-05,, Time: 1.14
# lambda_u: 1.329e+01
# lambda_ut: 1.297e+00
# lambda_r: 6.491e+00
# Compute NTK...
# It: 20500, Loss: 1.139e-03, Loss_res: 1.261e-04,  Loss_bcs: 2.982e-05, Loss_ut_ics: 1.163e-05,, Time: 1.14
# lambda_u: 1.262e+01
# lambda_ut: 1.324e+00
# lambda_r: 6.045e+00
# Compute NTK...
# It: 20600, Loss: 2.095e-03, Loss_res: 2.237e-04,  Loss_bcs: 5.459e-05, Loss_ut_ics: 1.393e-05,, Time: 1.10
# lambda_u: 1.383e+01
# lambda_ut: 1.315e+00
# lambda_r: 5.989e+00
# Compute NTK...
# It: 20700, Loss: 4.210e-03, Loss_res: 3.372e-04,  Loss_bcs: 1.265e-04, Loss_ut_ics: 1.301e-05,, Time: 1.11
# lambda_u: 1.276e+01
# lambda_ut: 1.263e+00
# lambda_r: 7.699e+00
# Compute NTK...
# It: 20800, Loss: 5.562e-03, Loss_res: 6.059e-04,  Loss_bcs: 4.869e-05, Loss_ut_ics: 3.080e-05,, Time: 1.13
# lambda_u: 1.147e+01
# lambda_ut: 1.263e+00
# lambda_r: 8.258e+00
# Compute NTK...
# It: 20900, Loss: 8.659e-04, Loss_res: 6.606e-05,  Loss_bcs: 3.467e-05, Loss_ut_ics: 2.837e-05,, Time: 1.09
# lambda_u: 1.379e+01
# lambda_ut: 1.321e+00
# lambda_r: 5.872e+00
# Compute NTK...
# It: 21000, Loss: 7.815e-04, Loss_res: 8.283e-05,  Loss_bcs: 2.494e-05, Loss_ut_ics: 9.966e-06,, Time: 1.07
# lambda_u: 1.379e+01
# lambda_ut: 1.355e+00
# lambda_r: 5.285e+00
# Compute NTK...
# It: 21100, Loss: 3.461e-03, Loss_res: 2.360e-04,  Loss_bcs: 1.280e-04, Loss_ut_ics: 7.981e-05,, Time: 1.09
# lambda_u: 1.212e+01
# lambda_ut: 1.260e+00
# lambda_r: 8.091e+00
# Compute NTK...
# It: 21200, Loss: 1.767e-03, Loss_res: 1.864e-04,  Loss_bcs: 2.172e-05, Loss_ut_ics: 9.097e-06,, Time: 1.15
# lambda_u: 1.233e+01
# lambda_ut: 1.258e+00
# lambda_r: 8.044e+00
# Compute NTK...
# It: 21300, Loss: 3.329e-03, Loss_res: 3.701e-04,  Loss_bcs: 4.790e-05, Loss_ut_ics: 1.415e-05,, Time: 1.08
# lambda_u: 1.347e+01
# lambda_ut: 1.269e+00
# lambda_r: 7.251e+00
# Compute NTK...
# It: 21400, Loss: 1.807e-03, Loss_res: 1.660e-04,  Loss_bcs: 6.695e-05, Loss_ut_ics: 3.195e-05,, Time: 1.16
# lambda_u: 1.315e+01
# lambda_ut: 1.343e+00
# lambda_r: 5.584e+00
# Compute NTK...
# It: 21500, Loss: 1.621e-03, Loss_res: 2.131e-04,  Loss_bcs: 2.881e-05, Loss_ut_ics: 2.470e-05,, Time: 1.09
# lambda_u: 1.383e+01
# lambda_ut: 1.327e+00
# lambda_r: 5.739e+00
# Compute NTK...
# It: 21600, Loss: 9.015e-04, Loss_res: 8.301e-05,  Loss_bcs: 2.663e-05, Loss_ut_ics: 1.973e-05,, Time: 1.24
# lambda_u: 1.363e+01
# lambda_ut: 1.294e+00
# lambda_r: 6.487e+00
# Compute NTK...
# It: 21700, Loss: 5.709e-04, Loss_res: 6.878e-05,  Loss_bcs: 1.220e-05, Loss_ut_ics: 2.248e-06,, Time: 1.16
# lambda_u: 1.299e+01
# lambda_ut: 1.322e+00
# lambda_r: 5.997e+00
# Compute NTK...
# It: 21800, Loss: 2.669e-03, Loss_res: 2.476e-04,  Loss_bcs: 7.238e-05, Loss_ut_ics: 2.108e-05,, Time: 1.13
# lambda_u: 1.331e+01
# lambda_ut: 1.283e+00
# lambda_r: 6.891e+00
# Compute NTK...
# It: 21900, Loss: 2.515e-03, Loss_res: 2.850e-04,  Loss_bcs: 4.591e-05, Loss_ut_ics: 4.055e-05,, Time: 1.07
# lambda_u: 1.280e+01
# lambda_ut: 1.292e+00
# lambda_r: 6.762e+00
# Compute NTK...
# It: 22000, Loss: 3.518e-03, Loss_res: 3.179e-04,  Loss_bcs: 9.749e-05, Loss_ut_ics: 5.564e-05,, Time: 1.19
# lambda_u: 1.172e+01
# lambda_ut: 1.281e+00
# lambda_r: 7.471e+00
# Compute NTK...
# It: 22100, Loss: 1.017e-03, Loss_res: 1.345e-04,  Loss_bcs: 2.695e-05, Loss_ut_ics: 1.396e-05,, Time: 1.14
# lambda_u: 1.383e+01
# lambda_ut: 1.391e+00
# lambda_r: 4.794e+00
# Compute NTK...
# It: 22200, Loss: 1.833e-03, Loss_res: 1.395e-04,  Loss_bcs: 6.321e-05, Loss_ut_ics: 3.391e-05,, Time: 1.12
# lambda_u: 1.366e+01
# lambda_ut: 1.277e+00
# lambda_r: 6.953e+00
# Compute NTK...
# It: 22300, Loss: 1.619e-03, Loss_res: 1.776e-04,  Loss_bcs: 4.482e-05, Loss_ut_ics: 2.291e-05,, Time: 1.06
# lambda_u: 1.361e+01
# lambda_ut: 1.332e+00
# lambda_r: 5.681e+00
# Compute NTK...
# It: 22400, Loss: 6.327e-04, Loss_res: 7.161e-05,  Loss_bcs: 1.684e-05, Loss_ut_ics: 9.716e-06,, Time: 1.14
# lambda_u: 1.245e+01
# lambda_ut: 1.333e+00
# lambda_r: 5.908e+00
# Compute NTK...
# It: 22500, Loss: 6.913e-04, Loss_res: 4.970e-05,  Loss_bcs: 2.963e-05, Loss_ut_ics: 2.210e-05,, Time: 1.18
# lambda_u: 1.387e+01
# lambda_ut: 1.332e+00
# lambda_r: 5.643e+00
# Compute NTK...
# It: 22600, Loss: 7.940e-03, Loss_res: 8.011e-04,  Loss_bcs: 2.272e-04, Loss_ut_ics: 1.097e-04,, Time: 1.14
# lambda_u: 1.237e+01
# lambda_ut: 1.311e+00
# lambda_r: 6.403e+00
# Compute NTK...
# It: 22700, Loss: 1.301e-03, Loss_res: 2.020e-04,  Loss_bcs: 1.245e-05, Loss_ut_ics: 6.516e-06,, Time: 1.19
# lambda_u: 1.266e+01
# lambda_ut: 1.344e+00
# lambda_r: 5.659e+00
# Compute NTK...
# It: 22800, Loss: 9.780e-04, Loss_res: 7.656e-05,  Loss_bcs: 3.788e-05, Loss_ut_ics: 1.013e-05,, Time: 1.22
# lambda_u: 1.325e+01
# lambda_ut: 1.309e+00
# lambda_r: 6.220e+00
# Compute NTK...
# It: 22900, Loss: 1.005e-03, Loss_res: 9.054e-05,  Loss_bcs: 3.816e-05, Loss_ut_ics: 2.628e-05,, Time: 1.23
# lambda_u: 1.248e+01
# lambda_ut: 1.336e+00
# lambda_r: 5.839e+00
# Compute NTK...
# It: 23000, Loss: 6.747e-04, Loss_res: 5.061e-05,  Loss_bcs: 2.970e-05, Loss_ut_ics: 6.671e-06,, Time: 1.10
# lambda_u: 1.255e+01
# lambda_ut: 1.328e+00
# lambda_r: 5.968e+00
# Compute NTK...
# It: 23100, Loss: 1.172e-02, Loss_res: 9.230e-04,  Loss_bcs: 3.651e-04, Loss_ut_ics: 1.411e-04,, Time: 1.14
# lambda_u: 1.283e+01
# lambda_ut: 1.264e+00
# lambda_r: 7.620e+00
# Compute NTK...
# It: 23200, Loss: 5.557e-04, Loss_res: 8.000e-05,  Loss_bcs: 1.659e-05, Loss_ut_ics: 9.792e-06,, Time: 1.12
# lambda_u: 1.359e+01
# lambda_ut: 1.462e+00
# lambda_r: 4.129e+00
# Compute NTK...
# It: 23300, Loss: 5.139e-04, Loss_res: 4.492e-05,  Loss_bcs: 1.646e-05, Loss_ut_ics: 1.229e-05,, Time: 1.21
# lambda_u: 1.284e+01
# lambda_ut: 1.293e+00
# lambda_r: 6.736e+00
# Compute NTK...
# It: 23400, Loss: 1.332e-03, Loss_res: 1.594e-04,  Loss_bcs: 2.787e-05, Loss_ut_ics: 1.211e-05,, Time: 1.19
# lambda_u: 1.240e+01
# lambda_ut: 1.320e+00
# lambda_r: 6.186e+00
# Compute NTK...
# It: 23500, Loss: 6.701e-04, Loss_res: 8.255e-05,  Loss_bcs: 1.268e-05, Loss_ut_ics: 8.271e-06,, Time: 1.09
# lambda_u: 1.370e+01
# lambda_ut: 1.315e+00
# lambda_r: 6.012e+00
# Compute NTK...
# It: 23600, Loss: 8.219e-04, Loss_res: 1.054e-04,  Loss_bcs: 9.180e-06, Loss_ut_ics: 5.284e-06,, Time: 1.16
# lambda_u: 1.472e+01
# lambda_ut: 1.284e+00
# lambda_r: 6.515e+00
# Compute NTK...
# It: 23700, Loss: 1.117e-03, Loss_res: 1.184e-04,  Loss_bcs: 3.264e-05, Loss_ut_ics: 2.244e-05,, Time: 1.14
# lambda_u: 1.162e+01
# lambda_ut: 1.327e+00
# lambda_r: 6.231e+00
# Compute NTK...
# It: 23800, Loss: 4.774e-04, Loss_res: 5.781e-05,  Loss_bcs: 1.435e-05, Loss_ut_ics: 5.170e-06,, Time: 1.09
# lambda_u: 1.363e+01
# lambda_ut: 1.386e+00
# lambda_r: 4.874e+00
# Compute NTK...
# It: 23900, Loss: 5.875e-04, Loss_res: 7.524e-05,  Loss_bcs: 1.683e-05, Loss_ut_ics: 5.764e-06,, Time: 1.13
# lambda_u: 1.424e+01
# lambda_ut: 1.402e+00
# lambda_r: 4.622e+00
# Compute NTK...
# It: 24000, Loss: 8.022e-04, Loss_res: 1.013e-04,  Loss_bcs: 1.723e-05, Loss_ut_ics: 1.206e-05,, Time: 1.23
# lambda_u: 1.295e+01
# lambda_ut: 1.337e+00
# lambda_r: 5.715e+00
# Compute NTK...
# It: 24100, Loss: 1.337e-03, Loss_res: 1.123e-04,  Loss_bcs: 4.418e-05, Loss_ut_ics: 3.025e-05,, Time: 1.11
# lambda_u: 1.277e+01
# lambda_ut: 1.288e+00
# lambda_r: 6.878e+00
# Compute NTK...
# It: 24200, Loss: 1.016e-03, Loss_res: 1.114e-04,  Loss_bcs: 3.220e-05, Loss_ut_ics: 1.130e-05,, Time: 1.08
# lambda_u: 1.199e+01
# lambda_ut: 1.352e+00
# lambda_r: 5.651e+00
# Compute NTK...
# It: 24300, Loss: 1.086e-03, Loss_res: 6.962e-05,  Loss_bcs: 4.859e-05, Loss_ut_ics: 5.975e-06,, Time: 1.15
# lambda_u: 1.196e+01
# lambda_ut: 1.285e+00
# lambda_r: 7.243e+00
# Compute NTK...
# It: 24400, Loss: 1.779e-03, Loss_res: 1.627e-04,  Loss_bcs: 4.451e-05, Loss_ut_ics: 2.300e-05,, Time: 1.18
# lambda_u: 1.333e+01
# lambda_ut: 1.269e+00
# lambda_r: 7.292e+00
# Compute NTK...
# It: 24500, Loss: 2.584e-03, Loss_res: 2.037e-04,  Loss_bcs: 8.000e-05, Loss_ut_ics: 3.813e-05,, Time: 1.11
# lambda_u: 1.259e+01
# lambda_ut: 1.264e+00
# lambda_r: 7.743e+00
# Compute NTK...
# It: 24600, Loss: 2.499e-04, Loss_res: 3.725e-05,  Loss_bcs: 4.256e-06, Loss_ut_ics: 3.464e-06,, Time: 1.13
# lambda_u: 1.346e+01
# lambda_ut: 1.366e+00
# lambda_r: 5.170e+00
# Compute NTK...
# It: 24700, Loss: 1.646e-03, Loss_res: 7.928e-05,  Loss_bcs: 8.865e-05, Loss_ut_ics: 3.694e-06,, Time: 1.13
# lambda_u: 1.204e+01
# lambda_ut: 1.282e+00
# lambda_r: 7.298e+00
# Compute NTK...
# It: 24800, Loss: 3.070e-04, Loss_res: 2.482e-05,  Loss_bcs: 1.061e-05, Loss_ut_ics: 8.568e-06,, Time: 1.16
# lambda_u: 1.170e+01
# lambda_ut: 1.284e+00
# lambda_r: 7.367e+00
# Compute NTK...
# It: 24900, Loss: 7.208e-04, Loss_res: 7.391e-05,  Loss_bcs: 2.117e-05, Loss_ut_ics: 1.831e-05,, Time: 1.10
# lambda_u: 1.349e+01
# lambda_ut: 1.323e+00
# lambda_r: 5.887e+00
# Compute NTK...
# It: 25000, Loss: 1.143e-03, Loss_res: 1.042e-04,  Loss_bcs: 3.187e-05, Loss_ut_ics: 1.798e-05,, Time: 1.17
# lambda_u: 1.255e+01
# lambda_ut: 1.282e+00
# lambda_r: 7.126e+00
# Compute NTK...
# It: 25100, Loss: 8.023e-04, Loss_res: 1.921e-05,  Loss_bcs: 5.337e-05, Loss_ut_ics: 1.620e-05,, Time: 1.16
# lambda_u: 1.268e+01
# lambda_ut: 1.301e+00
# lambda_r: 6.554e+00
# Compute NTK...
# It: 25200, Loss: 6.823e-04, Loss_res: 7.572e-05,  Loss_bcs: 1.505e-05, Loss_ut_ics: 1.357e-05,, Time: 1.16
# lambda_u: 1.252e+01
# lambda_ut: 1.304e+00
# lambda_r: 6.521e+00
# Compute NTK...
# It: 25300, Loss: 7.293e-04, Loss_res: 2.675e-05,  Loss_bcs: 4.721e-05, Loss_ut_ics: 4.565e-05,, Time: 1.10
# lambda_u: 1.283e+01
# lambda_ut: 1.417e+00
# lambda_r: 4.623e+00
# Compute NTK...
# It: 25400, Loss: 6.898e-04, Loss_res: 7.359e-05,  Loss_bcs: 2.077e-05, Loss_ut_ics: 2.304e-06,, Time: 1.10
# lambda_u: 1.282e+01
# lambda_ut: 1.336e+00
# lambda_r: 5.755e+00
# Compute NTK...
# It: 25500, Loss: 1.048e-03, Loss_res: 9.309e-05,  Loss_bcs: 3.219e-05, Loss_ut_ics: 2.637e-05,, Time: 1.14
# lambda_u: 1.367e+01
# lambda_ut: 1.292e+00
# lambda_r: 6.531e+00
# Compute NTK...
# It: 25600, Loss: 8.873e-04, Loss_res: 1.264e-04,  Loss_bcs: 8.526e-06, Loss_ut_ics: 6.331e-06,, Time: 1.17
# lambda_u: 1.354e+01
# lambda_ut: 1.312e+00
# lambda_r: 6.106e+00
# Compute NTK...
# It: 25700, Loss: 5.911e-04, Loss_res: 4.960e-05,  Loss_bcs: 2.320e-05, Loss_ut_ics: 1.708e-05,, Time: 1.18
# lambda_u: 1.305e+01
# lambda_ut: 1.331e+00
# lambda_r: 5.816e+00
# Compute NTK...
# It: 25800, Loss: 7.156e-04, Loss_res: 8.412e-05,  Loss_bcs: 1.626e-05, Loss_ut_ics: 2.115e-06,, Time: 1.22
# lambda_u: 1.246e+01
# lambda_ut: 1.323e+00
# lambda_r: 6.098e+00
# Compute NTK...
# It: 25900, Loss: 1.130e-03, Loss_res: 5.892e-05,  Loss_bcs: 6.437e-05, Loss_ut_ics: 4.111e-05,, Time: 1.13
# lambda_u: 1.280e+01
# lambda_ut: 1.371e+00
# lambda_r: 5.190e+00
# Compute NTK...
# It: 26000, Loss: 5.655e-04, Loss_res: 6.268e-05,  Loss_bcs: 1.288e-05, Loss_ut_ics: 3.475e-06,, Time: 1.10
# lambda_u: 1.274e+01
# lambda_ut: 1.307e+00
# lambda_r: 6.405e+00
# Compute NTK...
# It: 26100, Loss: 4.119e-04, Loss_res: 5.615e-05,  Loss_bcs: 1.368e-05, Loss_ut_ics: 6.959e-06,, Time: 1.12
# lambda_u: 1.460e+01
# lambda_ut: 1.500e+00
# lambda_r: 3.779e+00
# Compute NTK...
# It: 26200, Loss: 6.953e-03, Loss_res: 5.677e-04,  Loss_bcs: 2.005e-04, Loss_ut_ics: 8.183e-05,, Time: 1.20
# lambda_u: 1.217e+01
# lambda_ut: 1.263e+00
# lambda_r: 7.949e+00
# Compute NTK...
# It: 26300, Loss: 2.064e-03, Loss_res: 1.867e-04,  Loss_bcs: 4.404e-05, Loss_ut_ics: 6.809e-06,, Time: 1.13
# lambda_u: 1.343e+01
# lambda_ut: 1.252e+00
# lambda_r: 7.888e+00
# Compute NTK...
# It: 26400, Loss: 1.531e-03, Loss_res: 1.229e-04,  Loss_bcs: 6.134e-05, Loss_ut_ics: 3.735e-05,, Time: 1.05
# lambda_u: 1.184e+01
# lambda_ut: 1.311e+00
# lambda_r: 6.545e+00
# Compute NTK...
# It: 26500, Loss: 3.287e-04, Loss_res: 3.038e-05,  Loss_bcs: 1.105e-05, Loss_ut_ics: 4.089e-06,, Time: 1.15
# lambda_u: 1.341e+01
# lambda_ut: 1.321e+00
# lambda_r: 5.943e+00
# Compute NTK...
# It: 26600, Loss: 5.699e-04, Loss_res: 6.388e-05,  Loss_bcs: 1.400e-05, Loss_ut_ics: 8.281e-06,, Time: 1.24
# lambda_u: 1.406e+01
# lambda_ut: 1.320e+00
# lambda_r: 5.842e+00
# Compute NTK...
# It: 26700, Loss: 4.178e-04, Loss_res: 3.584e-05,  Loss_bcs: 1.602e-05, Loss_ut_ics: 7.130e-06,, Time: 1.20
# lambda_u: 1.298e+01
# lambda_ut: 1.330e+00
# lambda_r: 5.855e+00
# Compute NTK...
# It: 26800, Loss: 3.262e-04, Loss_res: 2.394e-05,  Loss_bcs: 1.296e-05, Loss_ut_ics: 4.076e-06,, Time: 1.19
# lambda_u: 1.442e+01
# lambda_ut: 1.318e+00
# lambda_r: 5.821e+00
# Compute NTK...
# It: 26900, Loss: 6.279e-04, Loss_res: 5.043e-05,  Loss_bcs: 2.432e-05, Loss_ut_ics: 2.925e-06,, Time: 1.11
# lambda_u: 1.245e+01
# lambda_ut: 1.308e+00
# lambda_r: 6.446e+00
# Compute NTK...

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
R_star = r(X_star, a, c)

# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))
# Out:
# Relative L2 error_u: 9.198683e-03

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
R_star = griddata(X_star, R_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, R_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(R_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
