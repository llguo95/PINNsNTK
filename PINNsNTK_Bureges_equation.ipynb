# %%
# Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)+np.array([0.001,0])
        y = self.func(x)
       
        
        return x,y

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c,a, kernel_size):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        self.a = tf.constant(a, dtype=tf.float32)
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        

        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        
        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.a,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def train(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # Store losses
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)
                self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %
                      (it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))

                start_time = timeit.default_timer()
            
          
            if log_NTK:
                if it % 100 == 0:
                        print("Compute NTK...")
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) + \
                                       np.trace(K_r_value)

                        # Store NTK matrices
                        self.K_u_log.append(K_u_value)
                        self.K_ut_log.append(K_ut_value)
                        self.K_r_log.append(K_r_value)
                        
                        if update_lam:

                          self.lam_u_val = trace_K / np.trace(K_u_value)
                          self.lam_ut_val = trace_K /np.trace(K_ut_value)
                          self.lam_r_val = trace_K / np.trace(K_r_value)

                          # Store NTK weights
                          self.lam_u_log.append(self.lam_u_val)
                          self.lam_ut_log.append(self.lam_ut_val)
                          self.lam_r_log.append(self.lam_r_val)
                        
                        
          
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %% [markdown]
# we test its performance on an non-linear partial derivitive
# $\frac{\partial u}{\partial t} \frac{\partial^2 u}{\partial t^2} + u \frac{\partial u}{\partial x} = 0$

# %%
def u(x, a, c):
    # Define the solution to the Burger's equation
    t = x[:, 0:1]
    x = x[:, 1:2]
    
    
    return np.sin(x + t)




def r(X, a, c):

    t = X[:, 0:1]
    x = X[:, 1:2]
    
    u = np.sin(x + t)
    
    # Calculate first derivative with respect to x
    u_x =  np.cos(x + t)
    u_xx = -np.sin(x + t)
    # Calculate second derivative with respect to x
    u_t = np.cos(x + t)
    u_tt = -np.sin(x + t)
    
    # Calculate first derivative with respect to t
    #u_t = ((x - t) / (t * sqrt_term)) + (sqrt_term - 1) / (2 * t**2)
    
    # Calculate second derivative with respect to t
    #u_tt=  -2 * (x - t) / (t**2 * sqrt_term) - 3 * (sqrt_term - 1) / (2 * t**3)

    return u_t*u_tt+u*u_x
    #return u_t-u_x


def operator(u, t, x, a, c, sigma_t=1.0, sigma_x=1.0):
    # gradient
    
 
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x

    residual = u_t*u_tt+u*u_x
    return residual
    #return u_t-u_x

# %%
# Domain boundaries
ics_coords = np.array([[0.0, 0.0],
                        [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],
                        [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],
                        [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')

# %%
# Define PINN model
a = 0.5
c = 3

layers = [2, 500, 500, 500, 1]
kernel_size = 30
model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c,a, kernel_size)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
### Train model
itertaions = 20000
log_NTK = True # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK 

model.train(nIter=itertaions, batch_size=kernel_size, log_NTK=log_NTK, update_lam=update_lam)
# Out:
# It: 0, Loss: 1.010e-01, Loss_res: 1.672e-02,  Loss_bcs: 2.537e-02, Loss_ut_ics: 9.619e-05,, Time: 0.02
# lambda_u: 2.704e+00
# lambda_ut: 1.031e+01
# lambda_r: 1.875e+00
# Compute NTK...
# It: 100, Loss: 1.630e-01, Loss_res: 1.898e-02,  Loss_bcs: 4.262e-02, Loss_ut_ics: 1.269e-03,, Time: 1.32
# lambda_u: 2.706e+00
# lambda_ut: 8.039e+00
# lambda_r: 1.976e+00
# Compute NTK...
# It: 200, Loss: 1.643e-01, Loss_res: 1.483e-02,  Loss_bcs: 4.475e-02, Loss_ut_ics: 1.257e-03,, Time: 1.19
# lambda_u: 2.729e+00
# lambda_ut: 4.354e+00
# lambda_r: 2.476e+00
# Compute NTK...
# It: 300, Loss: 1.558e-01, Loss_res: 2.114e-02,  Loss_bcs: 3.792e-02, Loss_ut_ics: 2.550e-03,, Time: 1.08
# lambda_u: 2.138e+00
# lambda_ut: 1.022e+01
# lambda_r: 2.302e+00
# Compute NTK...
# It: 400, Loss: 1.780e-01, Loss_res: 2.155e-02,  Loss_bcs: 6.057e-02, Loss_ut_ics: 5.770e-04,, Time: 1.12
# lambda_u: 1.943e+00
# lambda_ut: 1.271e+01
# lambda_r: 2.458e+00
# Compute NTK...
# It: 500, Loss: 2.756e-01, Loss_res: 2.702e-02,  Loss_bcs: 8.332e-02, Loss_ut_ics: 4.210e-04,, Time: 1.11
# lambda_u: 2.648e+00
# lambda_ut: 1.592e+01
# lambda_r: 1.787e+00
# Compute NTK...
# It: 600, Loss: 8.861e-02, Loss_res: 1.751e-02,  Loss_bcs: 2.001e-02, Loss_ut_ics: 1.102e-04,, Time: 1.12
# lambda_u: 2.801e+00
# lambda_ut: 1.229e+01
# lambda_r: 1.780e+00
# Compute NTK...
# It: 700, Loss: 9.272e-02, Loss_res: 3.402e-02,  Loss_bcs: 9.583e-03, Loss_ut_ics: 8.778e-05,, Time: 1.23
# lambda_u: 2.505e+00
# lambda_ut: 1.008e+01
# lambda_r: 1.993e+00
# Compute NTK...
# It: 800, Loss: 1.096e-01, Loss_res: 3.711e-02,  Loss_bcs: 1.619e-02, Loss_ut_ics: 6.451e-05,, Time: 1.20
# lambda_u: 2.820e+00
# lambda_ut: 1.863e+01
# lambda_r: 1.690e+00
# Compute NTK...
# It: 900, Loss: 9.450e-02, Loss_res: 2.693e-02,  Loss_bcs: 1.437e-02, Loss_ut_ics: 2.350e-04,, Time: 1.31
# lambda_u: 3.311e+00
# lambda_ut: 1.108e+01
# lambda_r: 1.646e+00
# Compute NTK...
# It: 1000, Loss: 1.340e-01, Loss_res: 2.360e-02,  Loss_bcs: 3.320e-02, Loss_ut_ics: 2.891e-04,, Time: 1.35
# lambda_u: 2.576e+00
# lambda_ut: 1.111e+01
# lambda_r: 1.917e+00
# Compute NTK...
# It: 1100, Loss: 9.698e-02, Loss_res: 2.803e-02,  Loss_bcs: 1.785e-02, Loss_ut_ics: 3.029e-05,, Time: 1.49
# lambda_u: 2.243e+00
# lambda_ut: 1.746e+01
# lambda_r: 2.013e+00
# Compute NTK...
# It: 1200, Loss: 8.146e-02, Loss_res: 1.131e-02,  Loss_bcs: 2.529e-02, Loss_ut_ics: 2.411e-04,, Time: 1.29
# lambda_u: 2.098e+00
# lambda_ut: 1.384e+01
# lambda_r: 2.217e+00
# Compute NTK...
# It: 1300, Loss: 1.346e-01, Loss_res: 3.687e-02,  Loss_bcs: 2.402e-02, Loss_ut_ics: 1.323e-04,, Time: 1.37
# lambda_u: 2.870e+00
# lambda_ut: 1.342e+01
# lambda_r: 1.733e+00
# Compute NTK...
# It: 1400, Loss: 1.559e-01, Loss_res: 2.338e-02,  Loss_bcs: 4.266e-02, Loss_ut_ics: 1.598e-04,, Time: 1.33
# lambda_u: 2.428e+00
# lambda_ut: 7.657e+00
# lambda_r: 2.185e+00
# Compute NTK...
# It: 1500, Loss: 1.608e-01, Loss_res: 3.606e-02,  Loss_bcs: 3.335e-02, Loss_ut_ics: 5.483e-05,, Time: 1.41
# lambda_u: 2.991e+00
# lambda_ut: 1.484e+01
# lambda_r: 1.672e+00
# Compute NTK...
# It: 1600, Loss: 2.373e-01, Loss_res: 1.218e-01,  Loss_bcs: 1.460e-02, Loss_ut_ics: 2.013e-04,, Time: 1.41
# lambda_u: 4.826e+00
# lambda_ut: 2.528e+01
# lambda_r: 1.328e+00
# Compute NTK...
# It: 1700, Loss: 1.255e-01, Loss_res: 4.068e-02,  Loss_bcs: 1.036e-02, Loss_ut_ics: 1.121e-03,, Time: 1.43
# lambda_u: 4.689e+00
# lambda_ut: 1.919e+01
# lambda_r: 1.361e+00
# Compute NTK...
# It: 1800, Loss: 8.804e-02, Loss_res: 2.838e-02,  Loss_bcs: 1.120e-02, Loss_ut_ics: 2.061e-04,, Time: 1.32
# lambda_u: 3.817e+00
# lambda_ut: 1.816e+01
# lambda_r: 1.464e+00
# Compute NTK...
# It: 1900, Loss: 5.244e-01, Loss_res: 2.771e-02,  Loss_bcs: 1.425e-01, Loss_ut_ics: 1.617e-03,, Time: 1.37
# lambda_u: 3.230e+00
# lambda_ut: 1.138e+01
# lambda_r: 1.660e+00
# Compute NTK...
# It: 2000, Loss: 1.581e-01, Loss_res: 3.663e-02,  Loss_bcs: 1.651e-02, Loss_ut_ics: 2.101e-03,, Time: 1.21
# lambda_u: 4.015e+00
# lambda_ut: 1.869e+01
# lambda_r: 1.434e+00
# Compute NTK...
# It: 2100, Loss: 1.868e-01, Loss_res: 3.826e-02,  Loss_bcs: 2.812e-02, Loss_ut_ics: 8.934e-04,, Time: 1.23
# lambda_u: 3.801e+00
# lambda_ut: 2.846e+01
# lambda_r: 1.425e+00
# Compute NTK...
# It: 2200, Loss: 1.819e-01, Loss_res: 2.700e-02,  Loss_bcs: 3.978e-02, Loss_ut_ics: 5.257e-04,, Time: 1.22
# lambda_u: 3.282e+00
# lambda_ut: 1.702e+01
# lambda_r: 1.571e+00
# Compute NTK...
# It: 2300, Loss: 8.042e-02, Loss_res: 1.412e-02,  Loss_bcs: 2.086e-02, Loss_ut_ics: 3.026e-04,, Time: 1.41
# lambda_u: 2.241e+00
# lambda_ut: 1.179e+01
# lambda_r: 2.132e+00
# Compute NTK...
# It: 2400, Loss: 1.336e-01, Loss_res: 3.650e-02,  Loss_bcs: 2.565e-02, Loss_ut_ics: 6.243e-05,, Time: 1.46
# lambda_u: 2.569e+00
# lambda_ut: 1.574e+01
# lambda_r: 1.827e+00
# Compute NTK...
# It: 2500, Loss: 2.128e-01, Loss_res: 3.215e-02,  Loss_bcs: 5.009e-02, Loss_ut_ics: 1.797e-04,, Time: 1.40
# lambda_u: 3.165e+00
# lambda_ut: 2.015e+01
# lambda_r: 1.576e+00
# Compute NTK...
# It: 2600, Loss: 1.942e-01, Loss_res: 7.854e-02,  Loss_bcs: 1.941e-02, Loss_ut_ics: 2.858e-04,, Time: 1.24
# lambda_u: 2.963e+00
# lambda_ut: 1.424e+01
# lambda_r: 1.688e+00
# Compute NTK...
# It: 2700, Loss: 1.328e-01, Loss_res: 3.727e-02,  Loss_bcs: 1.531e-02, Loss_ut_ics: 6.396e-04,, Time: 1.27
# lambda_u: 4.382e+00
# lambda_ut: 2.261e+01
# lambda_r: 1.374e+00
# Compute NTK...
# It: 2800, Loss: 1.112e-01, Loss_res: 2.421e-02,  Loss_bcs: 2.423e-02, Loss_ut_ics: 7.971e-05,, Time: 1.29
# lambda_u: 2.584e+00
# lambda_ut: 9.302e+00
# lambda_r: 1.978e+00
# Compute NTK...
# It: 2900, Loss: 1.512e-01, Loss_res: 2.794e-02,  Loss_bcs: 3.248e-02, Loss_ut_ics: 4.711e-04,, Time: 1.28
# lambda_u: 2.966e+00
# lambda_ut: 1.933e+01
# lambda_r: 1.636e+00
# Compute NTK...
# It: 3000, Loss: 2.417e-01, Loss_res: 3.113e-02,  Loss_bcs: 6.947e-02, Loss_ut_ics: 1.765e-04,, Time: 1.23
# lambda_u: 2.613e+00
# lambda_ut: 1.248e+01
# lambda_r: 1.862e+00
# Compute NTK...
# It: 3100, Loss: 1.891e-01, Loss_res: 3.256e-02,  Loss_bcs: 4.914e-02, Loss_ut_ics: 1.286e-04,, Time: 1.28
# lambda_u: 2.645e+00
# lambda_ut: 2.569e+01
# lambda_r: 1.715e+00
# Compute NTK...
# It: 3200, Loss: 1.426e-01, Loss_res: 1.829e-02,  Loss_bcs: 3.853e-02, Loss_ut_ics: 2.458e-04,, Time: 1.38
# lambda_u: 2.740e+00
# lambda_ut: 9.226e+00
# lambda_r: 1.899e+00
# Compute NTK...
# It: 3300, Loss: 1.373e-01, Loss_res: 2.547e-02,  Loss_bcs: 3.360e-02, Loss_ut_ics: 2.011e-05,, Time: 1.34
# lambda_u: 2.795e+00
# lambda_ut: 2.021e+01
# lambda_r: 1.687e+00
# Compute NTK...
# It: 3400, Loss: 7.852e-02, Loss_res: 2.026e-02,  Loss_bcs: 1.439e-02, Loss_ut_ics: 2.477e-05,, Time: 1.39
# lambda_u: 2.348e+00
# lambda_ut: 8.398e+00
# lambda_r: 2.198e+00
# Compute NTK...
# It: 3500, Loss: 2.012e-01, Loss_res: 3.040e-02,  Loss_bcs: 4.801e-02, Loss_ut_ics: 9.251e-04,, Time: 1.39
# lambda_u: 2.841e+00
# lambda_ut: 1.171e+01
# lambda_r: 1.778e+00
# Compute NTK...
# It: 3600, Loss: 1.243e-01, Loss_res: 4.066e-02,  Loss_bcs: 1.643e-02, Loss_ut_ics: 1.390e-04,, Time: 1.39
# lambda_u: 3.596e+00
# lambda_ut: 1.214e+01
# lambda_r: 1.563e+00
# Compute NTK...
# It: 3700, Loss: 1.577e-01, Loss_res: 2.146e-02,  Loss_bcs: 3.743e-02, Loss_ut_ics: 3.648e-04,, Time: 1.25
# lambda_u: 3.136e+00
# lambda_ut: 1.152e+01
# lambda_r: 1.683e+00
# Compute NTK...
# It: 3800, Loss: 7.070e-02, Loss_res: 2.695e-02,  Loss_bcs: 6.116e-03, Loss_ut_ics: 4.378e-04,, Time: 1.31
# lambda_u: 4.007e+00
# lambda_ut: 1.609e+01
# lambda_r: 1.453e+00
# Compute NTK...
# It: 3900, Loss: 1.083e-01, Loss_res: 1.615e-02,  Loss_bcs: 2.760e-02, Loss_ut_ics: 1.541e-04,, Time: 1.30
# lambda_u: 2.834e+00
# lambda_ut: 1.721e+01
# lambda_r: 1.698e+00
# Compute NTK...
# It: 4000, Loss: 2.931e-01, Loss_res: 1.682e-02,  Loss_bcs: 8.689e-02, Loss_ut_ics: 3.180e-04,, Time: 1.38
# lambda_u: 2.997e+00
# lambda_ut: 1.353e+01
# lambda_r: 1.688e+00
# Compute NTK...
# It: 4100, Loss: 6.417e-02, Loss_res: 2.146e-02,  Loss_bcs: 8.606e-03, Loss_ut_ics: 4.025e-05,, Time: 1.34
# lambda_u: 3.548e+00
# lambda_ut: 1.457e+01
# lambda_r: 1.540e+00
# Compute NTK...
# It: 4200, Loss: 8.329e-02, Loss_res: 2.103e-02,  Loss_bcs: 1.668e-02, Loss_ut_ics: 9.548e-05,, Time: 1.32
# lambda_u: 2.721e+00
# lambda_ut: 2.689e+01
# lambda_r: 1.680e+00
# Compute NTK...
# It: 4300, Loss: 1.052e-01, Loss_res: 2.255e-02,  Loss_bcs: 2.471e-02, Loss_ut_ics: 2.917e-05,, Time: 1.23
# lambda_u: 2.579e+00
# lambda_ut: 1.612e+01
# lambda_r: 1.817e+00
# Compute NTK...
# It: 4400, Loss: 1.258e-01, Loss_res: 2.961e-02,  Loss_bcs: 2.688e-02, Loss_ut_ics: 7.670e-05,, Time: 1.25
# lambda_u: 2.395e+00
# lambda_ut: 1.065e+01
# lambda_r: 2.047e+00
# Compute NTK...
# It: 4500, Loss: 1.687e-01, Loss_res: 4.443e-02,  Loss_bcs: 3.027e-02, Loss_ut_ics: 2.872e-04,, Time: 1.33
# lambda_u: 2.881e+00
# lambda_ut: 1.200e+01
# lambda_r: 1.756e+00
# Compute NTK...
# It: 4600, Loss: 1.067e-01, Loss_res: 2.359e-02,  Loss_bcs: 2.228e-02, Loss_ut_ics: 3.054e-05,, Time: 1.32
# lambda_u: 2.922e+00
# lambda_ut: 1.161e+01
# lambda_r: 1.749e+00
# Compute NTK...
# It: 4700, Loss: 1.242e-01, Loss_res: 3.250e-02,  Loss_bcs: 2.203e-02, Loss_ut_ics: 1.057e-04,, Time: 1.20
# lambda_u: 3.231e+00
# lambda_ut: 1.854e+01
# lambda_r: 1.571e+00
# Compute NTK...
# It: 4800, Loss: 3.001e-01, Loss_res: 6.308e-02,  Loss_bcs: 5.137e-02, Loss_ut_ics: 1.844e-04,, Time: 1.26
# lambda_u: 3.993e+00
# lambda_ut: 1.555e+01
# lambda_r: 1.459e+00
# Compute NTK...
# It: 4900, Loss: 3.567e-01, Loss_res: 3.034e-02,  Loss_bcs: 8.643e-02, Loss_ut_ics: 1.285e-04,, Time: 1.33
# lambda_u: 3.574e+00
# lambda_ut: 2.514e+01
# lambda_r: 1.470e+00
# Compute NTK...
# It: 5000, Loss: 3.249e-01, Loss_res: 3.548e-02,  Loss_bcs: 7.617e-02, Loss_ut_ics: 6.649e-04,, Time: 1.39
# lambda_u: 3.401e+00
# lambda_ut: 1.625e+01
# lambda_r: 1.552e+00
# Compute NTK...
# It: 5100, Loss: 1.077e-01, Loss_res: 2.893e-02,  Loss_bcs: 1.496e-02, Loss_ut_ics: 1.387e-04,, Time: 1.26
# lambda_u: 4.320e+00
# lambda_ut: 2.150e+01
# lambda_r: 1.385e+00
# Compute NTK...
# It: 5200, Loss: 9.531e-02, Loss_res: 2.463e-02,  Loss_bcs: 1.225e-02, Loss_ut_ics: 9.542e-04,, Time: 1.38
# lambda_u: 3.358e+00
# lambda_ut: 1.656e+01
# lambda_r: 1.558e+00
# Compute NTK...
# It: 5300, Loss: 1.606e-01, Loss_res: 5.352e-02,  Loss_bcs: 1.700e-02, Loss_ut_ics: 4.502e-04,, Time: 1.26
# lambda_u: 4.289e+00
# lambda_ut: 3.334e+01
# lambda_r: 1.357e+00
# Compute NTK...
# It: 5400, Loss: 5.916e-02, Loss_res: 2.182e-02,  Loss_bcs: 6.621e-03, Loss_ut_ics: 1.376e-04,, Time: 1.28
# lambda_u: 3.624e+00
# lambda_ut: 2.157e+01
# lambda_r: 1.476e+00
# Compute NTK...
# It: 5500, Loss: 2.343e-01, Loss_res: 1.601e-02,  Loss_bcs: 7.061e-02, Loss_ut_ics: 1.031e-03,, Time: 1.19
# lambda_u: 2.756e+00
# lambda_ut: 8.909e+00
# lambda_r: 1.905e+00
# Compute NTK...
# It: 5600, Loss: 1.811e-01, Loss_res: 2.292e-02,  Loss_bcs: 5.610e-02, Loss_ut_ics: 1.603e-04,, Time: 1.22
# lambda_u: 2.391e+00
# lambda_ut: 1.457e+01
# lambda_r: 1.949e+00
# Compute NTK...
# It: 5700, Loss: 2.127e-01, Loss_res: 2.223e-02,  Loss_bcs: 6.398e-02, Loss_ut_ics: 3.095e-04,, Time: 1.20
# lambda_u: 2.616e+00
# lambda_ut: 1.181e+01
# lambda_r: 1.876e+00
# Compute NTK...
# It: 5800, Loss: 1.765e-01, Loss_res: 1.061e-02,  Loss_bcs: 6.521e-02, Loss_ut_ics: 8.448e-04,, Time: 1.22
# lambda_u: 2.219e+00
# lambda_ut: 7.954e+00
# lambda_r: 2.360e+00
# Compute NTK...
# It: 5900, Loss: 1.590e-01, Loss_res: 4.154e-02,  Loss_bcs: 2.805e-02, Loss_ut_ics: 2.894e-04,, Time: 1.20
# lambda_u: 2.028e+00
# lambda_ut: 1.156e+01
# lambda_r: 2.379e+00
# Compute NTK...
# It: 6000, Loss: 8.636e-02, Loss_res: 3.412e-02,  Loss_bcs: 8.656e-03, Loss_ut_ics: 2.158e-04,, Time: 1.22
# lambda_u: 3.430e+00
# lambda_ut: 1.359e+01
# lambda_r: 1.575e+00
# Compute NTK...
# It: 6100, Loss: 2.469e-01, Loss_res: 3.572e-02,  Loss_bcs: 6.015e-02, Loss_ut_ics: 1.983e-04,, Time: 1.21
# lambda_u: 3.034e+00
# lambda_ut: 1.031e+01
# lambda_r: 1.744e+00
# Compute NTK...
# It: 6200, Loss: 8.053e-02, Loss_res: 2.131e-02,  Loss_bcs: 1.495e-02, Loss_ut_ics: 2.218e-04,, Time: 1.20
# lambda_u: 2.388e+00
# lambda_ut: 1.438e+01
# lambda_r: 1.954e+00
# Compute NTK...
# It: 6300, Loss: 9.090e-02, Loss_res: 2.997e-02,  Loss_bcs: 1.307e-02, Loss_ut_ics: 3.396e-05,, Time: 1.25
# lambda_u: 2.522e+00
# lambda_ut: 1.214e+01
# lambda_r: 1.919e+00
# Compute NTK...
# It: 6400, Loss: 3.859e-01, Loss_res: 3.764e-02,  Loss_bcs: 7.363e-02, Loss_ut_ics: 1.297e-03,, Time: 1.22
# lambda_u: 4.259e+00
# lambda_ut: 1.395e+01
# lambda_r: 1.442e+00
# Compute NTK...
# It: 6500, Loss: 1.635e-01, Loss_res: 3.276e-02,  Loss_bcs: 2.137e-02, Loss_ut_ics: 5.301e-04,, Time: 1.25
# lambda_u: 5.062e+00
# lambda_ut: 2.293e+01
# lambda_r: 1.318e+00
# Compute NTK...
# It: 6600, Loss: 1.781e-01, Loss_res: 3.377e-02,  Loss_bcs: 4.021e-02, Loss_ut_ics: 2.643e-04,, Time: 1.21
# lambda_u: 2.809e+00
# lambda_ut: 9.486e+00
# lambda_r: 1.857e+00
# Compute NTK...
# It: 6700, Loss: 1.761e-01, Loss_res: 4.184e-02,  Loss_bcs: 3.190e-02, Loss_ut_ics: 1.834e-04,, Time: 1.20
# lambda_u: 3.102e+00
# lambda_ut: 8.019e+00
# lambda_r: 1.809e+00
# Compute NTK...
# It: 6800, Loss: 2.381e-01, Loss_res: 2.824e-02,  Loss_bcs: 6.113e-02, Loss_ut_ics: 4.116e-04,, Time: 1.27
# lambda_u: 2.999e+00
# lambda_ut: 8.803e+00
# lambda_r: 1.808e+00
# Compute NTK...
# It: 6900, Loss: 1.797e-01, Loss_res: 5.418e-02,  Loss_bcs: 2.835e-02, Loss_ut_ics: 5.586e-05,, Time: 1.19
# lambda_u: 3.345e+00
# lambda_ut: 1.811e+01
# lambda_r: 1.548e+00
# Compute NTK...
# It: 7000, Loss: 2.682e-01, Loss_res: 2.725e-02,  Loss_bcs: 6.439e-02, Loss_ut_ics: 1.349e-04,, Time: 1.17
# lambda_u: 3.483e+00
# lambda_ut: 1.829e+01
# lambda_r: 1.519e+00
# Compute NTK...
# It: 7100, Loss: 1.589e-01, Loss_res: 2.593e-02,  Loss_bcs: 3.761e-02, Loss_ut_ics: 9.002e-04,, Time: 1.20
# lambda_u: 2.672e+00
# lambda_ut: 1.101e+01
# lambda_r: 1.870e+00
# Compute NTK...
# It: 7200, Loss: 1.137e-01, Loss_res: 2.066e-02,  Loss_bcs: 2.727e-02, Loss_ut_ics: 7.819e-05,, Time: 1.24
# lambda_u: 2.794e+00
# lambda_ut: 1.336e+01
# lambda_r: 1.763e+00
# Compute NTK...
# It: 7300, Loss: 1.065e-01, Loss_res: 3.444e-02,  Loss_bcs: 1.356e-02, Loss_ut_ics: 2.186e-05,, Time: 1.25
# lambda_u: 4.093e+00
# lambda_ut: 1.307e+01
# lambda_r: 1.472e+00
# Compute NTK...
# It: 7400, Loss: 1.037e-01, Loss_res: 3.732e-02,  Loss_bcs: 1.423e-02, Loss_ut_ics: 1.669e-05,, Time: 1.25
# lambda_u: 3.012e+00
# lambda_ut: 1.953e+01
# lambda_r: 1.621e+00
# Compute NTK...
# It: 7500, Loss: 1.318e-01, Loss_res: 1.919e-02,  Loss_bcs: 2.808e-02, Loss_ut_ics: 6.270e-05,, Time: 1.24
# lambda_u: 3.581e+00
# lambda_ut: 1.073e+01
# lambda_r: 1.593e+00
# Compute NTK...
# It: 7600, Loss: 1.048e-01, Loss_res: 1.810e-02,  Loss_bcs: 2.748e-02, Loss_ut_ics: 2.453e-04,, Time: 1.12
# lambda_u: 2.128e+00
# lambda_ut: 8.196e+00
# lambda_r: 2.451e+00
# Compute NTK...
# It: 7700, Loss: 1.848e-01, Loss_res: 2.091e-02,  Loss_bcs: 5.606e-02, Loss_ut_ics: 8.234e-04,, Time: 1.21
# lambda_u: 2.357e+00
# lambda_ut: 1.309e+01
# lambda_r: 2.003e+00
# Compute NTK...
# It: 7800, Loss: 1.117e-01, Loss_res: 2.998e-02,  Loss_bcs: 2.013e-02, Loss_ut_ics: 4.274e-05,, Time: 1.29
# lambda_u: 2.970e+00
# lambda_ut: 1.256e+01
# lambda_r: 1.713e+00
# Compute NTK...
# It: 7900, Loss: 2.829e-01, Loss_res: 3.641e-02,  Loss_bcs: 5.723e-02, Loss_ut_ics: 2.884e-03,, Time: 1.23
# lambda_u: 3.045e+00
# lambda_ut: 1.710e+01
# lambda_r: 1.631e+00
# Compute NTK...
# It: 8000, Loss: 1.158e-01, Loss_res: 4.097e-02,  Loss_bcs: 1.067e-02, Loss_ut_ics: 5.991e-04,, Time: 1.20
# lambda_u: 4.650e+00
# lambda_ut: 1.563e+01
# lambda_r: 1.387e+00
# Compute NTK...
# It: 8100, Loss: 1.315e-01, Loss_res: 2.440e-02,  Loss_bcs: 1.774e-02, Loss_ut_ics: 1.331e-04,, Time: 1.21
# lambda_u: 5.454e+00
# lambda_ut: 1.258e+01
# lambda_r: 1.357e+00
# Compute NTK...
# It: 8200, Loss: 3.675e-01, Loss_res: 6.227e-02,  Loss_bcs: 5.191e-02, Loss_ut_ics: 1.596e-03,, Time: 1.24
# lambda_u: 5.002e+00
# lambda_ut: 1.398e+01
# lambda_r: 1.373e+00
# Compute NTK...
# It: 8300, Loss: 8.722e-02, Loss_res: 4.438e-02,  Loss_bcs: 5.487e-03, Loss_ut_ics: 5.112e-06,, Time: 1.32
# lambda_u: 5.165e+00
# lambda_ut: 1.944e+01
# lambda_r: 1.325e+00
# Compute NTK...
# It: 8400, Loss: 8.294e-02, Loss_res: 2.546e-02,  Loss_bcs: 1.301e-02, Loss_ut_ics: 6.225e-05,, Time: 1.21
# lambda_u: 3.212e+00
# lambda_ut: 1.950e+01
# lambda_r: 1.569e+00
# Compute NTK...
# It: 8500, Loss: 6.233e-02, Loss_res: 1.874e-02,  Loss_bcs: 9.602e-03, Loss_ut_ics: 1.023e-04,, Time: 1.18
# lambda_u: 2.815e+00
# lambda_ut: 1.025e+01
# lambda_r: 1.827e+00
# Compute NTK...
# It: 8600, Loss: 1.439e-01, Loss_res: 3.448e-02,  Loss_bcs: 2.610e-02, Loss_ut_ics: 2.638e-04,, Time: 1.16
# lambda_u: 3.236e+00
# lambda_ut: 2.421e+01
# lambda_r: 1.539e+00
# Compute NTK...
# It: 8700, Loss: 2.048e-01, Loss_res: 2.976e-02,  Loss_bcs: 5.172e-02, Loss_ut_ics: 2.439e-04,, Time: 1.22
# lambda_u: 2.915e+00
# lambda_ut: 1.500e+01
# lambda_r: 1.694e+00
# Compute NTK...
# It: 8800, Loss: 2.882e-01, Loss_res: 2.081e-02,  Loss_bcs: 1.033e-01, Loss_ut_ics: 1.467e-04,, Time: 1.23
# lambda_u: 2.382e+00
# lambda_ut: 2.135e+01
# lambda_r: 1.875e+00
# Compute NTK...
# It: 8900, Loss: 9.868e-02, Loss_res: 1.423e-02,  Loss_bcs: 2.927e-02, Loss_ut_ics: 1.850e-04,, Time: 1.21
# lambda_u: 2.242e+00
# lambda_ut: 1.027e+01
# lambda_r: 2.190e+00
# Compute NTK...
# It: 9000, Loss: 2.690e-01, Loss_res: 3.989e-02,  Loss_bcs: 8.000e-02, Loss_ut_ics: 2.555e-04,, Time: 1.18
# lambda_u: 2.032e+00
# lambda_ut: 7.939e+00
# lambda_r: 2.619e+00
# Compute NTK...
# It: 9100, Loss: 2.972e-01, Loss_res: 3.069e-02,  Loss_bcs: 5.472e-02, Loss_ut_ics: 3.554e-04,, Time: 1.24
# lambda_u: 4.546e+00
# lambda_ut: 1.551e+01
# lambda_r: 1.398e+00
# Compute NTK...
# It: 9200, Loss: 1.710e-01, Loss_res: 2.293e-02,  Loss_bcs: 4.499e-02, Loss_ut_ics: 1.331e-05,, Time: 1.29
# lambda_u: 2.893e+00
# lambda_ut: 1.092e+01
# lambda_r: 1.777e+00
# Compute NTK...
# It: 9300, Loss: 1.218e-01, Loss_res: 2.723e-02,  Loss_bcs: 2.626e-02, Loss_ut_ics: 3.478e-05,, Time: 1.25
# lambda_u: 2.744e+00
# lambda_ut: 1.199e+01
# lambda_r: 1.811e+00
# Compute NTK...
# It: 9400, Loss: 1.693e-01, Loss_res: 5.391e-02,  Loss_bcs: 2.580e-02, Loss_ut_ics: 2.791e-04,, Time: 1.23
# lambda_u: 2.688e+00
# lambda_ut: 1.552e+01
# lambda_r: 1.775e+00
# Compute NTK...
# It: 9500, Loss: 6.883e-02, Loss_res: 2.918e-02,  Loss_bcs: 6.216e-03, Loss_ut_ics: 7.870e-05,, Time: 1.20
# lambda_u: 3.947e+00
# lambda_ut: 1.411e+01
# lambda_r: 1.480e+00
# Compute NTK...
# It: 9600, Loss: 8.946e-02, Loss_res: 2.207e-02,  Loss_bcs: 1.643e-02, Loss_ut_ics: 1.027e-04,, Time: 1.26
# lambda_u: 3.148e+00
# lambda_ut: 1.320e+01
# lambda_r: 1.648e+00
# Compute NTK...
# It: 9700, Loss: 2.606e-01, Loss_res: 7.627e-02,  Loss_bcs: 4.026e-02, Loss_ut_ics: 2.829e-04,, Time: 1.22
# lambda_u: 3.383e+00
# lambda_ut: 1.403e+01
# lambda_r: 1.580e+00
# Compute NTK...
# It: 9800, Loss: 7.434e-02, Loss_res: 3.190e-02,  Loss_bcs: 6.565e-03, Loss_ut_ics: 8.623e-05,, Time: 1.31
# lambda_u: 4.298e+00
# lambda_ut: 2.130e+01
# lambda_r: 1.388e+00
# Compute NTK...
# It: 9900, Loss: 1.769e-01, Loss_res: 6.405e-02,  Loss_bcs: 2.086e-02, Loss_ut_ics: 1.988e-04,, Time: 1.14
# lambda_u: 3.310e+00
# lambda_ut: 1.088e+01
# lambda_r: 1.650e+00
# Compute NTK...
# It: 10000, Loss: 7.757e-02, Loss_res: 2.727e-02,  Loss_bcs: 6.795e-03, Loss_ut_ics: 5.256e-04,, Time: 1.15
# lambda_u: 4.802e+00
# lambda_ut: 1.277e+01
# lambda_r: 1.402e+00
# Compute NTK...
# It: 10100, Loss: 3.024e-01, Loss_res: 4.109e-02,  Loss_bcs: 5.359e-02, Loss_ut_ics: 5.251e-04,, Time: 1.11
# lambda_u: 4.403e+00
# lambda_ut: 9.827e+00
# lambda_r: 1.490e+00
# Compute NTK...
# It: 10200, Loss: 3.530e-01, Loss_res: 1.073e-01,  Loss_bcs: 3.724e-02, Loss_ut_ics: 1.151e-03,, Time: 1.14
# lambda_u: 4.570e+00
# lambda_ut: 3.503e+01
# lambda_r: 1.329e+00
# Compute NTK...
# It: 10300, Loss: 2.368e-01, Loss_res: 4.956e-02,  Loss_bcs: 2.682e-02, Loss_ut_ics: 1.978e-04,, Time: 1.10
# lambda_u: 6.350e+00
# lambda_ut: 1.943e+01
# lambda_r: 1.264e+00
# Compute NTK...
# It: 10400, Loss: 1.587e-01, Loss_res: 5.236e-02,  Loss_bcs: 2.024e-02, Loss_ut_ics: 1.946e-05,, Time: 1.09
# lambda_u: 3.956e+00
# lambda_ut: 1.256e+01
# lambda_r: 1.498e+00
# Compute NTK...
# It: 10500, Loss: 1.575e-01, Loss_res: 4.077e-02,  Loss_bcs: 2.529e-02, Loss_ut_ics: 5.554e-05,, Time: 1.12
# lambda_u: 3.738e+00
# lambda_ut: 1.280e+01
# lambda_r: 1.528e+00
# Compute NTK...
# It: 10600, Loss: 3.142e-01, Loss_res: 4.554e-02,  Loss_bcs: 6.558e-02, Loss_ut_ics: 1.752e-04,, Time: 1.11
# lambda_u: 3.679e+00
# lambda_ut: 1.162e+01
# lambda_r: 1.557e+00
# Compute NTK...
# It: 10700, Loss: 2.469e-01, Loss_res: 2.951e-02,  Loss_bcs: 5.812e-02, Loss_ut_ics: 9.534e-05,, Time: 1.11
# lambda_u: 3.426e+00
# lambda_ut: 1.365e+01
# lambda_r: 1.575e+00
# Compute NTK...
# It: 10800, Loss: 9.467e-02, Loss_res: 4.765e-02,  Loss_bcs: 6.453e-03, Loss_ut_ics: 4.435e-05,, Time: 1.13
# lambda_u: 4.198e+00
# lambda_ut: 2.141e+01
# lambda_r: 1.398e+00
# Compute NTK...
# It: 10900, Loss: 1.515e-01, Loss_res: 7.844e-02,  Loss_bcs: 8.217e-03, Loss_ut_ics: 3.040e-05,, Time: 1.11
# lambda_u: 4.321e+00
# lambda_ut: 1.106e+01
# lambda_r: 1.475e+00
# Compute NTK...
# It: 11000, Loss: 9.303e-02, Loss_res: 3.801e-02,  Loss_bcs: 8.139e-03, Loss_ut_ics: 1.458e-04,, Time: 1.15
# lambda_u: 4.758e+00
# lambda_ut: 1.969e+01
# lambda_r: 1.353e+00
# Compute NTK...
# It: 11100, Loss: 1.039e-01, Loss_res: 5.300e-02,  Loss_bcs: 6.583e-03, Loss_ut_ics: 2.426e-05,, Time: 1.09
# lambda_u: 3.581e+00
# lambda_ut: 1.754e+01
# lambda_r: 1.507e+00
# Compute NTK...
# It: 11200, Loss: 1.505e-01, Loss_res: 2.231e-02,  Loss_bcs: 2.636e-02, Loss_ut_ics: 3.373e-05,, Time: 1.07
# lambda_u: 4.494e+00
# lambda_ut: 1.393e+01
# lambda_r: 1.417e+00
# Compute NTK...
# It: 11300, Loss: 1.621e-01, Loss_res: 6.177e-02,  Loss_bcs: 1.703e-02, Loss_ut_ics: 8.562e-05,, Time: 1.10
# lambda_u: 3.752e+00
# lambda_ut: 1.008e+01
# lambda_r: 1.577e+00
# Compute NTK...
# It: 11400, Loss: 1.073e-01, Loss_res: 4.191e-02,  Loss_bcs: 1.156e-02, Loss_ut_ics: 2.020e-05,, Time: 1.09
# lambda_u: 4.028e+00
# lambda_ut: 1.746e+01
# lambda_r: 1.440e+00
# Compute NTK...
# It: 11500, Loss: 4.853e-01, Loss_res: 5.090e-02,  Loss_bcs: 7.755e-02, Loss_ut_ics: 6.694e-05,, Time: 1.11
# lambda_u: 5.362e+00
# lambda_ut: 1.416e+01
# lambda_r: 1.346e+00
# Compute NTK...
# It: 11600, Loss: 1.161e-01, Loss_res: 3.499e-02,  Loss_bcs: 1.770e-02, Loss_ut_ics: 8.725e-05,, Time: 1.16
# lambda_u: 2.792e+00
# lambda_ut: 9.029e+00
# lambda_r: 1.883e+00
# Compute NTK...
# It: 11700, Loss: 8.402e-02, Loss_res: 4.345e-02,  Loss_bcs: 3.308e-03, Loss_ut_ics: 3.660e-04,, Time: 1.11
# lambda_u: 4.674e+00
# lambda_ut: 2.948e+01
# lambda_r: 1.330e+00
# Compute NTK...
# It: 11800, Loss: 4.257e-01, Loss_res: 3.992e-02,  Loss_bcs: 1.362e-01, Loss_ut_ics: 2.324e-04,, Time: 1.08
# lambda_u: 2.520e+00
# lambda_ut: 9.509e+00
# lambda_r: 2.008e+00
# Compute NTK...
# It: 11900, Loss: 1.062e-01, Loss_res: 2.891e-02,  Loss_bcs: 1.355e-02, Loss_ut_ics: 1.009e-05,, Time: 1.13
# lambda_u: 5.022e+00
# lambda_ut: 2.715e+01
# lambda_r: 1.309e+00
# Compute NTK...
# It: 12000, Loss: 6.715e-02, Loss_res: 2.808e-02,  Loss_bcs: 6.362e-03, Loss_ut_ics: 4.595e-05,, Time: 1.14
# lambda_u: 3.026e+00
# lambda_ut: 1.322e+01
# lambda_r: 1.684e+00
# Compute NTK...
# It: 12100, Loss: 8.663e-02, Loss_res: 1.761e-02,  Loss_bcs: 2.048e-02, Loss_ut_ics: 9.628e-06,, Time: 1.14
# lambda_u: 2.000e+00
# lambda_ut: 8.788e+00
# lambda_r: 2.589e+00
# Compute NTK...
# It: 12200, Loss: 2.430e-01, Loss_res: 4.619e-02,  Loss_bcs: 6.126e-02, Loss_ut_ics: 1.858e-04,, Time: 1.13
# lambda_u: 2.426e+00
# lambda_ut: 1.147e+01
# lambda_r: 1.997e+00
# Compute NTK...
# It: 12300, Loss: 9.510e-02, Loss_res: 3.360e-02,  Loss_bcs: 1.282e-02, Loss_ut_ics: 5.387e-06,, Time: 1.14
# lambda_u: 3.077e+00
# lambda_ut: 1.422e+01
# lambda_r: 1.654e+00
# Compute NTK...
# It: 12400, Loss: 1.737e-01, Loss_res: 3.333e-02,  Loss_bcs: 2.878e-02, Loss_ut_ics: 1.649e-04,, Time: 1.06
# lambda_u: 4.296e+00
# lambda_ut: 1.526e+01
# lambda_r: 1.425e+00
# Compute NTK...
# It: 12500, Loss: 1.165e-01, Loss_res: 4.972e-02,  Loss_bcs: 1.132e-02, Loss_ut_ics: 1.781e-05,, Time: 1.14
# lambda_u: 3.725e+00
# lambda_ut: 1.666e+01
# lambda_r: 1.489e+00
# Compute NTK...
# It: 12600, Loss: 1.274e-01, Loss_res: 8.497e-02,  Loss_bcs: 2.839e-03, Loss_ut_ics: 2.323e-05,, Time: 1.15
# lambda_u: 5.068e+00
# lambda_ut: 2.094e+01
# lambda_r: 1.325e+00
# Compute NTK...
# It: 12700, Loss: 7.873e-02, Loss_res: 4.228e-02,  Loss_bcs: 3.951e-03, Loss_ut_ics: 2.845e-05,, Time: 1.14
# lambda_u: 4.016e+00
# lambda_ut: 1.346e+01
# lambda_r: 1.478e+00
# Compute NTK...
# It: 12800, Loss: 2.259e-01, Loss_res: 3.803e-02,  Loss_bcs: 3.185e-02, Loss_ut_ics: 2.908e-04,, Time: 1.14
# lambda_u: 5.357e+00
# lambda_ut: 1.445e+01
# lambda_r: 1.344e+00
# Compute NTK...
# It: 12900, Loss: 1.990e-01, Loss_res: 6.543e-02,  Loss_bcs: 2.410e-02, Loss_ut_ics: 4.143e-04,, Time: 1.19
# lambda_u: 2.760e+00
# lambda_ut: 7.583e+00
# lambda_r: 1.977e+00
# Compute NTK...
# It: 13000, Loss: 7.254e-02, Loss_res: 2.395e-02,  Loss_bcs: 7.542e-03, Loss_ut_ics: 4.936e-06,, Time: 1.08
# lambda_u: 5.376e+00
# lambda_ut: 1.573e+01
# lambda_r: 1.333e+00
# Compute NTK...
# It: 13100, Loss: 2.311e-01, Loss_res: 2.927e-02,  Loss_bcs: 5.625e-02, Loss_ut_ics: 3.550e-04,, Time: 1.16
# lambda_u: 3.172e+00
# lambda_ut: 1.421e+01
# lambda_r: 1.628e+00
# Compute NTK...
# It: 13200, Loss: 9.225e-02, Loss_res: 3.688e-02,  Loss_bcs: 1.051e-02, Loss_ut_ics: 5.836e-05,, Time: 1.12
# lambda_u: 3.219e+00
# lambda_ut: 2.306e+01
# lambda_r: 1.548e+00
# Compute NTK...
# It: 13300, Loss: 7.994e-02, Loss_res: 2.700e-02,  Loss_bcs: 1.038e-02, Loss_ut_ics: 1.475e-04,, Time: 1.07
# lambda_u: 3.345e+00
# lambda_ut: 1.285e+01
# lambda_r: 1.605e+00
# Compute NTK...
# It: 13400, Loss: 1.215e-01, Loss_res: 2.523e-02,  Loss_bcs: 2.075e-02, Loss_ut_ics: 1.225e-05,, Time: 1.12
# lambda_u: 4.111e+00
# lambda_ut: 1.830e+01
# lambda_r: 1.424e+00
# Compute NTK...
# It: 13500, Loss: 1.029e-01, Loss_res: 5.888e-02,  Loss_bcs: 4.250e-03, Loss_ut_ics: 7.811e-05,, Time: 1.28
# lambda_u: 4.161e+00
# lambda_ut: 1.723e+01
# lambda_r: 1.425e+00
# Compute NTK...
# It: 13600, Loss: 1.302e-01, Loss_res: 5.336e-02,  Loss_bcs: 1.286e-02, Loss_ut_ics: 2.099e-05,, Time: 1.40
# lambda_u: 4.530e+00
# lambda_ut: 3.251e+01
# lambda_r: 1.336e+00
# Compute NTK...
# It: 13700, Loss: 1.688e-01, Loss_res: 2.855e-02,  Loss_bcs: 2.450e-02, Loss_ut_ics: 6.201e-04,, Time: 1.30
# lambda_u: 4.806e+00
# lambda_ut: 2.024e+01
# lambda_r: 1.347e+00
# Compute NTK...
# It: 13800, Loss: 8.562e-02, Loss_res: 4.671e-02,  Loss_bcs: 4.721e-03, Loss_ut_ics: 1.307e-05,, Time: 1.21
# lambda_u: 3.905e+00
# lambda_ut: 2.186e+01
# lambda_r: 1.432e+00
# Compute NTK...
# It: 13900, Loss: 9.842e-02, Loss_res: 2.142e-02,  Loss_bcs: 1.185e-02, Loss_ut_ics: 7.558e-05,, Time: 1.18
# lambda_u: 5.839e+00
# lambda_ut: 1.531e+01
# lambda_r: 1.310e+00
# Compute NTK...
# It: 14000, Loss: 1.758e-01, Loss_res: 1.683e-02,  Loss_bcs: 5.831e-02, Loss_ut_ics: 1.273e-04,, Time: 1.29
# lambda_u: 2.435e+00
# lambda_ut: 1.724e+01
# lambda_r: 1.882e+00
# Compute NTK...
# It: 14100, Loss: 7.047e-02, Loss_res: 2.167e-02,  Loss_bcs: 1.064e-02, Loss_ut_ics: 7.669e-06,, Time: 1.20
# lambda_u: 2.793e+00
# lambda_ut: 9.136e+00
# lambda_r: 1.878e+00
# Compute NTK...
# It: 14200, Loss: 1.595e-01, Loss_res: 7.394e-02,  Loss_bcs: 1.066e-02, Loss_ut_ics: 1.031e-05,, Time: 1.25
# lambda_u: 2.622e+00
# lambda_ut: 1.801e+01
# lambda_r: 1.776e+00
# Compute NTK...
# It: 14300, Loss: 2.428e-01, Loss_res: 8.121e-02,  Loss_bcs: 2.091e-02, Loss_ut_ics: 2.153e-04,, Time: 1.39
# lambda_u: 6.522e+00
# lambda_ut: 3.083e+01
# lambda_r: 1.228e+00
# Compute NTK...
# It: 14400, Loss: 1.502e-01, Loss_res: 3.006e-02,  Loss_bcs: 2.934e-02, Loss_ut_ics: 3.999e-05,, Time: 1.36
# lambda_u: 3.576e+00
# lambda_ut: 2.332e+01
# lambda_r: 1.476e+00
# Compute NTK...
# It: 14500, Loss: 2.145e-01, Loss_res: 4.617e-02,  Loss_bcs: 3.685e-02, Loss_ut_ics: 5.416e-04,, Time: 1.42
# lambda_u: 3.574e+00
# lambda_ut: 7.489e+00
# lambda_r: 1.704e+00
# Compute NTK...
# It: 14600, Loss: 6.202e-02, Loss_res: 3.651e-02,  Loss_bcs: 1.895e-03, Loss_ut_ics: 1.157e-04,, Time: 1.31
# lambda_u: 5.601e+00
# lambda_ut: 5.062e+01
# lambda_r: 1.247e+00
# Compute NTK...
# It: 14700, Loss: 1.560e-01, Loss_res: 5.088e-02,  Loss_bcs: 1.679e-02, Loss_ut_ics: 2.677e-05,, Time: 1.37
# lambda_u: 4.953e+00
# lambda_ut: 1.032e+01
# lambda_r: 1.426e+00
# Compute NTK...
# It: 14800, Loss: 1.378e-01, Loss_res: 4.408e-02,  Loss_bcs: 1.579e-02, Loss_ut_ics: 1.640e-05,, Time: 1.27
# lambda_u: 5.090e+00
# lambda_ut: 3.514e+01
# lambda_r: 1.290e+00
# Compute NTK...
# It: 14900, Loss: 1.259e-01, Loss_res: 2.124e-02,  Loss_bcs: 3.014e-02, Loss_ut_ics: 9.638e-05,, Time: 1.26
# lambda_u: 2.827e+00
# lambda_ut: 8.813e+00
# lambda_r: 1.877e+00
# Compute NTK...
# It: 15000, Loss: 1.784e-01, Loss_res: 2.711e-02,  Loss_bcs: 3.248e-02, Loss_ut_ics: 4.407e-05,, Time: 1.32
# lambda_u: 4.286e+00
# lambda_ut: 1.638e+01
# lambda_r: 1.417e+00
# Compute NTK...
# It: 15100, Loss: 1.002e-01, Loss_res: 3.230e-02,  Loss_bcs: 1.603e-02, Loss_ut_ics: 1.900e-05,, Time: 1.41
# lambda_u: 2.818e+00
# lambda_ut: 1.823e+01
# lambda_r: 1.694e+00
# Compute NTK...
# It: 15200, Loss: 6.940e-02, Loss_res: 3.556e-02,  Loss_bcs: 3.684e-03, Loss_ut_ics: 1.104e-04,, Time: 1.22
# lambda_u: 5.331e+00
# lambda_ut: 1.310e+01
# lambda_r: 1.359e+00
# Compute NTK...
# It: 15300, Loss: 7.221e-02, Loss_res: 2.190e-02,  Loss_bcs: 1.049e-02, Loss_ut_ics: 2.897e-05,, Time: 1.20
# lambda_u: 3.490e+00
# lambda_ut: 1.079e+01
# lambda_r: 1.611e+00
# Compute NTK...
# It: 15400, Loss: 1.102e-01, Loss_res: 3.085e-02,  Loss_bcs: 1.480e-02, Loss_ut_ics: 3.818e-04,, Time: 1.23
# lambda_u: 3.992e+00
# lambda_ut: 1.059e+01
# lambda_r: 1.526e+00
# Compute NTK...
# It: 15500, Loss: 2.924e-01, Loss_res: 9.197e-02,  Loss_bcs: 3.519e-02, Loss_ut_ics: 4.664e-04,, Time: 1.27
# lambda_u: 4.437e+00
# lambda_ut: 1.916e+01
# lambda_r: 1.384e+00
# Compute NTK...
# It: 15600, Loss: 2.254e-01, Loss_res: 3.780e-02,  Loss_bcs: 2.951e-02, Loss_ut_ics: 6.814e-05,, Time: 1.38
# lambda_u: 5.952e+00
# lambda_ut: 4.532e+01
# lambda_r: 1.235e+00
# Compute NTK...
# It: 15700, Loss: 3.058e-01, Loss_res: 6.339e-02,  Loss_bcs: 5.464e-02, Loss_ut_ics: 1.163e-04,, Time: 1.28
# lambda_u: 3.815e+00
# lambda_ut: 1.307e+01
# lambda_r: 1.512e+00
# Compute NTK...
# It: 15800, Loss: 1.062e-01, Loss_res: 2.967e-02,  Loss_bcs: 2.017e-02, Loss_ut_ics: 5.711e-05,, Time: 1.26
# lambda_u: 2.528e+00
# lambda_ut: 1.739e+01
# lambda_r: 1.828e+00
# Compute NTK...
# It: 15900, Loss: 1.070e-01, Loss_res: 5.059e-02,  Loss_bcs: 8.561e-03, Loss_ut_ics: 4.954e-05,, Time: 1.26
# lambda_u: 3.326e+00
# lambda_ut: 2.189e+01
# lambda_r: 1.530e+00
# Compute NTK...
# It: 16000, Loss: 4.082e-01, Loss_res: 4.076e-02,  Loss_bcs: 6.270e-02, Loss_ut_ics: 6.643e-05,, Time: 1.32
# lambda_u: 5.643e+00
# lambda_ut: 1.801e+01
# lambda_r: 1.303e+00
# Compute NTK...
# It: 16100, Loss: 1.982e-01, Loss_res: 3.823e-02,  Loss_bcs: 4.379e-02, Loss_ut_ics: 4.374e-06,, Time: 1.21
# lambda_u: 3.187e+00
# lambda_ut: 3.091e+01
# lambda_r: 1.529e+00
# Compute NTK...
# It: 16200, Loss: 2.019e-01, Loss_res: 6.035e-02,  Loss_bcs: 3.229e-02, Loss_ut_ics: 8.686e-05,, Time: 1.16
# lambda_u: 3.280e+00
# lambda_ut: 1.784e+01
# lambda_r: 1.565e+00
# Compute NTK...
# It: 16300, Loss: 1.370e-01, Loss_res: 4.443e-02,  Loss_bcs: 1.914e-02, Loss_ut_ics: 2.168e-06,, Time: 1.24
# lambda_u: 3.526e+00
# lambda_ut: 1.302e+01
# lambda_r: 1.564e+00
# Compute NTK...
# It: 16400, Loss: 1.037e-01, Loss_res: 1.422e-02,  Loss_bcs: 2.719e-02, Loss_ut_ics: 1.062e-05,, Time: 1.43
# lambda_u: 2.907e+00
# lambda_ut: 1.327e+01
# lambda_r: 1.722e+00
# Compute NTK...
# It: 16500, Loss: 1.198e-01, Loss_res: 6.973e-02,  Loss_bcs: 4.195e-03, Loss_ut_ics: 3.086e-05,, Time: 1.33
# lambda_u: 3.628e+00
# lambda_ut: 1.843e+01
# lambda_r: 1.492e+00
# Compute NTK...
# It: 16600, Loss: 7.330e-02, Loss_res: 3.898e-02,  Loss_bcs: 3.573e-03, Loss_ut_ics: 9.026e-05,, Time: 1.29
# lambda_u: 5.826e+00
# lambda_ut: 1.523e+01
# lambda_r: 1.311e+00
# Compute NTK...
# It: 16700, Loss: 1.179e-01, Loss_res: 5.703e-02,  Loss_bcs: 5.413e-03, Loss_ut_ics: 5.358e-05,, Time: 1.34
# lambda_u: 3.170e+00
# lambda_ut: 8.644e+00
# lambda_r: 1.758e+00
# Compute NTK...
# It: 16800, Loss: 2.058e-01, Loss_res: 6.549e-02,  Loss_bcs: 2.573e-02, Loss_ut_ics: 2.514e-05,, Time: 1.35
# lambda_u: 4.565e+00
# lambda_ut: 2.997e+01
# lambda_r: 1.338e+00
# Compute NTK...
# It: 16900, Loss: 7.549e-02, Loss_res: 2.848e-02,  Loss_bcs: 6.257e-03, Loss_ut_ics: 4.461e-05,, Time: 1.36
# lambda_u: 6.144e+00
# lambda_ut: 2.028e+01
# lambda_r: 1.269e+00
# Compute NTK...
# It: 17000, Loss: 1.280e-01, Loss_res: 8.231e-02,  Loss_bcs: 2.521e-03, Loss_ut_ics: 6.256e-05,, Time: 1.15
# lambda_u: 4.225e+00
# lambda_ut: 1.808e+01
# lambda_r: 1.412e+00
# Compute NTK...
# It: 17100, Loss: 1.599e-01, Loss_res: 3.158e-02,  Loss_bcs: 2.622e-02, Loss_ut_ics: 1.274e-04,, Time: 1.29
# lambda_u: 4.300e+00
# lambda_ut: 3.424e+01
# lambda_r: 1.355e+00
# Compute NTK...
# It: 17200, Loss: 1.464e-01, Loss_res: 2.176e-02,  Loss_bcs: 3.903e-02, Loss_ut_ics: 6.512e-05,, Time: 1.21
# lambda_u: 2.716e+00
# lambda_ut: 1.229e+01
# lambda_r: 1.817e+00
# Compute NTK...
# It: 17300, Loss: 9.463e-02, Loss_res: 5.123e-02,  Loss_bcs: 5.076e-03, Loss_ut_ics: 3.427e-05,, Time: 1.29
# lambda_u: 4.765e+00
# lambda_ut: 1.767e+01
# lambda_r: 1.363e+00
# Compute NTK...
# It: 17400, Loss: 1.875e-01, Loss_res: 3.139e-02,  Loss_bcs: 3.066e-02, Loss_ut_ics: 1.892e-04,, Time: 1.33
# lambda_u: 4.580e+00
# lambda_ut: 2.479e+01
# lambda_r: 1.349e+00
# Compute NTK...
# It: 17500, Loss: 1.002e-01, Loss_res: 2.044e-02,  Loss_bcs: 2.073e-02, Loss_ut_ics: 1.570e-04,, Time: 1.06
# lambda_u: 2.731e+00
# lambda_ut: 6.501e+00
# lambda_r: 2.083e+00
# Compute NTK...
# It: 17600, Loss: 1.210e-01, Loss_res: 4.350e-02,  Loss_bcs: 1.197e-02, Loss_ut_ics: 3.191e-04,, Time: 1.34
# lambda_u: 4.655e+00
# lambda_ut: 1.635e+01
# lambda_r: 1.381e+00
# Compute NTK...
# It: 17700, Loss: 1.423e-01, Loss_res: 3.488e-02,  Loss_bcs: 2.182e-02, Loss_ut_ics: 2.422e-05,, Time: 1.23
# lambda_u: 4.239e+00
# lambda_ut: 1.720e+01
# lambda_r: 1.417e+00
# Compute NTK...
# It: 17800, Loss: 1.860e-01, Loss_res: 1.175e-02,  Loss_bcs: 6.663e-02, Loss_ut_ics: 2.762e-04,, Time: 1.26
# lambda_u: 2.388e+00
# lambda_ut: 1.298e+01
# lambda_r: 1.984e+00
# Compute NTK...
# It: 17900, Loss: 2.600e-01, Loss_res: 2.720e-02,  Loss_bcs: 5.921e-02, Loss_ut_ics: 9.542e-04,, Time: 1.21
# lambda_u: 3.424e+00
# lambda_ut: 1.570e+01
# lambda_r: 1.552e+00
# Compute NTK...
# It: 18000, Loss: 1.477e-01, Loss_res: 3.833e-02,  Loss_bcs: 2.192e-02, Loss_ut_ics: 2.762e-05,, Time: 1.17
# lambda_u: 4.292e+00
# lambda_ut: 2.276e+01
# lambda_r: 1.383e+00
# Compute NTK...
# It: 18100, Loss: 1.443e-01, Loss_res: 5.399e-02,  Loss_bcs: 1.534e-02, Loss_ut_ics: 2.965e-05,, Time: 1.41
# lambda_u: 4.322e+00
# lambda_ut: 1.374e+01
# lambda_r: 1.437e+00
# Compute NTK...
# It: 18200, Loss: 2.200e-01, Loss_res: 4.682e-02,  Loss_bcs: 4.443e-02, Loss_ut_ics: 1.949e-04,, Time: 1.41
# lambda_u: 3.073e+00
# lambda_ut: 9.993e+00
# lambda_r: 1.741e+00
# Compute NTK...
# It: 18300, Loss: 1.357e-01, Loss_res: 2.754e-02,  Loss_bcs: 2.492e-02, Loss_ut_ics: 2.808e-04,, Time: 1.43
# lambda_u: 3.558e+00
# lambda_ut: 1.092e+01
# lambda_r: 1.594e+00
# Compute NTK...
# It: 18400, Loss: 9.120e-02, Loss_res: 2.285e-02,  Loss_bcs: 1.533e-02, Loss_ut_ics: 1.262e-04,, Time: 1.30
# lambda_u: 3.215e+00
# lambda_ut: 7.637e+00
# lambda_r: 1.792e+00
# Compute NTK...
# It: 18500, Loss: 1.221e-01, Loss_res: 2.084e-02,  Loss_bcs: 2.992e-02, Loss_ut_ics: 1.658e-05,, Time: 1.61
# lambda_u: 2.696e+00
# lambda_ut: 8.066e+00
# lambda_r: 1.980e+00
# Compute NTK...
# It: 18600, Loss: 2.109e-01, Loss_res: 1.012e-01,  Loss_bcs: 1.472e-02, Loss_ut_ics: 4.368e-05,, Time: 1.49
# lambda_u: 3.339e+00
# lambda_ut: 1.382e+01
# lambda_r: 1.592e+00
# Compute NTK...
# It: 18700, Loss: 1.143e-01, Loss_res: 6.211e-02,  Loss_bcs: 5.875e-03, Loss_ut_ics: 2.051e-05,, Time: 1.34
# lambda_u: 5.839e+00
# lambda_ut: 2.074e+01
# lambda_r: 1.281e+00
# Compute NTK...
# It: 18800, Loss: 1.622e-01, Loss_res: 5.661e-02,  Loss_bcs: 2.105e-02, Loss_ut_ics: 1.041e-04,, Time: 1.32
# lambda_u: 3.523e+00
# lambda_ut: 1.661e+01
# lambda_r: 1.524e+00
# Compute NTK...
# It: 18900, Loss: 8.469e-02, Loss_res: 3.955e-02,  Loss_bcs: 5.943e-03, Loss_ut_ics: 1.479e-05,, Time: 1.30
# lambda_u: 4.129e+00
# lambda_ut: 1.014e+01
# lambda_r: 1.517e+00
# Compute NTK...
# It: 19000, Loss: 1.714e-01, Loss_res: 2.831e-02,  Loss_bcs: 3.131e-02, Loss_ut_ics: 4.592e-05,, Time: 1.39
# lambda_u: 4.145e+00
# lambda_ut: 1.468e+01
# lambda_r: 1.448e+00
# Compute NTK...
# It: 19100, Loss: 7.483e-02, Loss_res: 3.106e-02,  Loss_bcs: 8.333e-03, Loss_ut_ics: 3.323e-06,, Time: 1.40
# lambda_u: 3.692e+00
# lambda_ut: 4.573e+01
# lambda_r: 1.414e+00
# Compute NTK...
# It: 19200, Loss: 1.410e-01, Loss_res: 2.018e-02,  Loss_bcs: 2.956e-02, Loss_ut_ics: 4.563e-04,, Time: 1.36
# lambda_u: 3.494e+00
# lambda_ut: 1.335e+01
# lambda_r: 1.565e+00
# Compute NTK...
# It: 19300, Loss: 2.548e-01, Loss_res: 2.425e-02,  Loss_bcs: 7.818e-02, Loss_ut_ics: 2.989e-04,, Time: 1.39
# lambda_u: 2.577e+00
# lambda_ut: 7.237e+00
# lambda_r: 2.110e+00
# Compute NTK...
# It: 19400, Loss: 1.484e-01, Loss_res: 3.222e-02,  Loss_bcs: 2.737e-02, Loss_ut_ics: 3.258e-04,, Time: 1.52
# lambda_u: 3.394e+00
# lambda_ut: 1.315e+01
# lambda_r: 1.589e+00
# Compute NTK...
# It: 19500, Loss: 8.249e-02, Loss_res: 3.508e-02,  Loss_bcs: 7.466e-03, Loss_ut_ics: 4.080e-05,, Time: 1.43
# lambda_u: 3.966e+00
# lambda_ut: 1.285e+01
# lambda_r: 1.492e+00
# Compute NTK...
# It: 19600, Loss: 1.380e-01, Loss_res: 2.374e-02,  Loss_bcs: 3.685e-02, Loss_ut_ics: 2.145e-05,, Time: 1.36
# lambda_u: 2.300e+00
# lambda_ut: 8.473e+00
# lambda_r: 2.236e+00
# Compute NTK...
# It: 19700, Loss: 1.460e-01, Loss_res: 2.709e-02,  Loss_bcs: 3.168e-02, Loss_ut_ics: 9.133e-05,, Time: 1.15
# lambda_u: 3.159e+00
# lambda_ut: 1.277e+01
# lambda_r: 1.653e+00
# Compute NTK...
# It: 19800, Loss: 7.055e-02, Loss_res: 2.053e-02,  Loss_bcs: 1.157e-02, Loss_ut_ics: 2.415e-05,, Time: 1.08
# lambda_u: 3.099e+00
# lambda_ut: 1.243e+01
# lambda_r: 1.675e+00
# Compute NTK...
# It: 19900, Loss: 9.296e-02, Loss_res: 1.832e-02,  Loss_bcs: 2.193e-02, Loss_ut_ics: 2.477e-04,, Time: 1.09
# lambda_u: 2.507e+00
# lambda_ut: 1.587e+01
# lambda_r: 1.859e+00
# Compute NTK...

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
print(x.shape,t.shape)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))
print(X_star.shape)
u_star = u(X_star, a,c)
R_star = r(X_star, a, c)
print(u_star.shape,R_star.shape)
# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
print(u_pred.shape,r_pred.shape)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))
# Out:
# (200, 200) (200, 200)
# (40000, 2)
# (40000, 1) (40000, 1)
# (40000, 1) (40000, 1)
# Relative L2 error_u: 6.822912e-01

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
print(X_star.shape,R_star.shape,u_star.shape)
R_star = griddata(X_star, R_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, R_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(R_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# (40000, 2) (40000, 1) (40000, 1)

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
