# %%
# Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        

        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        
        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def train(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # Store losses
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)
                self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %
                      (it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))

                start_time = timeit.default_timer()
            
          
            if log_NTK:
                if it % 100 == 0:
                        print("Compute NTK...")
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) + \
                                       np.trace(K_r_value)

                        # Store NTK matrices
                        self.K_u_log.append(K_u_value)
                        self.K_ut_log.append(K_ut_value)
                        self.K_r_log.append(K_r_value)
                        
                        if update_lam:

                          self.lam_u_val = trace_K / np.trace(K_u_value)
                          self.lam_ut_val = trace_K /np.trace(K_ut_value)
                          self.lam_r_val = trace_K / np.trace(K_r_value)

                          # Store NTK weights
                          self.lam_u_log.append(self.lam_u_val)
                          self.lam_ut_log.append(self.lam_ut_val)
                          self.lam_r_log.append(self.lam_r_val)
                        
                        
          
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
def u(x, a, c):
    """
    exact solution
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    
    return np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * np.exp(-(2*np.pi)**2*2*c*t)
    
    #return np.sin(np.pi * x) * np.cos(c * np.pi * t) + \
    #a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    # first derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * (2*np.pi)**2*c * np.exp(-(2*np.pi)**2*c*t)
    return u_tss

def u_tt(x, a, c):
    # second derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * (2*np.pi)**4*c**2 * np.exp(-(2*np.pi)**2*c*t)


    return u_tt

def u_xx(x, a, c):
    # second derivitive of x
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - \
              a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx

def u_x(x,a,c):
    t = x[:,0:1]
    x = x[:,1:2]
    return (-x/a**2) * np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * np.exp(-(2*np.pi)**2*c*t) - \
(2*np.pi) * np.exp(-x**2/2*a**2) * np.sin(2*np.pi*x) * np.exp(-(2*np.pi)**2*c*t)

def r(x, a, c):
    # THE pde its selft
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    # gradient
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
# Domain boundaries
ics_coords = np.array([[0.0, 0.0],
                        [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],
                        [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],
                        [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')

# %%
# Define PINN model
a = 0.5
c = 0.2

layers = [2, 500, 500, 500, 1]
kernel_size = 300
model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
### Train model
itertaions = 30001
log_NTK = False # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK 

model.train(nIter=itertaions, batch_size=kernel_size, log_NTK=log_NTK, update_lam=update_lam)
# Out:
# It: 0, Loss: 3.262e-03, Loss_res: 3.649e-04,  Loss_bcs: 2.826e-03, Loss_ut_ics: 7.059e-05,, Time: 0.04
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 100, Loss: 5.592e-03, Loss_res: 3.914e-04,  Loss_bcs: 4.615e-03, Loss_ut_ics: 5.859e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 200, Loss: 5.037e-03, Loss_res: 5.069e-04,  Loss_bcs: 4.201e-03, Loss_ut_ics: 3.298e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 300, Loss: 1.136e-02, Loss_res: 3.985e-04,  Loss_bcs: 1.088e-02, Loss_ut_ics: 7.675e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 400, Loss: 1.387e-02, Loss_res: 3.309e-04,  Loss_bcs: 1.336e-02, Loss_ut_ics: 1.740e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 500, Loss: 6.619e-03, Loss_res: 1.534e-04,  Loss_bcs: 6.437e-03, Loss_ut_ics: 2.855e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 600, Loss: 3.398e-03, Loss_res: 2.345e-04,  Loss_bcs: 3.101e-03, Loss_ut_ics: 6.298e-05,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 700, Loss: 9.827e-03, Loss_res: 3.126e-04,  Loss_bcs: 9.367e-03, Loss_ut_ics: 1.468e-04,, Time: 1.57
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 800, Loss: 3.723e-03, Loss_res: 1.773e-04,  Loss_bcs: 3.393e-03, Loss_ut_ics: 1.534e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 900, Loss: 2.001e-02, Loss_res: 7.306e-04,  Loss_bcs: 1.911e-02, Loss_ut_ics: 1.670e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1000, Loss: 1.259e-02, Loss_res: 1.003e-03,  Loss_bcs: 1.132e-02, Loss_ut_ics: 2.728e-04,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1100, Loss: 1.853e-02, Loss_res: 3.046e-04,  Loss_bcs: 1.806e-02, Loss_ut_ics: 1.654e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1200, Loss: 1.588e-02, Loss_res: 5.804e-04,  Loss_bcs: 1.517e-02, Loss_ut_ics: 1.340e-04,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1300, Loss: 1.129e-02, Loss_res: 4.456e-04,  Loss_bcs: 1.056e-02, Loss_ut_ics: 2.847e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1400, Loss: 4.077e-03, Loss_res: 3.176e-04,  Loss_bcs: 3.227e-03, Loss_ut_ics: 5.331e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1500, Loss: 5.260e-03, Loss_res: 2.312e-04,  Loss_bcs: 4.804e-03, Loss_ut_ics: 2.249e-04,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1600, Loss: 1.245e-02, Loss_res: 3.215e-04,  Loss_bcs: 1.176e-02, Loss_ut_ics: 3.609e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1700, Loss: 2.293e-02, Loss_res: 1.583e-04,  Loss_bcs: 2.225e-02, Loss_ut_ics: 5.233e-04,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1800, Loss: 1.109e-02, Loss_res: 1.074e-04,  Loss_bcs: 1.090e-02, Loss_ut_ics: 8.879e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 1900, Loss: 1.040e-02, Loss_res: 2.441e-04,  Loss_bcs: 1.008e-02, Loss_ut_ics: 6.997e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2000, Loss: 8.505e-03, Loss_res: 5.410e-04,  Loss_bcs: 7.895e-03, Loss_ut_ics: 6.880e-05,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2100, Loss: 3.619e-03, Loss_res: 2.253e-04,  Loss_bcs: 3.343e-03, Loss_ut_ics: 5.045e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2200, Loss: 5.869e-03, Loss_res: 1.497e-04,  Loss_bcs: 5.585e-03, Loss_ut_ics: 1.338e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2300, Loss: 1.489e-02, Loss_res: 2.149e-04,  Loss_bcs: 1.405e-02, Loss_ut_ics: 6.259e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2400, Loss: 1.031e-02, Loss_res: 1.409e-04,  Loss_bcs: 9.958e-03, Loss_ut_ics: 2.101e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2500, Loss: 3.601e-03, Loss_res: 2.748e-04,  Loss_bcs: 3.114e-03, Loss_ut_ics: 2.130e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2600, Loss: 1.706e-02, Loss_res: 1.506e-03,  Loss_bcs: 1.473e-02, Loss_ut_ics: 8.203e-04,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2700, Loss: 1.481e-02, Loss_res: 1.829e-04,  Loss_bcs: 1.437e-02, Loss_ut_ics: 2.607e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2800, Loss: 7.906e-03, Loss_res: 6.271e-04,  Loss_bcs: 6.309e-03, Loss_ut_ics: 9.700e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 2900, Loss: 2.589e-03, Loss_res: 2.509e-04,  Loss_bcs: 2.074e-03, Loss_ut_ics: 2.641e-04,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3000, Loss: 1.062e-02, Loss_res: 6.336e-04,  Loss_bcs: 9.873e-03, Loss_ut_ics: 1.172e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3100, Loss: 7.834e-03, Loss_res: 2.268e-04,  Loss_bcs: 7.484e-03, Loss_ut_ics: 1.225e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3200, Loss: 1.219e-02, Loss_res: 1.334e-03,  Loss_bcs: 1.069e-02, Loss_ut_ics: 1.627e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3300, Loss: 1.580e-02, Loss_res: 9.387e-05,  Loss_bcs: 1.555e-02, Loss_ut_ics: 1.512e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3400, Loss: 5.358e-03, Loss_res: 2.976e-04,  Loss_bcs: 4.210e-03, Loss_ut_ics: 8.506e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3500, Loss: 5.216e-03, Loss_res: 2.834e-04,  Loss_bcs: 4.900e-03, Loss_ut_ics: 3.257e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3600, Loss: 1.599e-02, Loss_res: 1.453e-04,  Loss_bcs: 1.561e-02, Loss_ut_ics: 2.324e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3700, Loss: 1.693e-02, Loss_res: 3.732e-04,  Loss_bcs: 1.601e-02, Loss_ut_ics: 5.411e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3800, Loss: 2.309e-03, Loss_res: 2.284e-04,  Loss_bcs: 2.057e-03, Loss_ut_ics: 2.401e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 3900, Loss: 9.392e-03, Loss_res: 4.757e-04,  Loss_bcs: 8.660e-03, Loss_ut_ics: 2.562e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4000, Loss: 7.043e-03, Loss_res: 4.366e-04,  Loss_bcs: 6.299e-03, Loss_ut_ics: 3.068e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4100, Loss: 7.763e-03, Loss_res: 1.303e-04,  Loss_bcs: 7.498e-03, Loss_ut_ics: 1.353e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4200, Loss: 7.056e-03, Loss_res: 1.560e-04,  Loss_bcs: 6.784e-03, Loss_ut_ics: 1.166e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4300, Loss: 7.786e-03, Loss_res: 6.744e-04,  Loss_bcs: 7.053e-03, Loss_ut_ics: 5.951e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4400, Loss: 3.231e-03, Loss_res: 1.840e-04,  Loss_bcs: 3.017e-03, Loss_ut_ics: 2.987e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4500, Loss: 7.726e-03, Loss_res: 2.234e-04,  Loss_bcs: 7.319e-03, Loss_ut_ics: 1.832e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4600, Loss: 8.877e-03, Loss_res: 7.862e-04,  Loss_bcs: 7.947e-03, Loss_ut_ics: 1.437e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4700, Loss: 1.076e-02, Loss_res: 1.488e-04,  Loss_bcs: 1.034e-02, Loss_ut_ics: 2.623e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4800, Loss: 7.895e-03, Loss_res: 7.905e-04,  Loss_bcs: 6.824e-03, Loss_ut_ics: 2.806e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 4900, Loss: 5.105e-03, Loss_res: 2.105e-04,  Loss_bcs: 4.852e-03, Loss_ut_ics: 4.291e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5000, Loss: 1.408e-02, Loss_res: 1.821e-04,  Loss_bcs: 1.352e-02, Loss_ut_ics: 3.793e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5100, Loss: 8.741e-03, Loss_res: 1.712e-04,  Loss_bcs: 8.453e-03, Loss_ut_ics: 1.161e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5200, Loss: 1.355e-02, Loss_res: 3.356e-04,  Loss_bcs: 1.313e-02, Loss_ut_ics: 8.600e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5300, Loss: 8.364e-03, Loss_res: 2.265e-04,  Loss_bcs: 7.992e-03, Loss_ut_ics: 1.453e-04,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5400, Loss: 6.462e-03, Loss_res: 1.571e-04,  Loss_bcs: 6.282e-03, Loss_ut_ics: 2.271e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5500, Loss: 9.360e-03, Loss_res: 2.759e-04,  Loss_bcs: 8.915e-03, Loss_ut_ics: 1.693e-04,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5600, Loss: 8.097e-03, Loss_res: 1.247e-04,  Loss_bcs: 7.893e-03, Loss_ut_ics: 7.989e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5700, Loss: 1.516e-02, Loss_res: 1.980e-04,  Loss_bcs: 1.489e-02, Loss_ut_ics: 6.883e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5800, Loss: 1.764e-02, Loss_res: 1.455e-04,  Loss_bcs: 1.739e-02, Loss_ut_ics: 1.049e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 5900, Loss: 5.107e-03, Loss_res: 3.217e-04,  Loss_bcs: 4.716e-03, Loss_ut_ics: 6.994e-05,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6000, Loss: 1.084e-02, Loss_res: 2.457e-04,  Loss_bcs: 1.050e-02, Loss_ut_ics: 9.471e-05,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6100, Loss: 5.756e-03, Loss_res: 2.293e-04,  Loss_bcs: 5.466e-03, Loss_ut_ics: 6.049e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6200, Loss: 2.860e-03, Loss_res: 5.173e-04,  Loss_bcs: 2.320e-03, Loss_ut_ics: 2.224e-05,, Time: 1.60
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6300, Loss: 1.968e-03, Loss_res: 3.618e-04,  Loss_bcs: 1.571e-03, Loss_ut_ics: 3.425e-05,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6400, Loss: 8.887e-03, Loss_res: 9.824e-05,  Loss_bcs: 8.761e-03, Loss_ut_ics: 2.744e-05,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6500, Loss: 1.823e-03, Loss_res: 1.954e-04,  Loss_bcs: 1.562e-03, Loss_ut_ics: 6.585e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6600, Loss: 1.759e-02, Loss_res: 2.106e-04,  Loss_bcs: 1.719e-02, Loss_ut_ics: 1.897e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6700, Loss: 2.704e-03, Loss_res: 1.092e-04,  Loss_bcs: 2.461e-03, Loss_ut_ics: 1.340e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6800, Loss: 3.292e-03, Loss_res: 1.109e-04,  Loss_bcs: 3.080e-03, Loss_ut_ics: 1.010e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 6900, Loss: 1.184e-02, Loss_res: 3.652e-04,  Loss_bcs: 1.133e-02, Loss_ut_ics: 1.422e-04,, Time: 1.59
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7000, Loss: 1.616e-02, Loss_res: 2.566e-04,  Loss_bcs: 1.578e-02, Loss_ut_ics: 1.253e-04,, Time: 1.63
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7100, Loss: 3.136e-03, Loss_res: 1.139e-04,  Loss_bcs: 2.858e-03, Loss_ut_ics: 1.647e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7200, Loss: 7.934e-03, Loss_res: 2.543e-04,  Loss_bcs: 7.495e-03, Loss_ut_ics: 1.842e-04,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7300, Loss: 5.245e-03, Loss_res: 3.382e-04,  Loss_bcs: 4.410e-03, Loss_ut_ics: 4.973e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7400, Loss: 8.900e-03, Loss_res: 1.357e-04,  Loss_bcs: 8.664e-03, Loss_ut_ics: 1.002e-04,, Time: 1.60
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7500, Loss: 6.258e-03, Loss_res: 2.199e-04,  Loss_bcs: 5.920e-03, Loss_ut_ics: 1.182e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7600, Loss: 1.851e-02, Loss_res: 1.280e-04,  Loss_bcs: 1.833e-02, Loss_ut_ics: 5.493e-05,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7700, Loss: 2.791e-03, Loss_res: 2.942e-04,  Loss_bcs: 2.417e-03, Loss_ut_ics: 8.031e-05,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7800, Loss: 5.955e-03, Loss_res: 1.902e-04,  Loss_bcs: 5.618e-03, Loss_ut_ics: 1.461e-04,, Time: 1.65
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 7900, Loss: 1.467e-02, Loss_res: 2.728e-04,  Loss_bcs: 1.428e-02, Loss_ut_ics: 1.210e-04,, Time: 1.58
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8000, Loss: 7.605e-03, Loss_res: 3.062e-04,  Loss_bcs: 7.246e-03, Loss_ut_ics: 5.236e-05,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8100, Loss: 8.209e-03, Loss_res: 2.987e-04,  Loss_bcs: 7.772e-03, Loss_ut_ics: 1.382e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8200, Loss: 1.939e-02, Loss_res: 2.233e-04,  Loss_bcs: 1.903e-02, Loss_ut_ics: 1.314e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8300, Loss: 6.412e-03, Loss_res: 2.097e-04,  Loss_bcs: 6.053e-03, Loss_ut_ics: 1.493e-04,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8400, Loss: 7.777e-03, Loss_res: 1.598e-04,  Loss_bcs: 7.514e-03, Loss_ut_ics: 1.029e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8500, Loss: 9.625e-03, Loss_res: 7.288e-04,  Loss_bcs: 8.701e-03, Loss_ut_ics: 1.953e-04,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8600, Loss: 1.013e-02, Loss_res: 9.698e-04,  Loss_bcs: 9.026e-03, Loss_ut_ics: 1.377e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8700, Loss: 8.446e-03, Loss_res: 1.943e-04,  Loss_bcs: 8.194e-03, Loss_ut_ics: 5.731e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8800, Loss: 2.782e-03, Loss_res: 1.390e-04,  Loss_bcs: 2.605e-03, Loss_ut_ics: 3.872e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 8900, Loss: 5.191e-03, Loss_res: 2.384e-04,  Loss_bcs: 4.892e-03, Loss_ut_ics: 6.044e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9000, Loss: 6.590e-03, Loss_res: 2.120e-04,  Loss_bcs: 6.096e-03, Loss_ut_ics: 2.819e-04,, Time: 1.36
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9100, Loss: 7.641e-03, Loss_res: 1.045e-04,  Loss_bcs: 7.378e-03, Loss_ut_ics: 1.590e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9200, Loss: 9.112e-03, Loss_res: 1.211e-04,  Loss_bcs: 8.838e-03, Loss_ut_ics: 1.530e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9300, Loss: 1.787e-03, Loss_res: 2.076e-04,  Loss_bcs: 1.547e-03, Loss_ut_ics: 3.280e-05,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9400, Loss: 7.442e-03, Loss_res: 2.243e-04,  Loss_bcs: 7.143e-03, Loss_ut_ics: 7.446e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9500, Loss: 2.522e-03, Loss_res: 4.266e-04,  Loss_bcs: 2.047e-03, Loss_ut_ics: 4.870e-05,, Time: 1.57
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9600, Loss: 9.574e-03, Loss_res: 9.522e-05,  Loss_bcs: 9.431e-03, Loss_ut_ics: 4.756e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9700, Loss: 5.702e-03, Loss_res: 5.548e-04,  Loss_bcs: 5.048e-03, Loss_ut_ics: 9.983e-05,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9800, Loss: 8.445e-03, Loss_res: 3.860e-04,  Loss_bcs: 7.960e-03, Loss_ut_ics: 9.846e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 9900, Loss: 4.286e-03, Loss_res: 1.376e-04,  Loss_bcs: 4.004e-03, Loss_ut_ics: 1.441e-04,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10000, Loss: 7.114e-03, Loss_res: 8.491e-05,  Loss_bcs: 6.975e-03, Loss_ut_ics: 5.450e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10100, Loss: 7.531e-03, Loss_res: 3.484e-04,  Loss_bcs: 6.761e-03, Loss_ut_ics: 4.219e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10200, Loss: 3.367e-03, Loss_res: 1.247e-04,  Loss_bcs: 3.213e-03, Loss_ut_ics: 2.964e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10300, Loss: 5.644e-03, Loss_res: 4.369e-04,  Loss_bcs: 5.098e-03, Loss_ut_ics: 1.098e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10400, Loss: 1.408e-03, Loss_res: 1.409e-04,  Loss_bcs: 1.229e-03, Loss_ut_ics: 3.870e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10500, Loss: 1.486e-02, Loss_res: 1.307e-04,  Loss_bcs: 1.436e-02, Loss_ut_ics: 3.692e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10600, Loss: 1.201e-02, Loss_res: 2.765e-04,  Loss_bcs: 1.146e-02, Loss_ut_ics: 2.752e-04,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10700, Loss: 4.221e-03, Loss_res: 2.210e-04,  Loss_bcs: 3.895e-03, Loss_ut_ics: 1.050e-04,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10800, Loss: 5.508e-03, Loss_res: 1.468e-04,  Loss_bcs: 5.321e-03, Loss_ut_ics: 4.025e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 10900, Loss: 7.783e-03, Loss_res: 9.928e-05,  Loss_bcs: 7.599e-03, Loss_ut_ics: 8.476e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11000, Loss: 1.837e-02, Loss_res: 1.197e-04,  Loss_bcs: 1.784e-02, Loss_ut_ics: 4.050e-04,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11100, Loss: 4.139e-03, Loss_res: 8.095e-05,  Loss_bcs: 4.016e-03, Loss_ut_ics: 4.229e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11200, Loss: 1.820e-02, Loss_res: 1.248e-04,  Loss_bcs: 1.770e-02, Loss_ut_ics: 3.753e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11300, Loss: 6.331e-03, Loss_res: 5.441e-04,  Loss_bcs: 5.594e-03, Loss_ut_ics: 1.929e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11400, Loss: 1.521e-02, Loss_res: 1.808e-04,  Loss_bcs: 1.501e-02, Loss_ut_ics: 1.996e-05,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11500, Loss: 2.644e-03, Loss_res: 1.463e-04,  Loss_bcs: 2.413e-03, Loss_ut_ics: 8.471e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11600, Loss: 8.763e-03, Loss_res: 1.261e-04,  Loss_bcs: 8.396e-03, Loss_ut_ics: 2.413e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11700, Loss: 5.505e-03, Loss_res: 1.318e-04,  Loss_bcs: 5.236e-03, Loss_ut_ics: 1.368e-04,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11800, Loss: 5.549e-03, Loss_res: 1.150e-04,  Loss_bcs: 5.364e-03, Loss_ut_ics: 7.029e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 11900, Loss: 4.141e-03, Loss_res: 4.039e-04,  Loss_bcs: 3.641e-03, Loss_ut_ics: 9.592e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12000, Loss: 1.653e-03, Loss_res: 2.112e-04,  Loss_bcs: 1.432e-03, Loss_ut_ics: 9.851e-06,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12100, Loss: 2.497e-03, Loss_res: 1.184e-04,  Loss_bcs: 2.363e-03, Loss_ut_ics: 1.528e-05,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12200, Loss: 1.181e-02, Loss_res: 1.702e-04,  Loss_bcs: 1.157e-02, Loss_ut_ics: 7.491e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12300, Loss: 1.011e-02, Loss_res: 1.209e-04,  Loss_bcs: 9.921e-03, Loss_ut_ics: 6.971e-05,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12400, Loss: 1.443e-02, Loss_res: 2.454e-04,  Loss_bcs: 1.408e-02, Loss_ut_ics: 1.043e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12500, Loss: 1.114e-02, Loss_res: 2.323e-04,  Loss_bcs: 1.080e-02, Loss_ut_ics: 1.105e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12600, Loss: 4.222e-03, Loss_res: 1.597e-04,  Loss_bcs: 3.977e-03, Loss_ut_ics: 8.502e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12700, Loss: 1.166e-03, Loss_res: 3.115e-04,  Loss_bcs: 8.260e-04, Loss_ut_ics: 2.899e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12800, Loss: 3.980e-03, Loss_res: 2.436e-04,  Loss_bcs: 3.628e-03, Loss_ut_ics: 1.078e-04,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 12900, Loss: 1.500e-03, Loss_res: 1.330e-04,  Loss_bcs: 1.351e-03, Loss_ut_ics: 1.594e-05,, Time: 1.29
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13000, Loss: 1.184e-02, Loss_res: 9.516e-05,  Loss_bcs: 1.171e-02, Loss_ut_ics: 3.175e-05,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13100, Loss: 1.326e-02, Loss_res: 1.339e-04,  Loss_bcs: 1.300e-02, Loss_ut_ics: 1.249e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13200, Loss: 1.001e-02, Loss_res: 9.293e-05,  Loss_bcs: 9.718e-03, Loss_ut_ics: 1.945e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13300, Loss: 5.652e-03, Loss_res: 1.151e-04,  Loss_bcs: 5.412e-03, Loss_ut_ics: 1.247e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13400, Loss: 1.472e-02, Loss_res: 1.765e-04,  Loss_bcs: 1.441e-02, Loss_ut_ics: 1.271e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13500, Loss: 7.650e-03, Loss_res: 2.011e-04,  Loss_bcs: 7.359e-03, Loss_ut_ics: 9.022e-05,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13600, Loss: 1.197e-02, Loss_res: 2.038e-04,  Loss_bcs: 1.169e-02, Loss_ut_ics: 7.302e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13700, Loss: 5.338e-03, Loss_res: 8.536e-05,  Loss_bcs: 5.215e-03, Loss_ut_ics: 3.737e-05,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13800, Loss: 3.814e-03, Loss_res: 1.123e-04,  Loss_bcs: 3.595e-03, Loss_ut_ics: 1.068e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 13900, Loss: 2.079e-02, Loss_res: 7.802e-05,  Loss_bcs: 2.047e-02, Loss_ut_ics: 2.420e-04,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14000, Loss: 7.034e-03, Loss_res: 1.281e-04,  Loss_bcs: 6.891e-03, Loss_ut_ics: 1.532e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14100, Loss: 5.324e-03, Loss_res: 1.068e-04,  Loss_bcs: 5.133e-03, Loss_ut_ics: 8.474e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14200, Loss: 5.914e-03, Loss_res: 1.417e-04,  Loss_bcs: 5.724e-03, Loss_ut_ics: 4.806e-05,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14300, Loss: 1.030e-02, Loss_res: 1.437e-04,  Loss_bcs: 9.996e-03, Loss_ut_ics: 1.642e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14400, Loss: 9.011e-03, Loss_res: 1.184e-04,  Loss_bcs: 8.813e-03, Loss_ut_ics: 7.962e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14500, Loss: 6.952e-03, Loss_res: 1.218e-04,  Loss_bcs: 6.765e-03, Loss_ut_ics: 6.500e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14600, Loss: 1.087e-02, Loss_res: 1.382e-04,  Loss_bcs: 1.068e-02, Loss_ut_ics: 5.429e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14700, Loss: 1.797e-03, Loss_res: 1.135e-04,  Loss_bcs: 1.618e-03, Loss_ut_ics: 6.484e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14800, Loss: 4.525e-03, Loss_res: 1.223e-04,  Loss_bcs: 4.337e-03, Loss_ut_ics: 6.538e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 14900, Loss: 7.026e-03, Loss_res: 1.393e-04,  Loss_bcs: 6.817e-03, Loss_ut_ics: 7.039e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15000, Loss: 1.238e-02, Loss_res: 1.869e-04,  Loss_bcs: 1.203e-02, Loss_ut_ics: 1.625e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15100, Loss: 1.603e-03, Loss_res: 1.508e-04,  Loss_bcs: 1.419e-03, Loss_ut_ics: 3.279e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15200, Loss: 1.111e-02, Loss_res: 1.657e-04,  Loss_bcs: 1.086e-02, Loss_ut_ics: 8.187e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15300, Loss: 1.329e-02, Loss_res: 6.881e-05,  Loss_bcs: 1.314e-02, Loss_ut_ics: 8.091e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15400, Loss: 8.458e-03, Loss_res: 2.213e-04,  Loss_bcs: 8.199e-03, Loss_ut_ics: 3.757e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15500, Loss: 6.225e-03, Loss_res: 2.256e-04,  Loss_bcs: 5.867e-03, Loss_ut_ics: 1.327e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15600, Loss: 8.626e-03, Loss_res: 1.179e-04,  Loss_bcs: 8.424e-03, Loss_ut_ics: 8.367e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15700, Loss: 2.963e-03, Loss_res: 9.362e-05,  Loss_bcs: 2.834e-03, Loss_ut_ics: 3.511e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15800, Loss: 7.160e-03, Loss_res: 2.172e-04,  Loss_bcs: 6.823e-03, Loss_ut_ics: 1.192e-04,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 15900, Loss: 2.339e-03, Loss_res: 1.182e-04,  Loss_bcs: 2.175e-03, Loss_ut_ics: 4.552e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16000, Loss: 7.854e-03, Loss_res: 2.875e-04,  Loss_bcs: 7.498e-03, Loss_ut_ics: 6.893e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16100, Loss: 1.088e-02, Loss_res: 1.171e-04,  Loss_bcs: 1.062e-02, Loss_ut_ics: 1.490e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16200, Loss: 4.047e-03, Loss_res: 1.719e-04,  Loss_bcs: 3.791e-03, Loss_ut_ics: 8.456e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16300, Loss: 2.106e-03, Loss_res: 1.159e-04,  Loss_bcs: 1.978e-03, Loss_ut_ics: 1.228e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16400, Loss: 1.094e-02, Loss_res: 1.338e-04,  Loss_bcs: 1.075e-02, Loss_ut_ics: 4.969e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16500, Loss: 9.477e-03, Loss_res: 1.868e-04,  Loss_bcs: 9.159e-03, Loss_ut_ics: 1.309e-04,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16600, Loss: 6.242e-03, Loss_res: 9.189e-05,  Loss_bcs: 6.059e-03, Loss_ut_ics: 9.143e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16700, Loss: 1.301e-02, Loss_res: 2.098e-04,  Loss_bcs: 1.276e-02, Loss_ut_ics: 3.731e-05,, Time: 1.57
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16800, Loss: 1.366e-02, Loss_res: 1.179e-04,  Loss_bcs: 1.352e-02, Loss_ut_ics: 2.504e-05,, Time: 1.60
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 16900, Loss: 4.497e-03, Loss_res: 9.300e-05,  Loss_bcs: 4.318e-03, Loss_ut_ics: 8.538e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17000, Loss: 5.003e-03, Loss_res: 1.039e-04,  Loss_bcs: 4.800e-03, Loss_ut_ics: 9.903e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17100, Loss: 8.441e-03, Loss_res: 1.289e-04,  Loss_bcs: 8.277e-03, Loss_ut_ics: 3.591e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17200, Loss: 6.268e-03, Loss_res: 1.160e-04,  Loss_bcs: 6.022e-03, Loss_ut_ics: 1.303e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17300, Loss: 5.785e-03, Loss_res: 1.925e-04,  Loss_bcs: 5.426e-03, Loss_ut_ics: 1.668e-04,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17400, Loss: 1.877e-03, Loss_res: 1.882e-04,  Loss_bcs: 1.653e-03, Loss_ut_ics: 3.537e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17500, Loss: 1.667e-02, Loss_res: 1.511e-04,  Loss_bcs: 1.641e-02, Loss_ut_ics: 1.090e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17600, Loss: 4.488e-03, Loss_res: 1.955e-04,  Loss_bcs: 4.254e-03, Loss_ut_ics: 3.900e-05,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17700, Loss: 1.326e-02, Loss_res: 1.318e-04,  Loss_bcs: 1.306e-02, Loss_ut_ics: 6.904e-05,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17800, Loss: 8.541e-03, Loss_res: 1.989e-04,  Loss_bcs: 8.176e-03, Loss_ut_ics: 1.653e-04,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 17900, Loss: 4.683e-03, Loss_res: 1.976e-04,  Loss_bcs: 4.446e-03, Loss_ut_ics: 3.952e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18000, Loss: 1.236e-02, Loss_res: 1.514e-04,  Loss_bcs: 1.204e-02, Loss_ut_ics: 1.709e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18100, Loss: 1.281e-02, Loss_res: 1.725e-04,  Loss_bcs: 1.245e-02, Loss_ut_ics: 1.804e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18200, Loss: 1.648e-02, Loss_res: 1.309e-04,  Loss_bcs: 1.626e-02, Loss_ut_ics: 9.429e-05,, Time: 1.57
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18300, Loss: 1.962e-02, Loss_res: 1.641e-04,  Loss_bcs: 1.920e-02, Loss_ut_ics: 2.552e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18400, Loss: 1.429e-02, Loss_res: 2.281e-04,  Loss_bcs: 1.397e-02, Loss_ut_ics: 9.289e-05,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18500, Loss: 4.628e-03, Loss_res: 1.222e-04,  Loss_bcs: 4.399e-03, Loss_ut_ics: 1.064e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18600, Loss: 4.103e-03, Loss_res: 5.290e-05,  Loss_bcs: 3.935e-03, Loss_ut_ics: 1.159e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18700, Loss: 2.604e-03, Loss_res: 2.061e-04,  Loss_bcs: 2.354e-03, Loss_ut_ics: 4.382e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18800, Loss: 8.428e-03, Loss_res: 1.122e-04,  Loss_bcs: 8.163e-03, Loss_ut_ics: 1.521e-04,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 18900, Loss: 1.697e-02, Loss_res: 9.043e-05,  Loss_bcs: 1.684e-02, Loss_ut_ics: 3.654e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19000, Loss: 1.992e-03, Loss_res: 7.360e-05,  Loss_bcs: 1.909e-03, Loss_ut_ics: 9.577e-06,, Time: 1.64
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19100, Loss: 3.637e-02, Loss_res: 6.746e-05,  Loss_bcs: 3.589e-02, Loss_ut_ics: 4.070e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19200, Loss: 1.480e-02, Loss_res: 2.399e-04,  Loss_bcs: 1.440e-02, Loss_ut_ics: 1.652e-04,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19300, Loss: 1.125e-02, Loss_res: 1.722e-04,  Loss_bcs: 1.091e-02, Loss_ut_ics: 1.621e-04,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19400, Loss: 6.296e-03, Loss_res: 1.704e-04,  Loss_bcs: 5.995e-03, Loss_ut_ics: 1.304e-04,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19500, Loss: 1.020e-03, Loss_res: 1.658e-04,  Loss_bcs: 8.447e-04, Loss_ut_ics: 9.066e-06,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19600, Loss: 1.576e-03, Loss_res: 1.398e-04,  Loss_bcs: 1.314e-03, Loss_ut_ics: 1.225e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19700, Loss: 3.143e-03, Loss_res: 1.181e-04,  Loss_bcs: 3.001e-03, Loss_ut_ics: 2.342e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19800, Loss: 1.885e-02, Loss_res: 1.154e-04,  Loss_bcs: 1.858e-02, Loss_ut_ics: 1.572e-04,, Time: 1.56
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 19900, Loss: 2.844e-03, Loss_res: 1.084e-04,  Loss_bcs: 2.692e-03, Loss_ut_ics: 4.339e-05,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20000, Loss: 3.504e-03, Loss_res: 1.086e-04,  Loss_bcs: 3.376e-03, Loss_ut_ics: 1.953e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20100, Loss: 1.208e-02, Loss_res: 1.059e-04,  Loss_bcs: 1.189e-02, Loss_ut_ics: 7.743e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20200, Loss: 1.332e-02, Loss_res: 1.200e-04,  Loss_bcs: 1.311e-02, Loss_ut_ics: 9.036e-05,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20300, Loss: 3.797e-03, Loss_res: 2.069e-04,  Loss_bcs: 3.527e-03, Loss_ut_ics: 6.354e-05,, Time: 1.61
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20400, Loss: 5.701e-03, Loss_res: 5.948e-05,  Loss_bcs: 5.603e-03, Loss_ut_ics: 3.880e-05,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20500, Loss: 1.731e-02, Loss_res: 1.263e-04,  Loss_bcs: 1.704e-02, Loss_ut_ics: 1.421e-04,, Time: 1.53
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20600, Loss: 2.407e-03, Loss_res: 6.421e-05,  Loss_bcs: 2.314e-03, Loss_ut_ics: 2.889e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20700, Loss: 1.439e-02, Loss_res: 1.581e-04,  Loss_bcs: 1.413e-02, Loss_ut_ics: 1.022e-04,, Time: 1.30
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20800, Loss: 7.009e-03, Loss_res: 1.101e-04,  Loss_bcs: 6.824e-03, Loss_ut_ics: 7.460e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 20900, Loss: 1.088e-02, Loss_res: 1.267e-04,  Loss_bcs: 1.070e-02, Loss_ut_ics: 5.364e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21000, Loss: 1.001e-02, Loss_res: 6.160e-05,  Loss_bcs: 9.854e-03, Loss_ut_ics: 8.915e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21100, Loss: 1.734e-03, Loss_res: 2.408e-04,  Loss_bcs: 1.458e-03, Loss_ut_ics: 3.448e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21200, Loss: 3.544e-03, Loss_res: 1.167e-04,  Loss_bcs: 3.379e-03, Loss_ut_ics: 4.775e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21300, Loss: 1.415e-02, Loss_res: 1.851e-04,  Loss_bcs: 1.382e-02, Loss_ut_ics: 1.449e-04,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21400, Loss: 6.334e-03, Loss_res: 1.335e-04,  Loss_bcs: 6.097e-03, Loss_ut_ics: 1.042e-04,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21500, Loss: 4.917e-03, Loss_res: 1.635e-04,  Loss_bcs: 4.660e-03, Loss_ut_ics: 9.307e-05,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21600, Loss: 9.181e-03, Loss_res: 1.200e-04,  Loss_bcs: 8.994e-03, Loss_ut_ics: 6.771e-05,, Time: 1.54
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21700, Loss: 3.326e-03, Loss_res: 1.109e-04,  Loss_bcs: 3.152e-03, Loss_ut_ics: 6.365e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21800, Loss: 1.005e-02, Loss_res: 1.253e-04,  Loss_bcs: 9.775e-03, Loss_ut_ics: 1.482e-04,, Time: 1.48
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 21900, Loss: 3.022e-03, Loss_res: 9.777e-05,  Loss_bcs: 2.859e-03, Loss_ut_ics: 6.489e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22000, Loss: 1.124e-03, Loss_res: 9.722e-05,  Loss_bcs: 9.891e-04, Loss_ut_ics: 3.785e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22100, Loss: 1.440e-02, Loss_res: 7.972e-05,  Loss_bcs: 1.412e-02, Loss_ut_ics: 1.941e-04,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22200, Loss: 1.632e-03, Loss_res: 1.182e-04,  Loss_bcs: 1.466e-03, Loss_ut_ics: 4.757e-05,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22300, Loss: 1.991e-03, Loss_res: 1.056e-04,  Loss_bcs: 1.870e-03, Loss_ut_ics: 1.519e-05,, Time: 1.67
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22400, Loss: 4.734e-03, Loss_res: 1.837e-04,  Loss_bcs: 4.507e-03, Loss_ut_ics: 4.349e-05,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22500, Loss: 7.781e-03, Loss_res: 8.784e-05,  Loss_bcs: 7.642e-03, Loss_ut_ics: 5.059e-05,, Time: 1.26
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22600, Loss: 1.072e-02, Loss_res: 6.607e-05,  Loss_bcs: 1.059e-02, Loss_ut_ics: 6.628e-05,, Time: 1.24
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22700, Loss: 9.216e-03, Loss_res: 7.659e-05,  Loss_bcs: 9.061e-03, Loss_ut_ics: 7.762e-05,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22800, Loss: 1.456e-03, Loss_res: 1.532e-04,  Loss_bcs: 1.293e-03, Loss_ut_ics: 9.447e-06,, Time: 1.23
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 22900, Loss: 1.776e-03, Loss_res: 2.076e-04,  Loss_bcs: 1.538e-03, Loss_ut_ics: 3.079e-05,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23000, Loss: 3.113e-03, Loss_res: 1.012e-04,  Loss_bcs: 2.990e-03, Loss_ut_ics: 2.145e-05,, Time: 1.28
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23100, Loss: 9.471e-03, Loss_res: 8.411e-05,  Loss_bcs: 9.276e-03, Loss_ut_ics: 1.111e-04,, Time: 1.23
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23200, Loss: 1.536e-02, Loss_res: 7.969e-05,  Loss_bcs: 1.513e-02, Loss_ut_ics: 1.496e-04,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23300, Loss: 1.073e-02, Loss_res: 3.072e-04,  Loss_bcs: 1.034e-02, Loss_ut_ics: 8.235e-05,, Time: 1.27
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23400, Loss: 5.709e-03, Loss_res: 6.489e-05,  Loss_bcs: 5.595e-03, Loss_ut_ics: 4.979e-05,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23500, Loss: 1.028e-02, Loss_res: 1.754e-04,  Loss_bcs: 1.004e-02, Loss_ut_ics: 6.332e-05,, Time: 1.23
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23600, Loss: 1.716e-02, Loss_res: 1.608e-04,  Loss_bcs: 1.688e-02, Loss_ut_ics: 1.205e-04,, Time: 1.24
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23700, Loss: 1.614e-03, Loss_res: 2.635e-04,  Loss_bcs: 1.329e-03, Loss_ut_ics: 2.106e-05,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23800, Loss: 8.831e-03, Loss_res: 6.237e-05,  Loss_bcs: 8.703e-03, Loss_ut_ics: 6.523e-05,, Time: 1.26
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 23900, Loss: 1.134e-02, Loss_res: 5.553e-05,  Loss_bcs: 1.123e-02, Loss_ut_ics: 6.002e-05,, Time: 1.25
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24000, Loss: 1.963e-03, Loss_res: 8.996e-05,  Loss_bcs: 1.861e-03, Loss_ut_ics: 1.220e-05,, Time: 1.21
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24100, Loss: 1.706e-02, Loss_res: 1.719e-04,  Loss_bcs: 1.685e-02, Loss_ut_ics: 2.966e-05,, Time: 1.26
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24200, Loss: 1.955e-02, Loss_res: 4.922e-05,  Loss_bcs: 1.937e-02, Loss_ut_ics: 1.301e-04,, Time: 1.28
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24300, Loss: 8.970e-03, Loss_res: 1.160e-04,  Loss_bcs: 8.796e-03, Loss_ut_ics: 5.778e-05,, Time: 1.23
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24400, Loss: 1.716e-02, Loss_res: 2.441e-04,  Loss_bcs: 1.676e-02, Loss_ut_ics: 1.514e-04,, Time: 1.23
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24500, Loss: 3.449e-03, Loss_res: 1.935e-04,  Loss_bcs: 3.202e-03, Loss_ut_ics: 5.334e-05,, Time: 1.27
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24600, Loss: 6.662e-03, Loss_res: 9.652e-05,  Loss_bcs: 6.553e-03, Loss_ut_ics: 1.264e-05,, Time: 1.36
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24700, Loss: 4.302e-03, Loss_res: 1.507e-04,  Loss_bcs: 4.091e-03, Loss_ut_ics: 6.037e-05,, Time: 1.49
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24800, Loss: 2.495e-03, Loss_res: 9.968e-05,  Loss_bcs: 2.376e-03, Loss_ut_ics: 2.003e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 24900, Loss: 8.855e-03, Loss_res: 1.776e-04,  Loss_bcs: 8.526e-03, Loss_ut_ics: 1.517e-04,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25000, Loss: 1.419e-02, Loss_res: 1.118e-04,  Loss_bcs: 1.394e-02, Loss_ut_ics: 1.442e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25100, Loss: 1.491e-02, Loss_res: 1.102e-04,  Loss_bcs: 1.470e-02, Loss_ut_ics: 9.701e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25200, Loss: 1.072e-02, Loss_res: 1.050e-04,  Loss_bcs: 1.044e-02, Loss_ut_ics: 1.695e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25300, Loss: 1.659e-03, Loss_res: 8.261e-05,  Loss_bcs: 1.556e-03, Loss_ut_ics: 2.019e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25400, Loss: 4.319e-03, Loss_res: 9.101e-05,  Loss_bcs: 4.133e-03, Loss_ut_ics: 9.519e-05,, Time: 1.55
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25500, Loss: 1.816e-03, Loss_res: 2.156e-04,  Loss_bcs: 1.556e-03, Loss_ut_ics: 4.474e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25600, Loss: 1.246e-02, Loss_res: 7.277e-05,  Loss_bcs: 1.224e-02, Loss_ut_ics: 1.481e-04,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25700, Loss: 1.356e-02, Loss_res: 1.069e-04,  Loss_bcs: 1.328e-02, Loss_ut_ics: 1.698e-04,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25800, Loss: 5.349e-03, Loss_res: 9.517e-05,  Loss_bcs: 5.205e-03, Loss_ut_ics: 4.921e-05,, Time: 1.58
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 25900, Loss: 7.206e-03, Loss_res: 5.423e-05,  Loss_bcs: 7.078e-03, Loss_ut_ics: 7.366e-05,, Time: 1.36
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26000, Loss: 5.547e-03, Loss_res: 7.724e-05,  Loss_bcs: 5.400e-03, Loss_ut_ics: 6.934e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26100, Loss: 7.166e-03, Loss_res: 9.966e-05,  Loss_bcs: 7.011e-03, Loss_ut_ics: 5.529e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26200, Loss: 3.324e-03, Loss_res: 5.136e-05,  Loss_bcs: 3.269e-03, Loss_ut_ics: 3.513e-06,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26300, Loss: 1.303e-02, Loss_res: 4.650e-05,  Loss_bcs: 1.287e-02, Loss_ut_ics: 1.159e-04,, Time: 1.52
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26400, Loss: 2.857e-03, Loss_res: 1.071e-04,  Loss_bcs: 2.629e-03, Loss_ut_ics: 1.212e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26500, Loss: 1.737e-03, Loss_res: 1.640e-04,  Loss_bcs: 1.528e-03, Loss_ut_ics: 4.590e-05,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26600, Loss: 3.601e-03, Loss_res: 2.002e-04,  Loss_bcs: 3.348e-03, Loss_ut_ics: 5.277e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26700, Loss: 1.385e-03, Loss_res: 1.674e-04,  Loss_bcs: 1.189e-03, Loss_ut_ics: 2.841e-05,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26800, Loss: 4.705e-03, Loss_res: 6.241e-05,  Loss_bcs: 4.567e-03, Loss_ut_ics: 7.511e-05,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 26900, Loss: 3.113e-03, Loss_res: 1.421e-04,  Loss_bcs: 2.956e-03, Loss_ut_ics: 1.547e-05,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27000, Loss: 2.208e-03, Loss_res: 1.869e-04,  Loss_bcs: 2.001e-03, Loss_ut_ics: 1.993e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27100, Loss: 1.349e-02, Loss_res: 1.096e-04,  Loss_bcs: 1.314e-02, Loss_ut_ics: 2.374e-04,, Time: 1.34
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27200, Loss: 6.894e-03, Loss_res: 2.768e-04,  Loss_bcs: 6.510e-03, Loss_ut_ics: 1.068e-04,, Time: 1.35
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27300, Loss: 1.266e-02, Loss_res: 1.796e-04,  Loss_bcs: 1.245e-02, Loss_ut_ics: 2.942e-05,, Time: 1.51
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27400, Loss: 5.277e-03, Loss_res: 8.914e-05,  Loss_bcs: 5.098e-03, Loss_ut_ics: 8.991e-05,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27500, Loss: 1.355e-02, Loss_res: 1.091e-04,  Loss_bcs: 1.335e-02, Loss_ut_ics: 9.713e-05,, Time: 1.33
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27600, Loss: 6.195e-03, Loss_res: 1.774e-04,  Loss_bcs: 5.929e-03, Loss_ut_ics: 8.903e-05,, Time: 1.39
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27700, Loss: 6.110e-03, Loss_res: 1.857e-04,  Loss_bcs: 5.760e-03, Loss_ut_ics: 1.648e-04,, Time: 1.45
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27800, Loss: 3.777e-03, Loss_res: 1.489e-04,  Loss_bcs: 3.582e-03, Loss_ut_ics: 4.613e-05,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 27900, Loss: 6.420e-03, Loss_res: 4.334e-05,  Loss_bcs: 6.258e-03, Loss_ut_ics: 1.189e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28000, Loss: 4.167e-03, Loss_res: 9.837e-05,  Loss_bcs: 4.017e-03, Loss_ut_ics: 5.096e-05,, Time: 1.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28100, Loss: 5.195e-03, Loss_res: 8.222e-05,  Loss_bcs: 5.054e-03, Loss_ut_ics: 5.874e-05,, Time: 1.50
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28200, Loss: 7.420e-03, Loss_res: 1.544e-04,  Loss_bcs: 7.214e-03, Loss_ut_ics: 5.153e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28300, Loss: 8.539e-03, Loss_res: 5.221e-05,  Loss_bcs: 8.375e-03, Loss_ut_ics: 1.112e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28400, Loss: 1.148e-02, Loss_res: 1.593e-04,  Loss_bcs: 1.115e-02, Loss_ut_ics: 1.630e-04,, Time: 1.37
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28500, Loss: 1.559e-02, Loss_res: 5.712e-05,  Loss_bcs: 1.541e-02, Loss_ut_ics: 1.238e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28600, Loss: 1.123e-02, Loss_res: 7.038e-05,  Loss_bcs: 1.106e-02, Loss_ut_ics: 9.338e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28700, Loss: 1.466e-02, Loss_res: 4.488e-05,  Loss_bcs: 1.447e-02, Loss_ut_ics: 1.489e-04,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28800, Loss: 1.004e-02, Loss_res: 1.389e-04,  Loss_bcs: 9.782e-03, Loss_ut_ics: 1.176e-04,, Time: 1.40
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 28900, Loss: 4.230e-03, Loss_res: 9.994e-05,  Loss_bcs: 3.997e-03, Loss_ut_ics: 1.332e-04,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29000, Loss: 1.252e-02, Loss_res: 8.036e-05,  Loss_bcs: 1.231e-02, Loss_ut_ics: 1.309e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29100, Loss: 7.850e-03, Loss_res: 1.195e-04,  Loss_bcs: 7.649e-03, Loss_ut_ics: 8.175e-05,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29200, Loss: 3.050e-03, Loss_res: 7.027e-05,  Loss_bcs: 2.921e-03, Loss_ut_ics: 5.855e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29300, Loss: 7.557e-03, Loss_res: 6.141e-05,  Loss_bcs: 7.452e-03, Loss_ut_ics: 4.366e-05,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29400, Loss: 2.699e-03, Loss_res: 1.071e-04,  Loss_bcs: 2.561e-03, Loss_ut_ics: 3.147e-05,, Time: 1.43
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29500, Loss: 1.251e-02, Loss_res: 4.413e-05,  Loss_bcs: 1.232e-02, Loss_ut_ics: 1.390e-04,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29600, Loss: 8.768e-03, Loss_res: 5.546e-05,  Loss_bcs: 8.607e-03, Loss_ut_ics: 1.057e-04,, Time: 1.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29700, Loss: 3.359e-03, Loss_res: 1.280e-04,  Loss_bcs: 3.169e-03, Loss_ut_ics: 6.190e-05,, Time: 1.41
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29800, Loss: 7.995e-03, Loss_res: 1.029e-04,  Loss_bcs: 7.785e-03, Loss_ut_ics: 1.069e-04,, Time: 1.42
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 29900, Loss: 1.280e-02, Loss_res: 6.136e-05,  Loss_bcs: 1.260e-02, Loss_ut_ics: 1.371e-04,, Time: 1.44
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 30000, Loss: 6.137e-03, Loss_res: 7.162e-05,  Loss_bcs: 6.031e-03, Loss_ut_ics: 3.454e-05,, Time: 1.38
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
R_star = r(X_star, a, c)

# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)

error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))
# Out:
# Relative L2 error_u: 3.509821e+00

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')

R_star = griddata(X_star, R_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, R_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(R_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
