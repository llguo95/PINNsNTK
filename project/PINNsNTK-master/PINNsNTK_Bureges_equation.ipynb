# %%
# Switch to tensorflow 1.x
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
from Compute_Jacobian import jacobian # Please download 'Compute_Jacobian.py' in the repository 
import numpy as np
import timeit
from scipy.interpolate import griddata
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name = None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name
    def sample(self, N):
        x = self.coords[0:1,:] + (self.coords[1:2,:]-self.coords[0:1,:])*np.random.rand(N, self.dim)
        y = self.func(x)
        return x, y

# %%
class PINN:
    # Initialize the class
    def __init__(self, layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size):
        # Normalization 
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_t, self.sigma_t = self.mu_X[0], self.sigma_X[0]
        self.mu_x, self.sigma_x = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.operator = operator
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers = layers
        self.weights, self.biases = self.initialize_NN(layers)
        
        # weights
        self.lam_u_val = np.array(1.0)
        self.lam_ut_val = np.array(1.0)
        self.lam_r_val = np.array(1.0)
      
        # Wave constant
        self.c = tf.constant(c, dtype=tf.float32)
        
        self.kernel_size = kernel_size # Size of the NTK matrix

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # Define placeholders and computational graph
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u_ics_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        self.lam_u_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_ut_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        self.lam_r_tf = tf.placeholder(tf.float32, shape=self.lam_u_val.shape)
        

        # Define placeholders for NTK computation
        D1 = self.kernel_size    # boundary
        D2 = self.kernel_size    # ut   
        D3 = self.kernel_size    # residual  D1 = D3 = 3D2

        self.t_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        self.x_u_ntk_tf = tf.placeholder(tf.float32, shape=(D1, 1))
        
        self.t_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        self.x_ut_ntk_tf = tf.placeholder(tf.float32, shape=(D2, 1))
        
        self.t_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))
        self.x_r_ntk_tf = tf.placeholder(tf.float32, shape=(D3, 1))

        # Evaluate predictions
        self.u_ics_pred = self.net_u(self.t_ics_tf, self.x_ics_tf)
        self.u_t_ics_pred = self.net_u_t(self.t_ics_tf, self.x_ics_tf)
        self.u_bc1_pred = self.net_u(self.t_bc1_tf, self.x_bc1_tf)
        self.u_bc2_pred = self.net_u(self.t_bc2_tf, self.x_bc2_tf)

        self.u_pred = self.net_u(self.t_u_tf, self.x_u_tf)
        self.r_pred = self.net_r(self.t_r_tf, self.x_r_tf)
        
        # Define predictions for NTK computation
        self.u_ntk_pred = self.net_u(self.t_u_ntk_tf, self.x_u_ntk_tf)
        self.ut_ntk_pred = self.net_u_t(self.t_ut_ntk_tf, self.x_ut_ntk_tf)
        self.r_ntk_pred = self.net_r(self.t_r_ntk_tf, self.x_r_ntk_tf)

        # Boundary loss and Initial loss
        self.loss_ics_u = tf.reduce_mean(tf.square(self.u_ics_tf - self.u_ics_pred))
        self.loss_ics_u_t = tf.reduce_mean(tf.square(self.u_t_ics_pred))
        self.loss_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred))
        self.loss_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred))

        self.loss_bcs = self.loss_ics_u + self.loss_bc1 + self.loss_bc2

        # Residual loss
        self.loss_res = tf.reduce_mean(tf.square(self.r_pred))

        # Total loss
        self.loss = self.lam_r_tf * self.loss_res + self.lam_u_tf * self.loss_bcs + self.lam_ut_tf * self.loss_ics_u_t 

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logger
        self.loss_bcs_log = []
        self.loss_ut_ics_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Compute the Jacobian for weights and biases in each hidden layer  
        self.J_u = self.compute_jacobian(self.u_ntk_pred)
        self.J_ut = self.compute_jacobian(self.ut_ntk_pred)
        self.J_r = self.compute_jacobian(self.r_ntk_pred)
        
        self.K_u = self.compute_ntk(self.J_u, D1, self.J_u, D1)
        self.K_ut = self.compute_ntk(self.J_ut, D2, self.J_ut, D2)
        self.K_r = self.compute_ntk(self.J_r, D3, self.J_r, D3)
        
        # NTK logger 
        self.K_u_log = []
        self.K_ut_log = []
        self.K_r_log = []
        
        # weights logger
        self.lam_u_log = []
        self.lam_ut_log = []
        self.lam_r_log = []
        
         # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random.normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                               dtype=tf.float32)

        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u
    def net_u(self, t, x):
        u = self.forward_pass(tf.concat([t, x], 1),
                              self.layers,
                              self.weights,
                              self.biases)
        return u

    # Forward pass for du/dt
    def net_u_t(self, t, x):
        u_t = tf.gradients(self.net_u(t, x), t)[0] / self.sigma_t
        return u_t

    # Forward pass for the residual
    def net_r(self, t, x):
        u = self.net_u(t, x)
        residual = self.operator(u, t, x,
                                 self.c,
                                 self.sigma_t,
                                 self.sigma_x)
        return residual
    
    
    # Compute Jacobian for each weights and biases in each layer and retrun a list 
    def compute_jacobian(self, f):
        J_list =[]
        L = len(self.weights)    
        for i in range(L):
            J_w = jacobian(f, self.weights[i])
            J_list.append(J_w)
     
        for i in range(L):
            J_b = jacobian(f, self.biases[i])
            J_list.append(J_b)
        return J_list
    
    # Compute the empirical NTK = J J^T
    def compute_ntk(self, J1_list, D1, J2_list, D2):

        N = len(J1_list)
        
        Ker = tf.zeros((D1,D2))
        for k in range(N):
            J1 = tf.reshape(J1_list[k], shape=(D1,-1))
            J2 = tf.reshape(J2_list[k], shape=(D2,-1))
            
            K = tf.matmul(J1, tf.transpose(J2))
            Ker = Ker + K
        return Ker

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

        # Trains the model by minimizing the MSE loss

    def train(self, nIter=10000, batch_size=128, log_NTK=False, update_lam=False):

        start_time = timeit.default_timer()
        for it in range(nIter):
            # Fetch boundary mini-batches
            X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size // 3)
            X_bc1_batch, _ = self.fetch_minibatch(self.bcs_sampler[0], batch_size // 3)
            X_bc2_batch, _ = self.fetch_minibatch(self.bcs_sampler[1], batch_size // 3)
            
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.t_ics_tf: X_ics_batch[:, 0:1], self.x_ics_tf: X_ics_batch[:, 1:2],
                       self.u_ics_tf: u_ics_batch,
                       self.t_bc1_tf: X_bc1_batch[:, 0:1], self.x_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 0:1], self.x_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 0:1], self.x_r_tf: X_res_batch[:, 1:2],
                       self.lam_u_tf: self.lam_u_val,
                       self.lam_ut_tf: self.lam_ut_val,
                       self.lam_r_tf: self.lam_r_val}

            # Run the Tensorflow session to minimize the loss
            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time

                loss_value = self.sess.run(self.loss, tf_dict)
                loss_bcs_value = self.sess.run(self.loss_bcs, tf_dict)
                loss_ics_ut_value = self.sess.run(self.loss_ics_u_t, tf_dict)
                loss_res_value = self.sess.run(self.loss_res, tf_dict)

                # Store losses
                self.loss_bcs_log.append(loss_bcs_value)
                self.loss_res_log.append(loss_res_value)
                self.loss_ut_ics_log.append(loss_ics_ut_value)

                print('It: %d, Loss: %.3e, Loss_res: %.3e,  Loss_bcs: %.3e, Loss_ut_ics: %.3e,, Time: %.2f' %
                      (it, loss_value, loss_res_value, loss_bcs_value, loss_ics_ut_value, elapsed))
                
                print('lambda_u: {:.3e}'.format(self.lam_u_val))
                print('lambda_ut: {:.3e}'.format(self.lam_ut_val))
                print('lambda_r: {:.3e}'.format(self.lam_r_val))

                start_time = timeit.default_timer()
            
          
            if log_NTK:
                if it % 100 == 0:
                        print("Compute NTK...")
                        X_bc_batch = np.vstack([X_ics_batch, X_bc1_batch, X_bc2_batch])
                        X_ics_batch, u_ics_batch = self.fetch_minibatch(self.ics_sampler, batch_size )

                        tf_dict = {self.t_u_ntk_tf: X_bc_batch[:,0:1], self.x_u_ntk_tf: X_bc_batch[:, 1:2],
                                   self.t_ut_ntk_tf: X_ics_batch[:,0:1], self.x_ut_ntk_tf: X_ics_batch[:, 1:2],
                                   self.t_r_ntk_tf: X_res_batch[:,0:1], self.x_r_ntk_tf: X_res_batch[:, 1:2]}
                        
                        K_u_value, K_ut_value, K_r_value =  self.sess.run([self.K_u, self.K_ut, self.K_r], tf_dict)
                        
                        trace_K = np.trace(K_u_value) + np.trace(K_ut_value) + \
                                       np.trace(K_r_value)

                        # Store NTK matrices
                        self.K_u_log.append(K_u_value)
                        self.K_ut_log.append(K_ut_value)
                        self.K_r_log.append(K_r_value)
                        
                        if update_lam:

                          self.lam_u_val = trace_K / np.trace(K_u_value)
                          self.lam_ut_val = trace_K /np.trace(K_ut_value)
                          self.lam_r_val = trace_K / np.trace(K_r_value)

                          # Store NTK weights
                          self.lam_u_log.append(self.lam_u_val)
                          self.lam_ut_log.append(self.lam_ut_val)
                          self.lam_r_log.append(self.lam_r_val)
                        
                        
          
    # Evaluates predictions at test points
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 0:1], self.x_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

        # Evaluates predictions at test points

    def predict_r(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_r_tf: X_star[:, 0:1], self.x_r_tf: X_star[:, 1:2]}
        r_star = self.sess.run(self.r_pred, tf_dict)
        return r_star

# %%
# Define the exact solution and its derivatives
def u(x, a, c):
    """
    exact solution
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    
    return np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * np.exp(-(2*np.pi)**2*2*c*t)
    
    #return np.sin(np.pi * x) * np.cos(c * np.pi * t) + \
    #a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    # first derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = -np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * (2*np.pi)**2*c * np.exp(-(2*np.pi)**2*c*t)
    return u_t

def u_tt(x, a, c):
    # second derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * (2*np.pi)**4*c**2 * np.exp(-(2*np.pi)**2*c*t)


    return u_tt

def u_xx(x, a, c):
    # second derivitive of x
    t = x[:,0:1]
    x = x[:,1:2]
    u_xx = - np.pi**2 * np.sin( np.pi * x) * np.cos(c * np.pi * t) - \
              a * (2 * c * np.pi)** 2 * np.sin(2 * c * np.pi* x) * np.cos(4 * c * np.pi * t)
    return  u_xx


def r(x, a, c):
    # THE pde its selft
    return u_tt(x, a, c) - c**2 * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    # gradient
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - c**2 * u_xx
    return residual

# %%
# Define the exact solution and its derivatives
def u(x, a, c):
    """
    exact solution
    :param x: x = (t, x)
    """
    t = x[:,0:1]
    x = x[:,1:2]
    
    return np.cos(a*(np.pi)*x)*np.exp(-c*(a*np.pi)**2*t)
    
    #return np.sin(np.pi * x) * np.cos(c * np.pi * t) + \
    #a * np.sin(2 * c * np.pi* x) * np.cos(4 * c  * np.pi * t)

def u_t(x,a, c):
    # first derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_t = np.cos(a*(np.pi)*x)*(-c*(a*np.pi)**2)*np.exp(-c*(a*np.pi)**2*t)
    return u_t

def u_tt(x, a, c):
    # second derivitive of t
    t = x[:,0:1]
    x = x[:,1:2]
    u_tt = -c*(a*np.pi)**2*np.cos(a*(np.pi)*x)*(-c*(a*np.pi)**2)*np.exp(-c*(a*np.pi)**2*t)
    return u_tt

def u_xx(x, a, c):
    # second derivitive of x
    t = x[:,0:1]
    x = x[:,1:2]
    
    u_xx = -np.exp(-x**2/2*a**2) * (np.cos(2*np.pi*x) * (2*np.pi)**2\
            + np.sin(2*np.pi*x) * (2*np.pi)**3*x/a**2) * np.exp(-(2*np.pi)**2*c*t)
    return  u_xx

def u_x(x,a,c):
    t = x[:,0:1]
    x = x[:,1:2]
    return (-x/a**2) * np.exp(-x**2/2*a**2) * np.cos(2*np.pi*x) * np.exp(-(2*np.pi)**2*c*t) - \
(2*np.pi) * np.exp(-x**2/2*a**2) * np.sin(2*np.pi*x) * np.exp(-(2*np.pi)**2*c*t)


def r(x, a, c):
    # THE pde its selft
    return u_tt(x, a, c)+u(x,a,c)*u_x(x,a,x) - c * u_xx(x, a, c)

def operator(u, t, x, c, sigma_t=1.0, sigma_x=1.0):
    # gradient
    u_t = tf.gradients(u, t)[0] / sigma_t
    u_x = tf.gradients(u, x)[0] / sigma_x
    u_tt = tf.gradients(u_t, t)[0] / sigma_t
    u_xx = tf.gradients(u_x, x)[0] / sigma_x
    residual = u_tt - u*u_x-c* u_xx
    return residual

# %%
# Domain boundaries
ics_coords = np.array([[0.0, 0.0],
                        [0.0, 1.0]])
bc1_coords = np.array([[0.0, 0.0],
                        [1.0, 0.0]])
bc2_coords = np.array([[0.0, 1.0],
                        [1.0, 1.0]])
dom_coords = np.array([[0.0, 0.0],
                        [1.0, 1.0]])

# Create initial conditions samplers
ics_sampler = Sampler(2, ics_coords, lambda x: u(x, a, c), name='Initial Condition 1')

# Create boundary conditions samplers
bc1 = Sampler(2, bc1_coords, lambda x: u(x, a, c), name='Dirichlet BC1')
bc2 = Sampler(2, bc2_coords, lambda x: u(x, a, c), name='Dirichlet BC2')
bcs_sampler = [bc1, bc2]

# Create residual sampler
res_sampler = Sampler(2, dom_coords, lambda x: r(x, a, c), name='Forcing')

# %%
# Define PINN model
a = 0.5
c = 2

layers = [2, 500, 500, 500, 1]
kernel_size = 300
model = PINN(layers, operator, ics_sampler, bcs_sampler, res_sampler, c, kernel_size)
# Out:
# WARNING:tensorflow:From /Users/asdfasd/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Device mapping:
# 2023-03-28 09:37:20.744080: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-28 09:37:20.745782: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# 2023-03-28 09:37:21.850262: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body/gradients/MatMul_24_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:21.921306: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_1/gradients/MatMul_25_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:21.979730: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_2/gradients/MatMul_26_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:22.032678: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_3/gradients/MatMul_27_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:22.477175: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_8/gradients/MatMul_28_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:22.620603: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_9/gradients/MatMul_29_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:22.744680: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_10/gradients/MatMul_30_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.067785: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_16/gradients/MatMul_32_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.097573: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_16/gradients/gradients_9/gradients_7/MatMul_32_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.127341: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_16/gradients/gradients_8/gradients_6/MatMul_32_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.807491: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_17/gradients/MatMul_33_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.837844: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_17/gradients/gradients_9/gradients_7/MatMul_33_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:24.871687: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_17/gradients/gradients_8/gradients_6/MatMul_33_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:25.290079: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_18/gradients/MatMul_34_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:25.326278: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_18/gradients/gradients_9/gradients_7/MatMul_34_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:25.361488: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_18/gradients/gradients_8/gradients_6/MatMul_34_grad/MatMul_grad/MatMul_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:25.792515: E tensorflow/core/common_runtime/executor.cc:642] Executor failed to create kernel. Internal: No function library
# 	 [[{{node loop_body_19/gradients/MatMul_35_grad/MatMul_1/pfor/cond}}]]
# 2023-03-28 09:37:28.031867: I tensorflow/core/common_runtime/placer.cc:54] random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031898: I tensorflow/core/common_runtime/placer.cc:54] random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031906: I tensorflow/core/common_runtime/placer.cc:54] random_normal: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031913: I tensorflow/core/common_runtime/placer.cc:54] mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031921: I tensorflow/core/common_runtime/placer.cc:54] Variable/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031927: I tensorflow/core/common_runtime/placer.cc:54] Variable/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031933: I tensorflow/core/common_runtime/placer.cc:54] Variable/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031939: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031945: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031950: I tensorflow/core/common_runtime/placer.cc:54] Variable_1/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031957: I tensorflow/core/common_runtime/placer.cc:54] random_normal_1/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031963: I tensorflow/core/common_runtime/placer.cc:54] random_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031970: I tensorflow/core/common_runtime/placer.cc:54] random_normal_1: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031976: I tensorflow/core/common_runtime/placer.cc:54] mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031983: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031989: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.031994: I tensorflow/core/common_runtime/placer.cc:54] Variable_2/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032000: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032007: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032012: I tensorflow/core/common_runtime/placer.cc:54] Variable_3/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032019: I tensorflow/core/common_runtime/placer.cc:54] random_normal_2/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032025: I tensorflow/core/common_runtime/placer.cc:54] random_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032031: I tensorflow/core/common_runtime/placer.cc:54] random_normal_2: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032038: I tensorflow/core/common_runtime/placer.cc:54] mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032044: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032053: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032058: I tensorflow/core/common_runtime/placer.cc:54] Variable_4/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032064: I tensorflow/core/common_runtime/placer.cc:54] Variable_5/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032070: I tensorflow/core/common_runtime/placer.cc:54] Variable_5/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032075: I tensorflow/core/common_runtime/placer.cc:54] Variable_5/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032083: I tensorflow/core/common_runtime/placer.cc:54] random_normal_3/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032090: I tensorflow/core/common_runtime/placer.cc:54] random_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032096: I tensorflow/core/common_runtime/placer.cc:54] random_normal_3: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032102: I tensorflow/core/common_runtime/placer.cc:54] mul_3: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032109: I tensorflow/core/common_runtime/placer.cc:54] Variable_6/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032115: I tensorflow/core/common_runtime/placer.cc:54] Variable_6/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032120: I tensorflow/core/common_runtime/placer.cc:54] Variable_6/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032127: I tensorflow/core/common_runtime/placer.cc:54] Variable_7/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032133: I tensorflow/core/common_runtime/placer.cc:54] Variable_7/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032138: I tensorflow/core/common_runtime/placer.cc:54] Variable_7/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032146: I tensorflow/core/common_runtime/placer.cc:54] concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032151: I tensorflow/core/common_runtime/placer.cc:54] MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032157: I tensorflow/core/common_runtime/placer.cc:54] MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032162: I tensorflow/core/common_runtime/placer.cc:54] Add/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032168: I tensorflow/core/common_runtime/placer.cc:54] Add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032175: I tensorflow/core/common_runtime/placer.cc:54] Tanh: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032180: I tensorflow/core/common_runtime/placer.cc:54] MatMul_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032186: I tensorflow/core/common_runtime/placer.cc:54] MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032191: I tensorflow/core/common_runtime/placer.cc:54] Add_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032197: I tensorflow/core/common_runtime/placer.cc:54] Add_1: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032203: I tensorflow/core/common_runtime/placer.cc:54] Tanh_1: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032209: I tensorflow/core/common_runtime/placer.cc:54] MatMul_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032220: I tensorflow/core/common_runtime/placer.cc:54] MatMul_2: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032226: I tensorflow/core/common_runtime/placer.cc:54] Add_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032233: I tensorflow/core/common_runtime/placer.cc:54] Add_2: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032239: I tensorflow/core/common_runtime/placer.cc:54] Tanh_2: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032244: I tensorflow/core/common_runtime/placer.cc:54] MatMul_3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032251: I tensorflow/core/common_runtime/placer.cc:54] MatMul_3: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032256: I tensorflow/core/common_runtime/placer.cc:54] Add_3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032262: I tensorflow/core/common_runtime/placer.cc:54] Add_3: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032268: I tensorflow/core/common_runtime/placer.cc:54] concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032273: I tensorflow/core/common_runtime/placer.cc:54] MatMul_4/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032279: I tensorflow/core/common_runtime/placer.cc:54] MatMul_4: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032284: I tensorflow/core/common_runtime/placer.cc:54] Add_4/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032291: I tensorflow/core/common_runtime/placer.cc:54] Add_4: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032297: I tensorflow/core/common_runtime/placer.cc:54] Tanh_3: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032302: I tensorflow/core/common_runtime/placer.cc:54] MatMul_5/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032309: I tensorflow/core/common_runtime/placer.cc:54] MatMul_5: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032314: I tensorflow/core/common_runtime/placer.cc:54] Add_5/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032320: I tensorflow/core/common_runtime/placer.cc:54] Add_5: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032327: I tensorflow/core/common_runtime/placer.cc:54] Tanh_4: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032332: I tensorflow/core/common_runtime/placer.cc:54] MatMul_6/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032339: I tensorflow/core/common_runtime/placer.cc:54] MatMul_6: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032344: I tensorflow/core/common_runtime/placer.cc:54] Add_6/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032350: I tensorflow/core/common_runtime/placer.cc:54] Add_6: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032356: I tensorflow/core/common_runtime/placer.cc:54] Tanh_5: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032361: I tensorflow/core/common_runtime/placer.cc:54] MatMul_7/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032367: I tensorflow/core/common_runtime/placer.cc:54] MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032372: I tensorflow/core/common_runtime/placer.cc:54] Add_7/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032378: I tensorflow/core/common_runtime/placer.cc:54] Add_7: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032392: I tensorflow/core/common_runtime/placer.cc:54] gradients/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032398: I tensorflow/core/common_runtime/placer.cc:54] gradients/Fill: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032405: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032411: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032417: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032423: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032429: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032435: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032440: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_7_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032446: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_7_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032452: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_7_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032458: I tensorflow/core/common_runtime/placer.cc:54] gradients/Tanh_5_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032464: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032470: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032476: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032482: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032488: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032494: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032500: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_6_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032506: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_6_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032512: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_6_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032518: I tensorflow/core/common_runtime/placer.cc:54] gradients/Tanh_4_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032524: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032530: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032536: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032542: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032548: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032554: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032559: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_5_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032565: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_5_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032571: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_5_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032577: I tensorflow/core/common_runtime/placer.cc:54] gradients/Tanh_3_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032583: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032589: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032595: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032601: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032607: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032613: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032619: I tensorflow/core/common_runtime/placer.cc:54] gradients/Add_4_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032624: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_4_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032630: I tensorflow/core/common_runtime/placer.cc:54] gradients/MatMul_4_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032636: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032642: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032648: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/ShapeN: (ShapeN): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032654: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032660: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032666: I tensorflow/core/common_runtime/placer.cc:54] gradients/concat_1_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032672: I tensorflow/core/common_runtime/placer.cc:54] truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032678: I tensorflow/core/common_runtime/placer.cc:54] concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032682: I tensorflow/core/common_runtime/placer.cc:54] MatMul_8/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032688: I tensorflow/core/common_runtime/placer.cc:54] MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032693: I tensorflow/core/common_runtime/placer.cc:54] Add_8/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032698: I tensorflow/core/common_runtime/placer.cc:54] Add_8: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032704: I tensorflow/core/common_runtime/placer.cc:54] Tanh_6: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032709: I tensorflow/core/common_runtime/placer.cc:54] MatMul_9/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032715: I tensorflow/core/common_runtime/placer.cc:54] MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032720: I tensorflow/core/common_runtime/placer.cc:54] Add_9/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032726: I tensorflow/core/common_runtime/placer.cc:54] Add_9: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032732: I tensorflow/core/common_runtime/placer.cc:54] Tanh_7: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032737: I tensorflow/core/common_runtime/placer.cc:54] MatMul_10/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032742: I tensorflow/core/common_runtime/placer.cc:54] MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032748: I tensorflow/core/common_runtime/placer.cc:54] Add_10/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032754: I tensorflow/core/common_runtime/placer.cc:54] Add_10: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032759: I tensorflow/core/common_runtime/placer.cc:54] Tanh_8: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032765: I tensorflow/core/common_runtime/placer.cc:54] MatMul_11/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032771: I tensorflow/core/common_runtime/placer.cc:54] MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032776: I tensorflow/core/common_runtime/placer.cc:54] Add_11/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032781: I tensorflow/core/common_runtime/placer.cc:54] Add_11: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032787: I tensorflow/core/common_runtime/placer.cc:54] concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032792: I tensorflow/core/common_runtime/placer.cc:54] MatMul_12/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032798: I tensorflow/core/common_runtime/placer.cc:54] MatMul_12: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032803: I tensorflow/core/common_runtime/placer.cc:54] Add_12/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032809: I tensorflow/core/common_runtime/placer.cc:54] Add_12: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032815: I tensorflow/core/common_runtime/placer.cc:54] Tanh_9: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032820: I tensorflow/core/common_runtime/placer.cc:54] MatMul_13/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032826: I tensorflow/core/common_runtime/placer.cc:54] MatMul_13: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032831: I tensorflow/core/common_runtime/placer.cc:54] Add_13/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032837: I tensorflow/core/common_runtime/placer.cc:54] Add_13: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032843: I tensorflow/core/common_runtime/placer.cc:54] Tanh_10: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032848: I tensorflow/core/common_runtime/placer.cc:54] MatMul_14/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032853: I tensorflow/core/common_runtime/placer.cc:54] MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032858: I tensorflow/core/common_runtime/placer.cc:54] Add_14/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032864: I tensorflow/core/common_runtime/placer.cc:54] Add_14: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032870: I tensorflow/core/common_runtime/placer.cc:54] Tanh_11: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032875: I tensorflow/core/common_runtime/placer.cc:54] MatMul_15/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032881: I tensorflow/core/common_runtime/placer.cc:54] MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032885: I tensorflow/core/common_runtime/placer.cc:54] Add_15/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032891: I tensorflow/core/common_runtime/placer.cc:54] Add_15: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032897: I tensorflow/core/common_runtime/placer.cc:54] concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032902: I tensorflow/core/common_runtime/placer.cc:54] MatMul_16/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032907: I tensorflow/core/common_runtime/placer.cc:54] MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032912: I tensorflow/core/common_runtime/placer.cc:54] Add_16/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032917: I tensorflow/core/common_runtime/placer.cc:54] Add_16: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032923: I tensorflow/core/common_runtime/placer.cc:54] Tanh_12: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032928: I tensorflow/core/common_runtime/placer.cc:54] MatMul_17/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032933: I tensorflow/core/common_runtime/placer.cc:54] MatMul_17: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032938: I tensorflow/core/common_runtime/placer.cc:54] Add_17/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032944: I tensorflow/core/common_runtime/placer.cc:54] Add_17: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032949: I tensorflow/core/common_runtime/placer.cc:54] Tanh_13: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032954: I tensorflow/core/common_runtime/placer.cc:54] MatMul_18/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032960: I tensorflow/core/common_runtime/placer.cc:54] MatMul_18: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032964: I tensorflow/core/common_runtime/placer.cc:54] Add_18/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032970: I tensorflow/core/common_runtime/placer.cc:54] Add_18: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032976: I tensorflow/core/common_runtime/placer.cc:54] Tanh_14: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032980: I tensorflow/core/common_runtime/placer.cc:54] MatMul_19/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032986: I tensorflow/core/common_runtime/placer.cc:54] MatMul_19: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032991: I tensorflow/core/common_runtime/placer.cc:54] Add_19/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.032997: I tensorflow/core/common_runtime/placer.cc:54] Add_19: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033003: I tensorflow/core/common_runtime/placer.cc:54] concat_5: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033008: I tensorflow/core/common_runtime/placer.cc:54] MatMul_20/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033021: I tensorflow/core/common_runtime/placer.cc:54] MatMul_20: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033026: I tensorflow/core/common_runtime/placer.cc:54] Add_20/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033032: I tensorflow/core/common_runtime/placer.cc:54] Add_20: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033038: I tensorflow/core/common_runtime/placer.cc:54] Tanh_15: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033043: I tensorflow/core/common_runtime/placer.cc:54] MatMul_21/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033048: I tensorflow/core/common_runtime/placer.cc:54] MatMul_21: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033054: I tensorflow/core/common_runtime/placer.cc:54] Add_21/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033059: I tensorflow/core/common_runtime/placer.cc:54] Add_21: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033065: I tensorflow/core/common_runtime/placer.cc:54] Tanh_16: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033070: I tensorflow/core/common_runtime/placer.cc:54] MatMul_22/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033076: I tensorflow/core/common_runtime/placer.cc:54] MatMul_22: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033080: I tensorflow/core/common_runtime/placer.cc:54] Add_22/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033086: I tensorflow/core/common_runtime/placer.cc:54] Add_22: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033091: I tensorflow/core/common_runtime/placer.cc:54] Tanh_17: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033096: I tensorflow/core/common_runtime/placer.cc:54] MatMul_23/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033102: I tensorflow/core/common_runtime/placer.cc:54] MatMul_23: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033106: I tensorflow/core/common_runtime/placer.cc:54] Add_23/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033117: I tensorflow/core/common_runtime/placer.cc:54] Add_23: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033124: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033131: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Fill: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033137: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033143: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033150: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033156: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033162: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033168: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033174: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_23_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033181: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_23_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033187: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_23_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033194: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Tanh_17_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033200: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033206: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033213: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033219: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033225: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033231: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033237: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_22_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033243: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_22_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033249: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_22_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033255: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Tanh_16_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033261: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033267: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033273: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033279: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033285: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033291: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033297: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_21_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033303: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_21_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033309: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_21_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033315: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Tanh_15_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033321: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033327: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033333: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033340: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033346: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033356: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033362: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/Add_20_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033368: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_20_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033375: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/MatMul_20_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033382: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033389: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033395: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/ShapeN: (ShapeN): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033402: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033408: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033414: I tensorflow/core/common_runtime/placer.cc:54] gradients_1/concat_5_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033420: I tensorflow/core/common_runtime/placer.cc:54] truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033426: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033432: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Fill: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033439: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033445: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033451: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033457: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033463: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033469: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033475: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_23_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033481: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/MatMul_23_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033487: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/MatMul_23_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033493: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Tanh_17_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033499: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033505: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033511: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033517: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033523: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033528: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.033534: I tensorflow/core/common_runtime/placer.cc:54] gradients_2/Add_22_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# 2023-03-28 09:37:28.429073: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_8_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429165: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_8_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429173: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_8_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429179: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_8_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429186: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_8_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429192: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/mul_6_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429198: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/mul_6_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429219: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429226: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429233: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429239: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429246: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429252: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429275: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429282: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429288: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429294: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_9_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429301: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429366: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429374: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429381: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429387: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429394: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429671: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/concat_8_grad/Slice_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429679: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/Add_35_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429685: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/Add_35_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429694: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429700: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/RealDiv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429707: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429713: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429719: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429726: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/RealDiv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429733: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/RealDiv_2: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429739: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429745: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429766: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/truediv_7_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429776: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429783: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429793: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429799: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429864: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429873: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429880: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/concat_8_grad/Slice_1_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429887: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/MatMul_32_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429893: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/MatMul_32_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429972: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/MatMul_35_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429982: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/MatMul_35_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429988: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.429995: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430001: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430264: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430271: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430280: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430286: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/concat_8_grad/Slice_1_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430293: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/MatMul_32_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430301: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/MatMul_32_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430308: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/Tanh_24_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430314: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/Tanh_24_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430320: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/Tanh_24_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430327: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/Tanh_24_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430344: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/MatMul_32_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430351: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/MatMul_32_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430357: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/Tanh_24_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430364: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/Tanh_24_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430371: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/Tanh_24_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430392: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/Tanh_24_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430399: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/Tanh_24_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430405: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/Tanh_24_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430412: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/Tanh_24_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430420: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_7/Tanh_24_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430504: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/gradients_6/Tanh_24_grad/TanhGrad_grad/mul_2_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430511: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/gradients_6/Tanh_24_grad/TanhGrad_grad/mul_2_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430518: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/MatMul_33_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430525: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/MatMul_33_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430534: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/gradients_7/Tanh_24_grad/TanhGrad_grad/mul_2_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430555: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/gradients_7/Tanh_24_grad/TanhGrad_grad/mul_2_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430562: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/MatMul_33_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430569: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_9/MatMul_33_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430576: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/gradients_6/Tanh_24_grad/TanhGrad_grad/mul_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430582: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/gradients_6/Tanh_24_grad/TanhGrad_grad/mul_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430730: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/gradients_8/Tanh_25_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-28 09:37:28.430739: I tensorflow/core/common_runtime/placer.cc:54] loop_body_19/gradients/IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Train model
itertaions = 1000
log_NTK = False # Compute and store NTK matrix during training
update_lam = True # Compute and update the loss weights using the NTK 

model.train(nIter=itertaions, batch_size=kernel_size, log_NTK=log_NTK, update_lam=update_lam)
# Out:
# It: 0, Loss: 3.100e-01, Loss_res: 3.444e-04,  Loss_bcs: 2.787e-01, Loss_ut_ics: 3.093e-02,, Time: 0.15
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 100, Loss: 2.189e-01, Loss_res: 7.006e-03,  Loss_bcs: 1.969e-01, Loss_ut_ics: 1.499e-02,, Time: 18.17
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 200, Loss: 1.684e-01, Loss_res: 8.436e-03,  Loss_bcs: 1.530e-01, Loss_ut_ics: 7.027e-03,, Time: 18.46
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 300, Loss: 1.538e-01, Loss_res: 5.448e-03,  Loss_bcs: 1.343e-01, Loss_ut_ics: 1.413e-02,, Time: 18.47
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 400, Loss: 1.592e-01, Loss_res: 2.668e-02,  Loss_bcs: 1.282e-01, Loss_ut_ics: 4.334e-03,, Time: 18.60
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 500, Loss: 1.415e-01, Loss_res: 1.124e-02,  Loss_bcs: 1.263e-01, Loss_ut_ics: 3.956e-03,, Time: 18.80
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 600, Loss: 1.076e-01, Loss_res: 6.086e-03,  Loss_bcs: 9.706e-02, Loss_ut_ics: 4.488e-03,, Time: 18.60
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 700, Loss: 1.021e-01, Loss_res: 1.942e-02,  Loss_bcs: 8.028e-02, Loss_ut_ics: 2.441e-03,, Time: 20.02
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 800, Loss: 8.236e-02, Loss_res: 3.235e-03,  Loss_bcs: 7.552e-02, Loss_ut_ics: 3.605e-03,, Time: 21.64
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00
# It: 900, Loss: 1.084e-01, Loss_res: 3.295e-02,  Loss_bcs: 6.780e-02, Loss_ut_ics: 7.597e-03,, Time: 18.05
# lambda_u: 1.000e+00
# lambda_ut: 1.000e+00
# lambda_r: 1.000e+00

# %% [markdown]
# **Training Loss**

# %%
loss_res = model.loss_res_log
loss_bcs = model.loss_bcs_log
loss_u_t_ics = model.loss_ut_ics_log

fig = plt.figure(figsize=(6, 5))
plt.plot(loss_res, label='$\mathcal{L}_{r}$')
plt.plot(loss_bcs, label='$\mathcal{L}_{u}$')
plt.plot(loss_u_t_ics, label='$\mathcal{L}_{u_t}$')
plt.yscale('log')
plt.xlabel('iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
nn = 200
t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
t, x = np.meshgrid(t, x)
X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

u_star = u(X_star, a,c)
R_star = r(X_star, a, c)

# Predictions
u_pred = model.predict_u(X_star)
r_pred = model.predict_r(X_star)
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)

print('Relative L2 error_u: %e' % (error_u))
# Out:
# Relative L2 error_u: 1.399332e+00

# %%
U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
R_star = griddata(X_star, R_star.flatten(), (t, x), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')


plt.figure(figsize=(18, 9))
plt.subplot(2, 3, 1)
plt.pcolor(t, x, U_star, cmap='jet')
plt.colorbar()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Exact u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 2)
plt.pcolor(t, x, U_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted u(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 3)
plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()

plt.subplot(2, 3, 4)
plt.pcolor(t, x, R_star, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Exact r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 5)
plt.pcolor(t, x, R_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Predicted r(t, x)')
plt.tight_layout()

plt.subplot(2, 3, 6)
plt.pcolor(t, x, np.abs(R_star - R_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lw/nwlcmhh94pl3g8q6fldyw3jh0000gn/T/ipykernel_99030/1156779678.py in <module>
#       1 U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
# ----> 2 R_star = griddata(X_star, R_star.flatten(), (t, x), method='cubic')
#       3 U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')
#       4 R_pred = griddata(X_star, r_pred.flatten(), (t, x), method='cubic')
#       5
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/scipy/interpolate/ndgriddata.py in griddata(points, values, xi, method, fill_value, rescale)
#     263     elif method == 'cubic' and ndim == 2:
#     264         ip = CloughTocher2DInterpolator(points, values, fill_value=fill_value,
# --> 265                                         rescale=rescale)
#     266         return ip(xi)
#     267     else:
#
# interpnd.pyx in scipy.interpolate.interpnd.CloughTocher2DInterpolator.__init__()
#
# interpnd.pyx in scipy.interpolate.interpnd.NDInterpolatorBase.__init__()
#
# interpnd.pyx in scipy.interpolate.interpnd._check_init_shape()
#
# ValueError: different number of values and points

# %% [markdown]
# **NTK Eigenvalues**

# %%
# Create empty lists for storing the eigenvalues of NTK
lam_K_u_log = []
lam_K_ut_log = []
lam_K_r_log = []

# Restore the NTK
K_u_list = model.K_u_log
K_ut_list = model.K_ut_log
K_r_list = model.K_r_log

K_list = []
    
for k in range(len(K_u_list)):
    K_u = K_u_list[k]
    K_ut = K_ut_list[k]
    K_r = K_r_list[k]
    
    # Compute eigenvalues
    lam_K_u, _ = np.linalg.eig(K_u)
    lam_K_ut, _ = np.linalg.eig(K_ut)
    lam_K_r, _ = np.linalg.eig(K_r)
    # Sort in descresing order
    lam_K_u = np.sort(np.real(lam_K_u))[::-1]
    lam_K_ut = np.sort(np.real(lam_K_ut))[::-1]
    lam_K_r = np.sort(np.real(lam_K_r))[::-1]
    
    # Store eigenvalues
    lam_K_u_log.append(lam_K_u)
    lam_K_ut_log.append(lam_K_ut)
    lam_K_r_log.append(lam_K_r)

# %%
#  Eigenvalues of NTK
fig = plt.figure(figsize=(18, 5))
plt.subplot(1,3,1)

plt.plot(lam_K_u_log[0], label = '$n=0$')
plt.plot(lam_K_u_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_u_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_u_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')

plt.title(r'Eigenvalues of ${K}_u$')

plt.subplot(1,3,2)
plt.plot(lam_K_ut_log[0], label = '$n=0$')
plt.plot(lam_K_ut_log[1], '--',label = '$n=10,000$')
plt.plot(lam_K_ut_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_ut_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{u_t}$')

ax =plt.subplot(1,3,3)
plt.plot(lam_K_r_log[0], label = '$n=0$')
plt.plot(lam_K_r_log[1], '--', label = '$n=10,000$')
plt.plot(lam_K_r_log[4], '--', label = '$n=40,000$')
plt.plot(lam_K_r_log[-1], '--', label = '$n=80,000$')
plt.xscale('log')
plt.yscale('log')
plt.title(r'Eigenvalues of ${K}_{r}$')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left", bbox_to_anchor=(0.35, -0.02),
            borderaxespad=0, bbox_transform=fig.transFigure, ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Evolution of NTK Weights**

# %%
if update_lam == True:

  lam_u_log = model.lam_u_log
  lam_ut_log = model.lam_ut_log
  lam_r_log = model.lam_r_log

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lam_u_log, label='$\lambda_u$')
plt.plot(lam_ut_log, label='$\lambda_{u_t}$')
plt.plot(lam_r_log, label='$\lambda_{r}$')
plt.xlabel('iterations')
plt.ylabel('$\lambda$')
plt.yscale('log')
plt.legend( )
plt.tight_layout()
plt.show()
